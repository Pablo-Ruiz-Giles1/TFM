# %% [markdown]
# ![](files/images/EscUpmPolit_p.gif "UPM")

# %% [markdown]
# <header style="width: 100%; position: relative; text-align: center;">
#   <div style="width: 80%; display: inline-block;">
#     <h1 style="margin: 0; margin-bottom: 10px;">Procesado de datos de Blockchain</h1>
#     <h3 style="margin: 0; margin-bottom: 20px;">TFM</h3>
#     <h5 style="margin: 0;">Universidad Politécnica de Madrid. © Pablo Ruiz Giles</h5>
#   </div>
# </header>

# %% [markdown]
# <section id="comprar">
#   <h1>Comprar</h1>
#
# </section>

# %% [markdown]
# A continuación se presenta un breve resumen de los puntos que se tratarán en el notebook:
#
# - Comprar: Esta sección abordará aspectos relacionados con la comparativa de las redes de blockchain.
#
# - Importar datasets: Se explicará cómo importar los conjuntos de datos necesarios para el estudio, incluyendo los datasets paralelo y Etherscan.
#
# - Procesamiento de los datos: En esta sección se describirán los procesos aplicados a los datos, como la modificación de la columna de coste en wei, la adición de columnas de diferencias de tiempos, duración y coste total, así como la conversión del gas utilizado de formato hexadecimal a decimal.
#
# - Representación: Se presentarán diversas representaciones gráficas para visualizar el coste en wei de las transacciones, el tiempo que tarda cada transacción, la relación entre el gas utilizado y el coste en wei, la dispersión por bloque y los boxplots comparativos.
#
# - Resumen del conjunto de datos: Esta sección se enfocará en el resumen general del conjunto de datos utilizado en el estudio.
#
# - Procesamiento de los datos: Se describirán las modificaciones adicionales realizadas en los datos, específicamente relacionadas con la columna de coste total.
#
# - Representación: Se presentarán representaciones gráficas del coste total y su relación con la duración de las transacciones.

# %% [markdown]
# <h1>Índice</h1>
# 	<ul>
# 		<li><h3>Comprar</h3></li>
# 		<li>Importar datasets
# 			<ul>
# 				<li><a href="#paralelo">Paralelo</a></li>
# 				<li><a href="#etherscan">Etherscan</a></li>
# 			</ul>
# 		</li>
# 		<li>Procesamos los datos
# 			<ul>
# 				<li><a href="#modificacion-wei">Modificación de la columna Coste en wei</a></li>
#                 <li><a href="#columnas-tiempo">Añadir columna Diferencia de tiempos, Duración y Coste Total</a></li>
# 				<li><a href="#conversion-hex-dec">Conversión de hexadecimal a decimal Gas utilizado</a></li>
# 			</ul>
# 		</li>
# 		<li>Representación
# 			<ul>
# 				<li><a href="#representacion-conjunto">Representación de Coste de Wei en Conjunto</a></li>
# 				<li><a href="#representacion-individual">Representación de Coste de Wei Individualizado</a></li>
# 				<li><a href="#representacion-tiempo">Representación de coste en wei y tiempo que tarda en cada transacción</a></li>
# 				<li><a href="#representacion-gas">Representación del gas y su equivalencia en Coste en wei</a></li>
# 				<li><a href="#dispersion-individual">Representación de dispersión para comparar el Gas utilizado y el Coste en wei por Bloque Individualizado</a></li>
# 				<li><a href="#dispersion-conjunto">Representación de dispersión para comparar el Gas utilizado y el Coste en wei por Bloque en Conjunto</a></li>
# 				<li><a href="#boxplot-gas">Representación mediante BoxPlot del Gas utilizado</a></li>
# 				<li><a href="#boxplot-coste">Representación mediante BoxPlot del Coste en wei</a></li>
# 			</ul>
# 		</li>
# 		<li><h3>Resumen del conjunto de datos</h3></li>
# 		<li>Importar dataset
# 			<ul>
# 				<li><a href="#resumen">Resumen</a></li>
# 			</ul>
# 		</li>
# 		<li>Procesamos los datos
# 			<ul>
# 				<li><a href="#modificacion-coste-total">Modificación de la columna Coste Total</a></li>
# 			</ul>
# 		</li>
# 		<li>Representación
# 			<ul>
# 				<li><a href="#representacion-coste-total">Representación de Coste Total</a></li>
# 				<li><a href="#representacion-coste-duracion">Representación de Coste Total y la duración</a></li>
# 			</ul>
# 		</li>
# 	</ul>

# %% [markdown]
# ## Importamos los datasets

# %% [markdown]
# <section id="paralelo">
#   <h2>Paralelo Datasets</h2>
#
# </section>

# %% [markdown]
# Importamos los datastes de datos y creamos un diccionario llamado datasets_resumen que contiene los datos anteriormente importados

# %%
import pandas as pd
import os

# Obtener la lista de carpetas en la carpeta datos/paralelo/
carpetas = [f for f in os.listdir('datos/paralelo/') if os.path.isdir(os.path.join('datos/paralelo/', f))]

# Crear un diccionario vacío para almacenar los DataFrames
datasets_resumen = {}
# Lista de archivos a excluir
archivos_excluidos = ['avalanche', 'celo']

# Leer cada archivo CSV en cada carpeta y asignarlo a una variable con el nombre de la carpeta
for carpeta in carpetas:
    csv_files = [f for f in os.listdir(os.path.join('datos/paralelo/', carpeta)) if f.endswith('paralelodatos1.csv') and not any(x in f for x in archivos_excluidos)]
    for f in csv_files:
        name = os.path.splitext(f)[0]
        name_without_suffix = name.replace('_paralelodatos1', '')
        vars()[name] = pd.read_csv(os.path.join('datos/paralelo/', carpeta, f))
        datasets_resumen[name_without_suffix] = eval(name)

# Imprimir los nombres de las variables creadas que contengan "_paralelodatos1"
print("Los siguientes DataFrames se han creado:")
for var in sorted(datasets_resumen.keys()):
    print(var)
# Out:
# Los siguientes DataFrames se han creado:
# arbitrum
# arbitrum_bear
# boba
# optimism_bear
# polygon_bear
# sepolia
# sepolia_bear

# %% [markdown]
# <section id="etherscan">
#   <h2>Etherscan Datasets</h2>
#
# </section>

# %% [markdown]
# Importamos los datastes de ethercan y creamos un diccionario llamado datasets_scan que contiene los datos anteriormente importandos

# %%
import pandas as pd
import os

# Crear un diccionario vacío para almacenar los DataFrames
datasets_scan = {}

# Obtener los archivos CSV en todas las subcarpetas que contengan '_secuencial' en su nombre
csv_files = []
for root, dirs, files in os.walk('datos/scan/'):
    for f in files:
        if 'scan' in f and f.endswith('.csv'):
            csv_file_path = os.path.join(root, f)
            name = os.path.splitext(os.path.basename(csv_file_path))[0]
            df = pd.read_csv(csv_file_path)
            vars()[name] = df
            datasets_scan[name] = df

# Imprimir los nombres de los DataFrames creados
print("Los siguientes DataFrames se han creado:")
for var_name in sorted(datasets_scan.keys()):
    print(var_name)
# Out:
# Los siguientes DataFrames se han creado:
# scan_arbitrum
# scan_avalanche
# scan_boba
# scan_celo
# scan_goerli
# scan_optimism
# scan_sepolia

# %% [markdown]
# #### Visualizamos el tipo de datos que contiene etherscan

# %%
# Imprimir los nombres de las variables creadas que contengan "scan"
print("Los siguientes DataFrames se han creado:")
for var in sorted(datasets_scan.keys()):
    if 'scan' in var:
        print(var)

        # Acceder a cada DataFrame y asignar el índice a la columna "index_col"
        datasets_scan[var]['index_col'] = datasets_scan[var].index
        datasets_scan[var].info()
# Out:
# Los siguientes DataFrames se han creado:
# scan_arbitrum
# <class 'pandas.core.frame.DataFrame'>
# Index: 117 entries, 0x60fefc9d415057be9422701b7b470afef223402020fdbcb9f642f5399294debf to 0xb98ba76b2aa7a6237947cf677e13d9a4f265c2d38b912dfca57d20c87b463101
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Txhash                 117 non-null    int64
#  1   Blockno                117 non-null    int64
#  2   UnixTimestamp          117 non-null    object
#  3   DateTime               117 non-null    object
#  4   From                   106 non-null    object
#  5   To                     11 non-null     object
#  6   ContractAddress        117 non-null    float64
#  7   Value_IN(ETH)          117 non-null    int64
#  8   Value_OUT(ETH)         117 non-null    float64
#  9   CurrentValue @ $0/Eth  117 non-null    float64
#  10  TxnFee(ETH)            117 non-null    float64
#  11  TxnFee(USD)            115 non-null    float64
#  12  Historical $Price/ETH  2 non-null      object
#  13  Status                 2 non-null      object
#  14  ErrCode                117 non-null    object
#  15  Method                 0 non-null      float64
#  16  index_col              117 non-null    object
# dtypes: float64(6), int64(3), object(8)
# memory usage: 16.5+ KB
# scan_avalanche
# <class 'pandas.core.frame.DataFrame'>
# Index: 83 entries, 0x24cd4afbf8c0f52567f806d859206d33c97c4b81b50ae00e21c76affcb63c630 to 0x28d0e0d45fd15719a80219c07bc913f776edd7430cd58abe61276dab0f89f37e
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Txhash                  83 non-null     int64
#  1   Blockno                 83 non-null     int64
#  2   UnixTimestamp           83 non-null     object
#  3   DateTime                83 non-null     object
#  4   From                    78 non-null     object
#  5   To                      5 non-null      object
#  6   ContractAddress         83 non-null     float64
#  7   Value_IN(AVAX)          83 non-null     float64
#  8   Value_OUT(AVAX)         83 non-null     float64
#  9   CurrentValue @ $0/Eth   83 non-null     float64
#  10  TxnFee(AVAX)            83 non-null     float64
#  11  TxnFee(USD)             81 non-null     float64
#  12  Historical $Price/AVAX  0 non-null      float64
#  13  Status                  0 non-null      float64
#  14  ErrCode                 83 non-null     object
#  15  Method                  0 non-null      float64
#  16  index_col               83 non-null     object
# dtypes: float64(9), int64(2), object(6)
# memory usage: 11.7+ KB
# scan_boba
# <class 'pandas.core.frame.DataFrame'>
# Index: 181 entries, 0x3490d7d03388958c0e257936095b20363b41abd72f42eff8772d8aa118a69a9f to 0x71fe7e478ec2aac05a0f246a98da2bfe048eb766c043dd75b806d3c4245d31c3
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Txhash                 181 non-null    int64
#  1   Blockno                181 non-null    int64
#  2   UnixTimestamp          181 non-null    object
#  3   DateTime               181 non-null    object
#  4   From                   171 non-null    object
#  5   To                     10 non-null     object
#  6   ContractAddress        181 non-null    float64
#  7   Value_IN(ETH)          181 non-null    int64
#  8   Value_OUT(ETH)         181 non-null    int64
#  9   CurrentValue @ $0/Eth  181 non-null    float64
#  10  TxnFee(ETH/Boba)       181 non-null    int64
#  11  TxnFee(USD)            0 non-null      float64
#  12  Historical $Price/Eth  0 non-null      float64
#  13  Status                 0 non-null      float64
#  14  ErrCode                181 non-null    object
#  15  Method                 0 non-null      float64
#  16  index_col              181 non-null    object
# dtypes: float64(6), int64(5), object(6)
# memory usage: 25.5+ KB
# scan_celo
# <class 'pandas.core.frame.DataFrame'>
# Index: 56 entries, 0x20ecffa91082ba63f0a188dca44018b708a49d614c0a7cdbe7f24ecb1eb107dc to 0x488470fa8d51ef795b93ccbec181d0ddcbc84736ac54d2a42f594d59a2459e2e
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Txhash                  56 non-null     int64
#  1   Blockno                 56 non-null     int64
#  2   UnixTimestamp           56 non-null     object
#  3   DateTime                56 non-null     object
#  4   From                    52 non-null     object
#  5   To                      4 non-null      object
#  6   ContractAddress         56 non-null     float64
#  7   Value_IN(CELO)          56 non-null     int64
#  8   Value_OUT(CELO)         56 non-null     float64
#  9   CurrentValue @ $0/Eth   56 non-null     float64
#  10  TxnFee(CELO)            56 non-null     float64
#  11  TxnFee(USD)             54 non-null     float64
#  12  Historical $Price/CELO  0 non-null      float64
#  13  Status                  0 non-null      float64
#  14  ErrCode                 56 non-null     object
#  15  Method                  0 non-null      float64
#  16  index_col               56 non-null     object
# dtypes: float64(8), int64(3), object(6)
# memory usage: 7.9+ KB
# scan_goerli
# <class 'pandas.core.frame.DataFrame'>
# Index: 53 entries, 0x7c47adafe7fda59be432ad055b1684e603cbd904dfc6daaa024d3af0d49aff13 to 0xb19ee428df955e0da32adc97e940331cd47ac3b09f8ead166b24136e86762d9b
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Txhash                 53 non-null     int64
#  1   Blockno                53 non-null     int64
#  2   UnixTimestamp          53 non-null     object
#  3   DateTime               53 non-null     object
#  4   From                   45 non-null     object
#  5   To                     8 non-null      object
#  6   ContractAddress        53 non-null     float64
#  7   Value_IN(ETH)          53 non-null     float64
#  8   Value_OUT(ETH)         53 non-null     int64
#  9   CurrentValue @ $0/Eth  53 non-null     float64
#  10  TxnFee(ETH)            53 non-null     int64
#  11  TxnFee(USD)            0 non-null      float64
#  12  Historical $Price/Eth  4 non-null      object
#  13  Status                 4 non-null      object
#  14  ErrCode                53 non-null     object
#  15  Method                 0 non-null      float64
#  16  index_col              53 non-null     object
# dtypes: float64(5), int64(4), object(8)
# memory usage: 7.5+ KB
# scan_optimism
# <class 'pandas.core.frame.DataFrame'>
# Index: 157 entries, 0x0eaa54a3fc2bcc3cb1fab12ce99ca36eddc4dce64bcaf874558a6cd2a8a1862e to 0x36f8c38db92a0fa37ab1f6a6f6cac044540bcf2ab845629859235b6f5dfbc843
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Txhash                 157 non-null    int64
#  1   Blockno                157 non-null    int64
#  2   UnixTimestamp          157 non-null    object
#  3   DateTime               157 non-null    object
#  4   From                   139 non-null    object
#  5   To                     18 non-null     object
#  6   ContractAddress        157 non-null    float64
#  7   Value_IN(ETH)          157 non-null    int64
#  8   Value_OUT(ETH)         157 non-null    int64
#  9   CurrentValue @ $0/Eth  157 non-null    float64
#  10  TxnFee(ETH)            157 non-null    int64
#  11  TxnFee(USD)            0 non-null      float64
#  12  Historical $Price/Eth  3 non-null      object
#  13  Status                 3 non-null      object
#  14  ErrCode                157 non-null    object
#  15  Method                 0 non-null      float64
#  16  index_col              157 non-null    object
# dtypes: float64(4), int64(5), object(8)
# memory usage: 22.1+ KB
# scan_sepolia
# <class 'pandas.core.frame.DataFrame'>
# Index: 273 entries, 0x2ba958925512bc001ad998db5d7323deb4009f536bd01685ac40f193382db6bf to 0x5c89f0a3c1ba1b723fcbd1953525b7c978e49888155d3228678f6c5f788d9b9c
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Txhash                 273 non-null    int64
#  1   Blockno                273 non-null    int64
#  2   UnixTimestamp          273 non-null    object
#  3   DateTime               273 non-null    object
#  4   From                   258 non-null    object
#  5   To                     15 non-null     object
#  6   ContractAddress        273 non-null    float64
#  7   Value_IN(ETH)          273 non-null    int64
#  8   Value_OUT(ETH)         273 non-null    int64
#  9   CurrentValue @ $0/Eth  273 non-null    float64
#  10  TxnFee(ETH)            273 non-null    int64
#  11  TxnFee(USD)            0 non-null      float64
#  12  Historical $Price/Eth  3 non-null      object
#  13  Status                 3 non-null      object
#  14  ErrCode                273 non-null    object
#  15  Method                 0 non-null      float64
#  16  index_col              273 non-null    object
# dtypes: float64(4), int64(5), object(8)
# memory usage: 38.4+ KB

# %%
scan_sepolia['CurrentValue @ $0/Eth']
# Out:
# 0x2ba958925512bc001ad998db5d7323deb4009f536bd01685ac40f193382db6bf    0.004907
# 0xaf2d1770d56bbff3511de38d8d46563535771d0bacc368019b0f4cb0ced09329    0.004907
# 0xcea1652e870fdd411c4a032a4c6357f4436c4e20a53095795013db0c09a2b90d    0.004907
# 0x062a7eb4b937dedeaaf052b483aad1709f893ff08fb6fa846b7e2bbf402d9c9b    0.004907
# 0x6ef5523d2706e7fce4240f88c99e52d857002405225b154d08a6f32cf3033d28    0.004907
#                                                                         ...
# 0x2b2abe3fcd305ba146c2e9649e220d07fc8d072da0f73839c0450aefe9af5126    0.000164
# 0x0a35f6ef1a9d96b5ee256e347e68c2e56546393e020f9b7de15dc68e8de921e3    0.000224
# 0xe9bbf8f437e3ded657c5fa023330f4a4dadbb2774414ae0d1e072a5c74d1bf3b    0.000187
# 0x6ddaba4ab985fa88ad834535acdc18582032e823720587b78802da5874e30d23    0.067051
# 0x5c89f0a3c1ba1b723fcbd1953525b7c978e49888155d3228678f6c5f788d9b9c    0.000926
# Name: CurrentValue @ $0/Eth, Length: 273, dtype: float64

# %%
scan_avalanche['CurrentValue @ $0/Eth']
# Out:
# 0x24cd4afbf8c0f52567f806d859206d33c97c4b81b50ae00e21c76affcb63c630    0.000567
# 0xae9ef4c03408ab4742a86b69b73f8b9225b47d0bbf66a13e6d724abe1afd8e28    0.000557
# 0x7351c744c9f0d47d6e1945806201cb3eb7e60c297982104ba9275524ed0cf5bf    0.000567
# 0xbb2a1f3da4431525e4bee332f17119618b74280fdecdc2e2825f5939eb80a123    0.000567
# 0x13d420d5c6dea926ea7dae0d9c5510404284744de64542e3c739d66feab549e1    0.000567
#                                                                         ...
# 0x9c4e13cebac0173af1fb14d27d6ce745466874a663644cd5990530027ecc0914    0.001024
# 0x3ed97ca96389cd196b8686f0295abed76389f1ce44310018e1cff51b19fd68dd    0.001080
# 0xd2e1d4a6098c80dbe734efac34131416576c3f4f111303db37703cdb6b96600e    0.004295
# 0xd4b7da15eaacca89fc10d666ac04aa8554b1faf5748d46fd0bc7c910568ef8bb    0.078207
# 0x28d0e0d45fd15719a80219c07bc913f776edd7430cd58abe61276dab0f89f37e    0.001080
# Name: CurrentValue @ $0/Eth, Length: 83, dtype: float64

# %% [markdown]
# # Procesamos los datos

# %% [markdown]
# <section id="modificacion-wei">
#   <h2>Modificación de la columna Coste en wei</h2>
#
# </section>

# %% [markdown]
# Creamos una lista llamada formatted_transactions que contiene los hashes de las operaciones que hemos realizado. Estos hashes se obtienen de los datasets de datos que se encuentran dentro de datasets_resumen

# %%
# Crear una lista con todas las transacciones formateadas como cadenas
formatted_transactions = []
for dataset in datasets_resumen.values():
    transacciones = [valor for valor in dataset['Transacción']]
    formatted_transactions += [str(valor)[:-1] for valor in transacciones]

# %%
len(formatted_transactions)
# Out:
# 84

# %% [markdown]
# Creamos un nuevo dataframe llamado df que contiene los hashes de las transacciones que coinciden con las de formatted_transactions y guardamos el valor de CurrentValue @ $0/Eth que indica el coste de la transacción. A su vez también se crea una nueva columna llamada index_col que guarda la dirección del hash

# %%
import pandas as pd

# Crear un DataFrame vacío para almacenar los DataFrames filtrados concatenados
df = pd.DataFrame()

# Iterar sobre las direcciones
for direccion in formatted_transactions:
    # Buscar en los datasets que empiezan con 'scan_' y contienen la dirección actual
    dataframes_direccion = [datasets_scan[k][datasets_scan[k]['index_col'] == direccion][['index_col', 'CurrentValue @ $0/Eth']] for k in datasets_scan.keys() if k.startswith('scan_')]

    # Concatenar los DataFrames filtrados en un solo DataFrame
    df = pd.concat([df] + dataframes_direccion)

# Imprimir información sobre el DataFrame concatenado resultante
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36 entries, 0x147a75b85c2cf9547c52f394c59b579482c65b7bcdd8f14d6c697ef4fb8f78fc to 0x908e71c7a11a9f80dce737c474cf1ce7e6ebea2431303d0052497a2250e5d53d
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   index_col              36 non-null     object
#  1   CurrentValue @ $0/Eth  36 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 864.0+ bytes
# None

# %% [markdown]
# Vemos la longitud del dataframe df. En este caso deberia de ser 12 * el numero de etherscan que se hayan cargado

# %%
# Imprimir la longitud del DataFrame
print(len(df))
# Out:
# 36

# %% [markdown]
# A continuación, vemos que valores de la columna index_col de df coinciden con la columna Transacción de los datasets de datos. Los que coincidan se sustituirá el valor de Coste en wei por el de CurrentValue @ $0/Eth que es el correcto

# %%
# Iterar sobre los DataFrames en el diccionario `datasets_resumen`
for k, df_resumen in datasets_resumen.items():
    # Iterar sobre las transacciones en el DataFrame `df`
    for index, row in df.iterrows():
        # Obtener la dirección de la transacción actual
        direccion = row['index_col']
        # Añadimos : para que sea igual a las transacciones de los datos
        direccion = row['index_col'] + ":"

        # Obtener el valor de la transacción actual
        valor = row['CurrentValue @ $0/Eth']
        # Buscar si la dirección de la transacción actual coincide con la columna "Transacción" del DataFrame del diccionario `datasets_resumen`
        mask = df_resumen['Transacción'] == direccion
        # Si hay una coincidencia, establecer el valor de "Coste en wei" en el valor de la transacción actual
        if mask.any():
            df_resumen.loc[mask, 'Coste en wei'] = valor

# %% [markdown]
# <section id="columnas-tiempo">
#   <h2>Añadir columna Diferencia de tiempos, Duración y Coste Total</h2>
#
# </section>

# %% [markdown]
# #### Crear una lista con los nombres de los datasets

# %%
import os

# Obtener la lista de carpetas en la carpeta datos/secuencial/
carpetas = [f for f in os.listdir('datos/paralelo/') if os.path.isdir(os.path.join('datos/paralelo/', f))]

# Crear una lista para almacenar los nombres de los datasets
datasets = []

# Lista de archivos a excluir
archivos_excluidos = ['avalanche', 'celo']
# Leer cada archivo CSV en cada carpeta y agregarlo a la lista datasets si termina en "_datos.csv"
for carpeta in carpetas:
    csv_files = [f for f in os.listdir(os.path.join('datos/paralelo/', carpeta)) if f.endswith('_paralelodatos1.csv') and os.path.splitext(f)[0] and not any(x in f for x in archivos_excluidos)]
    for f in csv_files:
        datasets.append(os.path.splitext(f)[0])

# Imprimir los nombres de los datasets creados
print("Los siguientes datasets se han creado:")
for dataset in datasets:
    print(dataset)
# Out:
# Los siguientes datasets se han creado:
# sepolia_bear_paralelodatos1
# sepolia_paralelodatos1
# polygon_bear_paralelodatos1
# optimism_bear_paralelodatos1
# boba_paralelodatos1
# arbitrum_bear_paralelodatos1
# arbitrum_paralelodatos1

# %% [markdown]
# ### Diferencia de tiempos, Duración y Coste Total

# %% [markdown]
# Diferencia de tiempos: Es el tiempo que ha tardado en procesarse una transacción
#
# Duración: Es la suma de las transacciones anteriores para ver como va aumentando el tiempo con la suma de transacciones
#
# Coste total: Es la suma de las transacciones anteriores para ver como va aumentando el ether con la suma de transacciones

# %%
# Iterar sobre la lista de nombres de datasets
for dataset in datasets:
    # Convertir la columna "Tiempo" a tipo datetime
    globals()[dataset]["Tiempo"] = pd.to_datetime(globals()[dataset]["Tiempo"])

    # Calcular la diferencia de tiempo entre cada fila y la anterior, en segundos
    globals()[dataset]["Diferencia de tiempo"] = (globals()[dataset]["Tiempo"] - globals()[dataset]["Tiempo"].shift(1)).dt.total_seconds()

    # Inicializar el primer valor de la columna "Duración" con el valor de la primera fila de la columna "Diferencia de tiempo"
    globals()[dataset].loc[0, "Duración"] = globals()[dataset].loc[0, "Diferencia de tiempo"]

    # Sumar el primer valor de la columna "Duración" al resto de los valores en la columna "Duración"
    globals()[dataset]["Duración"] = globals()[dataset]["Duración"] + globals()[dataset].loc[0, "Duración"]

    # Sumar la columna "Diferencia de tiempo" al resto de los valores en la columna "Duración"
    globals()[dataset]["Duración"] = globals()[dataset]["Diferencia de tiempo"].cumsum().fillna(method='ffill')

    # Calcular la media de la columna "Diferencia de tiempo"
    media_diferencia_tiempo = globals()[dataset]["Diferencia de tiempo"].mean()

    # Reemplazar los valores NaN con la media de las otras filas
    globals()[dataset]["Diferencia de tiempo"].fillna(media_diferencia_tiempo, inplace=True)
    # Reemplazar los valores NaN con la media de las otras filas
    globals()[dataset]["Duración"].fillna(globals()[dataset]["Diferencia de tiempo"][0], inplace=True)
    
    # Crear una columna llamada "Coste total" que sea la suma de la columna "Coste en wei"
    globals()[dataset]["Coste total"] = globals()[dataset]["Coste en wei"].cumsum()


# Iterar sobre la lista de nombres de datasets, pero saltarse la primera iteración
for dataset in datasets:
    globals()[dataset]["Duración"] =  globals()[dataset]["Duración"] +  globals()[dataset]["Duración"][0]

# Iterar sobre la lista de nombres de datasets
for dataset in datasets:
    # Modificar el valor de Duración de la primera fila en el DataFrame original
    globals()[dataset].loc[0, "Duración"] = globals()[dataset]["Diferencia de tiempo"][0]

# %% [markdown]
# <section id="conversion-hex-dec">
#   <h2>Conversión de hexadecimal a decimal Gas utilizado</h2>
#
# </section>

# %% [markdown]
# Hacemos una conversión de hexadecimal a decimal de la columna de Gas Utilizado

# %%
#Gas utilizado 
import pandas as pd

def hex_to_dec(datos):
    # Convierte la columna "Gas utilizado" de hexadecimal a decimal
    datos["Gas utilizado"] = datos["Gas utilizado"].apply(lambda x: int(x, 16))
    
    # Devuelve el DataFrame modificado
    return datos


# Iterar sobre la lista de nombres de datasets
for dataset in datasets:
    # Aplicar la función a la columna "Gas utilizado" del DataFrame
    globals()[dataset] = hex_to_dec(globals()[dataset])
    
    # Imprimir el DataFrame resultante
    print(globals()[dataset].head())
# Out:
#                                          Transacción  Estado  Gas utilizado  \
# 0  0x08c730b44b5ba6bc4ff1d5ff0a979bf140ab3b90bf01...    True          69484
# 1  0x94a8323c4edf758ee5a92ef24773209843129ae0fa2e...    True          69484
# 2  0x2593ff761d26c7777fffed51c140cb4dab0fbd85ecf8...    True          52384
# 3  0xc5a58f6aef579c07331cfb3546e1b07569892a82fd3a...    True          69472
# 4  0x88e95411fc55bde9539b84bdee532ee09e6cbb30c086...    True          52384
#
#    Coste en wei   Bloque              Tiempo  Diferencia de tiempo  Duración  \
# 0      0.000069  3318750 2023-05-12 12:34:42                   1.0       1.0
# 1      0.000069  3318751 2023-05-12 12:34:43                   1.0       2.0
# 2      0.000052  3318752 2023-05-12 12:34:44                   1.0       3.0
# 3      0.000069  3318753 2023-05-12 12:34:45                   1.0       4.0
# 4      0.000052  3318754 2023-05-12 12:34:46                   1.0       5.0
#
#    Coste total
# 0     0.000069
# 1     0.000139
# 2     0.000191
# 3     0.000261
# 4     0.000313
#                                          Transacción  Estado  Gas utilizado  \
# 0  0x147a75b85c2cf9547c52f394c59b579482c65b7bcdd8...    True          69484
# 1  0x6a1de4587245844ba1b507d115c6d043ac52c4fc1b7c...    True          52384
# 2  0x3b88b7d998c4106ecd5e61e55757773f0ba4587d61f6...    True          52384
# 3  0x5dccd7fc47553e271758fb47b1bad0c0e64788338c31...    True          52384
# 4  0x574d10d73267dfdb896fc0288a9be2a77acf317b68bb...    True          52384
#
#    Coste en wei   Bloque              Tiempo  Diferencia de tiempo  Duración  \
# 0      0.002085  3333098 2023-05-12 08:02:24                   0.0       0.0
# 1      0.001572  3333098 2023-05-12 08:02:24                   0.0       0.0
# 2      0.001572  3333098 2023-05-12 08:02:24                   0.0       0.0
# 3      0.001572  3333098 2023-05-12 08:02:24                   0.0       0.0
# 4      0.001572  3333098 2023-05-12 08:02:24                   0.0       0.0
#
#    Coste total
# 0     0.002085
# 1     0.003656
# 2     0.005228
# 3     0.006799
# 4     0.008371
#                                          Transacción  Estado  Gas utilizado  \
# 0  0xd7fb8efc46c40437de8061eb5a4b95e4233e8f7b3dca...    True          69484
# 1  0xc80feeb1dcb5b33f6c8a657e23dfa39b5094e3b7373a...    True          52384
# 2  0xcc54e685db95c61d2614eb4ff2dbc109ee409e4a3fa2...    True          69472
# 3  0x20965e4f4515572eafeb26585e67fae1481d509b4170...    True          52384
# 4  0x6ca2abec22e6e83eab716544d7c9c712fa40d8a1cac5...    True          69484
#
#    Coste en wei    Bloque              Tiempo  Diferencia de tiempo  Duración  \
# 0      0.000235  41666854 2023-05-12 02:38:06                   1.0       1.0
# 1      0.000177  41666855 2023-05-12 02:38:07                   1.0       2.0
# 2      0.000215  41666856 2023-05-12 02:38:08                   1.0       3.0
# 3      0.000148  41666857 2023-05-12 02:38:09                   1.0       4.0
# 4      0.000181  41666858 2023-05-12 02:38:10                   1.0       5.0
#
#    Coste total
# 0     0.000235
# 1     0.000413
# 2     0.000627
# 3     0.000775
# 4     0.000956
#                                          Transacción  Estado  Gas utilizado  \
# 0  0xec64d612a36f517786d8d386ea2a1991effc34792010...    True          69484
# 1  0xef131b78081c8a5f04b3f53c589a701ffdf55a6a2fca...    True          69472
# 2  0x8ab1fa92f0a0290fa7656124d99982f664422c62421b...    True          69484
# 3  0xb81c678d7d4ad3cf840eb4d4667d9d330c29bed811d0...    True          52384
# 4  0x2924cededceef76366be35dd1bd5a92fc71f841c0c25...    True          52384
#
#    Coste en wei    Bloque              Tiempo  Diferencia de tiempo  Duración  \
# 0      0.000070  91823109 2023-05-12 01:12:38                   1.0       1.0
# 1      0.000070  91823110 2023-05-12 01:12:39                   1.0       2.0
# 2      0.000070  91823111 2023-05-12 01:12:40                   1.0       3.0
# 3      0.000053  91823112 2023-05-12 01:12:41                   1.0       4.0
# 4      0.000053  91823113 2023-05-12 01:12:42                   1.0       5.0
#
#    Coste total
# 0     0.000070
# 1     0.000141
# 2     0.000211
# 3     0.000264
# 4     0.000316
#                                          Transacción  Estado  Gas utilizado  \
# 0  0x9cfedb3f1ea2616385a3bf78ee637758179b362143b3...    True          58999
# 1  0xe2af2d58189425e2ec70cd746841a1d6fba31c9fb179...    True          76099
# 2  0xe68724db3153bb0a4d9fda7c9c152d814f7329798f05...    True          76099
# 3  0xa4ef98e04b9c38db4822b1ccb3b10e253c68c7351ed7...    True          76069
# 4  0xad9a3cc6e20804c240036b72c88f7d60c1876f8602e0...    True          58999
#
#    Coste en wei  Bloque              Tiempo  Diferencia de tiempo  Duración  \
# 0      0.000059    9246 2023-05-12 03:06:00              0.454545  0.454545
# 1      0.000076    9247 2023-05-12 03:06:00              0.000000  0.454545
# 2      0.000076    9248 2023-05-12 03:06:00              0.000000  0.454545
# 3      0.000076    9249 2023-05-12 03:06:00              0.000000  0.454545
# 4      0.000059    9250 2023-05-12 03:06:00              0.000000  0.454545
#
#    Coste total
# 0     0.000059
# 1     0.000135
# 2     0.000211
# 3     0.000287
# 4     0.000346
#                                          Transacción  Estado  Gas utilizado  \
# 0  0x5559358454b1255d9404335f7020016d6903cb013c8c...    True          69484
# 1  0xc900cec1573cab343e127f05bb3ad6bda2b75b5b8fdb...    True          52384
# 2  0x83170e0fbe7834d7cf5a39d6eecdab69c7789c6a7c82...    True          69472
# 3  0xd92138b44df7d746e6b4418d76fcff5146e6a995925a...    True          52384
# 4  0x1a16e05cf7d97ede34de7e652e02d48637fb25caa746...    True          52384
#
#    Coste en wei    Bloque              Tiempo  Diferencia de tiempo  Duración  \
# 0      0.000070  81696848 2023-05-12 02:23:44                   1.0       1.0
# 1      0.000052  81696849 2023-05-12 02:23:45                   1.0       2.0
# 2      0.000070  81696850 2023-05-12 02:23:46                   1.0       3.0
# 3      0.000052  81696851 2023-05-12 02:23:47                   1.0       4.0
# 4      0.000052  81696852 2023-05-12 02:23:48                   1.0       5.0
#
#    Coste total
# 0     0.000070
# 1     0.000122
# 2     0.000192
# 3     0.000244
# 4     0.000296
#                                          Transacción  Estado  Gas utilizado  \
# 0  0x9d0573fdea524eb2bd38f30de88c4fc31a040497aa77...    True          52384
# 1  0x83ffa7606541df62cbbed9974cd6d861f1018ff0f9d3...    True          52384
# 2  0x9c226beba2280a0272437963d6e857015834c1a92464...    True          52384
# 3  0xcf7849ad011c1a0d0eba758d239ec34106dae2dc0d85...    True          52384
# 4  0xe384ad6547197efac720ed7cdf5b1f08bbab51705fc0...    True          69484
#
#    Coste en wei    Bloque              Tiempo  Diferencia de tiempo  Duración  \
# 0      0.000052  16948685 2023-05-12 02:44:03              0.545455  0.545455
# 1      0.000052  16948687 2023-05-12 02:44:03              0.000000  0.545455
# 2      0.000052  16948689 2023-05-12 02:44:04              1.000000  1.545455
# 3      0.000052  16948690 2023-05-12 02:44:04              0.000000  1.545455
# 4      0.000069  16948691 2023-05-12 02:44:05              1.000000  2.545455
#
#    Coste total
# 0     0.000052
# 1     0.000105
# 2     0.000157
# 3     0.000210
# 4     0.000279

# %%
sepolia_paralelodatos1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Transacción           12 non-null     object
#  1   Estado                12 non-null     bool
#  2   Gas utilizado         12 non-null     int64
#  3   Coste en wei          12 non-null     float64
#  4   Bloque                12 non-null     int64
#  5   Tiempo                12 non-null     datetime64[ns]
#  6   Diferencia de tiempo  12 non-null     float64
#  7   Duración              12 non-null     float64
#  8   Coste total           12 non-null     float64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(2), object(1)
# memory usage: 908.0+ bytes

# %% [markdown]
# # Representación

# %% [markdown]
# Observamos que todos los datos presentan la misma cantidad de elementos, lo que nos permite garantizar que las comparaciones efectuadas sean precisas y correctas.

# %%
for key, dataset_values in datasets_resumen.items():
    print(f"Longitud de la columna 'Coste en wei' en el DataFrame {key}: {len(dataset_values['Coste en wei'])}")
# Out:
# Longitud de la columna 'Coste en wei' en el DataFrame sepolia_bear: 12
# Longitud de la columna 'Coste en wei' en el DataFrame sepolia: 12
# Longitud de la columna 'Coste en wei' en el DataFrame polygon_bear: 12
# Longitud de la columna 'Coste en wei' en el DataFrame optimism_bear: 12
# Longitud de la columna 'Coste en wei' en el DataFrame boba: 12
# Longitud de la columna 'Coste en wei' en el DataFrame arbitrum_bear: 12
# Longitud de la columna 'Coste en wei' en el DataFrame arbitrum: 12

# %% [markdown]
# <section id="representacion-conjunto">
#   <h2>Representación de Coste de Wei en Conjunto</h2>
#
# </section>

# %% [markdown]
# Se representa en conjunto cual ha sido su coste en ether y como ha ido subiendo o bajando con el tiempo dependiendo de que función se estaba ejecutando o en que momento.

# %%
import matplotlib.pyplot as plt
import numpy as np

max_len = max([len(dataset_values['Coste en wei']) for dataset_values in datasets_resumen.values()])
labels = [f"{i}" for i in range(1, max_len+1)]
x = np.arange(len(labels))
width = 0.45

# Crear el gráfico con figsize
fig, ax = plt.subplots(figsize=(12, 6))

# Iterar sobre el diccionario de datasets y agregar los datos al gráfico
for i, (dataset_name, dataset_values) in enumerate(datasets_resumen.items()):
    dataset_len = len(dataset_values['Coste en wei'])
    ax.bar(x[:dataset_len] + ((-1)**i) * width/2, dataset_values['Coste en wei'], width, label=f'{dataset_name}')

# Configurar las etiquetas y leyendas del gráfico
ax.set_ylabel('Coste en wei')
ax.set_xlabel('Numero de transaccion')
ax.set_xticks(x)
ax.set_xticklabels(labels[:max_len])
ax.legend()
fig.suptitle("Comparativa coste en wei de Comprar entradas")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# <section id="representacion-individual">
#   <h2>Representación de Coste de Wei Individualizado</h2>
#
# </section>

# %% [markdown]
# Vamos a observar de forma individualizada cual ha sido su coste en ether y como ha ido subiendo o bajando con el tiempo dependiendo de que función se estaba ejecutando o en que momento.

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_comparativa_compra(dataset_name, dataset):
    # Configuración del gráfico
    labels = [f"{i}" for i in range(1, len(dataset['Coste en wei'])+1)]
    x = np.arange(len(labels))
    width = 0.45

    # Crear el gráfico con figsize
    fig, ax = plt.subplots(figsize=(12, 6))

    # Agregar los datos al gráfico
    ax.bar(x, dataset['Coste en wei'], width)

    # Configurar las etiquetas y leyendas del gráfico
    ax.set_ylabel('Coste en wei')
    ax.set_xlabel('Numero de transaccion')
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    fig.suptitle(f"Coste en wei de Comprar entradas - {dataset_name}")

    # Mostrar el gráfico
    plt.show()

# Generar la gráfica para cada dataset
for dataset_name, dataset_values in datasets_resumen.items():
    plot_comparativa_compra(dataset_name, dataset_values)

# %% [markdown]
# <section id="representacion-tiempo">
#   <h2>Representación de coste en wei y tiempo que tarda en cada transacción</h2>
#
# </section>

# %% [markdown]
# Se va a observar el tiempo que tarda cada transacción de forma individual en completarse y el coste que ha tendo dicha transacción.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Configuración del gráfico
size = 50
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']
max_len = max([len(dataset_values['Coste en wei']) for dataset_values in datasets_resumen.values()])
for dataset_values in datasets_resumen.values():
    dataset_values['Coste en wei'] = np.pad(dataset_values['Coste en wei'], (0, max_len - len(dataset_values['Coste en wei'])), mode='constant')
labels = [f"{i}" for i in range(1, max_len+1)]
x = np.arange(len(labels))
width = 0.45

# Crear el gráfico con figsize
fig, ax = plt.subplots(figsize=(12, 6))

# Iterar sobre el diccionario de datasets y agregar los datos al gráfico de dispersión
for i, (dataset_name, dataset_values) in enumerate(datasets_resumen.items()):
    ax.scatter(dataset_values['Coste en wei'], dataset_values['Diferencia de tiempo'], s=size, c=colors[i%len(colors)], alpha=0.5, label=f'{dataset_name}')
    
    # Agregar el número de puntos en cada posición
    points_dict = {}
    for j in range(len(dataset_values['Coste en wei'])):
        point = (dataset_values['Coste en wei'][j], dataset_values['Diferencia de tiempo'][j])
        if point in points_dict:
            points_dict[point] += 1
        else:
            points_dict[point] = 1
    for point, count in points_dict.items():
        if count > 1:
            ax.annotate(f"{count}", xy=point, xytext=(10, 10), textcoords='offset points', fontsize=8, color='white')

# Configurar las etiquetas y leyendas del gráfico
ax.set_xlabel('Coste en wei')
ax.set_ylabel('Diferencia de tiempo (s)')
ax.legend()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Vemos de forma numérica la cantidad de transaccione que han coincidido en coste y tiempo para poder hacernos una idea del tiempo que tardaría y el coste que supondría cada transacción de media

# %%
# Agregar columna 'Fuente' a cada DataFrame
for dataset_name, dataset_values in datasets_resumen.items():
    dataset_values['Fuente'] = dataset_name

# %%
# Crear una lista vacía para almacenar los DataFrames
dataframes = []

# Recorrer el diccionario y agregar cada DataFrame a la lista
for dataset_name, dataset_values in datasets_resumen.items():
    dataset_values['Fuente'] = dataset_name
    dataframes.append(dataset_values)

# Concatenar los DataFrames en la lista
datos = pd.concat(dataframes, axis=0, ignore_index=True)

# Contar el número de puntos con las mismas coordenadas y fuente
conteo = datos.groupby(['Diferencia de tiempo', 'Coste en wei', 'Fuente']).size().reset_index(name='coincidencia')

# Ordenar los resultados por la columna 'coincidencia' de mayor a menor
conteo = conteo.sort_values(by=['coincidencia'], ascending=False)

# Crear una columna que indique la fuente de cada punto
for dataset_name in datasets_resumen:
    conteo['Fuente'] = conteo['Fuente'].apply(lambda x: dataset_name if x == dataset_name else x)

# Mostrar los resultados
display(conteo)
# Out:
#     Diferencia de tiempo  Coste en wei         Fuente  coincidencia
# 5               0.000000      0.001572        sepolia             9
# 11              1.000000      0.000052   sepolia_bear             9
# 1               0.000000      0.000059           boba             7
# 0               0.000000      0.000052       arbitrum             4
# 10              1.000000      0.000052       arbitrum             4
# 19              1.000000      0.000053  optimism_bear             3
# 12              1.000000      0.000052  arbitrum_bear             3
# 35              1.000000      0.000096   polygon_bear             3
# 28              1.000000      0.000069   sepolia_bear             2
# 22              1.000000      0.000053  optimism_bear             2
# 7               0.000000      0.002085        sepolia             2
# 4               0.000000      0.000076           boba             2
# 32              1.000000      0.000070  optimism_bear             1
# 31              1.000000      0.000070  arbitrum_bear             1
# 33              1.000000      0.000070  optimism_bear             1
# 30              1.000000      0.000070  arbitrum_bear             1
# 34              1.000000      0.000070  optimism_bear             1
# 39              1.000000      0.000126   polygon_bear             1
# 36              1.000000      0.000102   polygon_bear             1
# 37              1.000000      0.000109   polygon_bear             1
# 38              1.000000      0.000117   polygon_bear             1
# 40              1.000000      0.000148   polygon_bear             1
# 41              1.000000      0.000177   polygon_bear             1
# 42              1.000000      0.000181   polygon_bear             1
# 43              1.000000      0.000215   polygon_bear             1
# 44              1.000000      0.000235   polygon_bear             1
# 29              1.000000      0.000070  arbitrum_bear             1
# 23              1.000000      0.000053  optimism_bear             1
# 27              1.000000      0.000069       arbitrum             1
# 26              1.000000      0.000069   sepolia_bear             1
# 2               0.000000      0.000069       arbitrum             1
# 3               0.000000      0.000076           boba             1
# 6               0.000000      0.002084        sepolia             1
# 8               0.454545      0.000059           boba             1
# 9               0.545455      0.000052       arbitrum             1
# 13              1.000000      0.000052  arbitrum_bear             1
# 14              1.000000      0.000052  arbitrum_bear             1
# 15              1.000000      0.000052  arbitrum_bear             1
# 16              1.000000      0.000052  arbitrum_bear             1
# 17              1.000000      0.000052  arbitrum_bear             1
# 18              1.000000      0.000052  arbitrum_bear             1
# 20              1.000000      0.000053  optimism_bear             1
# 21              1.000000      0.000053  optimism_bear             1
# 24              1.000000      0.000053  optimism_bear             1
# 25              1.000000      0.000069       arbitrum             1
# 45              5.000000      0.000059           boba             1

# %% [markdown]
# <section id="representacion-gas">
#   <h2>Representación del gas y su equivalencia en Coste en wei</h2>
#
# </section>

# %% [markdown]
# Se observa en esta ocasión el gas que se ha necesitado para procesar cada transacción y su traducción a ether

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Ajustar el tamaño de la figura
fig, axs = plt.subplots(len(datasets_resumen), 2, figsize=(12, 6*len(datasets_resumen)), sharex=True)
fig.subplots_adjust(hspace=0.5)

# Crear el gráfico de barras para cada conjunto de datos en datasets_resumen
for i, (dataset_name, dataset_values) in enumerate(datasets_resumen.items()):
    axs[i, 0].bar(dataset_values.index, dataset_values["Gas utilizado"], label="Gas utilizado")
    axs[i, 0].legend()
    axs[i, 0].set_title("Gas utilizado")

    axs[i, 1].bar(dataset_values.index, dataset_values["Coste en wei"], label="Coste en wei")
    axs[i, 1].legend()
    axs[i, 1].set_title("Coste en wei")
    axs[i, 1].set_xticks(dataset_values.index)
    axs[i, 1].set_xticklabels(dataset_values.index)

    # Añadir título a cada conjunto de gráficas
    axs[i, 0].set_title(f"Datos de {dataset_name}")

# Mostrar el gráfico
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_comparativa_compra(dataset_name, dataset):
    # Configuración del gráfico
    labels = [f"{i}" for i in range(1, len(dataset['Coste en wei'])+1)]
    x = np.arange(len(labels))
    width = 0.45

    # Crear el gráfico con figsize
    fig, axs = plt.subplots(2, 1, sharex=True, figsize=(12, 6))
    fig.subplots_adjust(hspace=0.5)

    # Gráfico para Coste en wei
    axs[0].bar(x, dataset['Coste en wei'], width)
    axs[0].set_ylabel('Coste en wei')
    axs[0].set_xticks(x)
    axs[0].set_xticklabels(labels)
    axs[0].set_title(f"Coste en wei - {dataset_name}")

    # Gráfico para Gas utilizado
    axs[1].bar(x, dataset['Gas utilizado'], width)
    axs[1].set_ylabel('Gas utilizado')
    axs[1].set_xticks(x)
    axs[1].set_xticklabels(labels)
    axs[1].set_title(f"Gas utilizado - {dataset_name}")

    # Mostrar el gráfico
    plt.show()

# Generar la gráfica para cada dataset
for dataset_name, dataset_values in datasets_resumen.items():
    plot_comparativa_compra(dataset_name, dataset_values)

# %% [markdown]
# <section id="dispersion-individual">
#   <h2>Representación de dispersión para comparar el Gas utilizado y el Coste en wei por Bloque Individualizado</h2>
#
# </section>

# %% [markdown]
# En esta representación veremos mediante un diagrama de dispersión como ha sido el gas utilizado y su respectivo coste en ether.

# %% [markdown]
# ### Forma individual

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_scatter(dataset_name, dataset):
    # Configuración del gráfico
    x = dataset['Coste en wei']
    y = dataset['Gas utilizado']
    size = 50
    colors = 'b'

    # Crear el gráfico de dispersión
    fig, ax = plt.subplots()
    ax.scatter(x, y, s=size, c=colors, alpha=0.5, label=dataset_name)

    # Configurar las etiquetas y leyendas del gráfico
    ax.set_xlabel('Coste en wei')
    ax.set_ylabel('Gas utilizado')
    ax.legend()

    # Añadir título al gráfico
    plt.title(f"Diagrama de dispersión: Gas utilizado vs Coste en wei - {dataset_name}")

    # Mostrar el gráfico
    plt.show()

# Generar la gráfica de dispersión para cada dataset
for dataset_name, dataset_values in datasets_resumen.items():
    plot_scatter(dataset_name, dataset_values)

# %% [markdown]
# <section id="dispersion-conjunto">
#   <h2>Representación de dispersión para comparar el Gas utilizado y el Coste en wei por Bloque en Conjunto</h2>
#
# </section>

# %% [markdown]
# En esta representación veremos mediante un diagrama de dispersión como ha sido el gas utilizado y su respectivo coste en ether.

# %%
# Conjunto

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


# Configuración del gráfico
fig, ax = plt.subplots()
for i, (dataset_name, dataset_values) in enumerate(datasets_resumen.items()):
    x = dataset_values['Coste en wei']
    y = dataset_values['Gas utilizado']
    size = 50

    # Crear el gráfico de dispersión
    ax.scatter(x, y, s=size,  alpha=0.5, label=dataset_name)

# Configurar las etiquetas y leyendas del gráfico
ax.set_xlabel('Coste en wei')
ax.set_ylabel('Gas utilizado')
ax.legend(title='Datasets', bbox_to_anchor=(1.05, 1), loc='upper left')

# Añadir título al gráfico
plt.title("Diagrama de dispersión: Gas utilizado vs Coste en wei")

# Mostrar el gráfico
plt.show()

# %%
# Crear una lista vacía para almacenar los DataFrames
dataframes = []

# Recorrer el diccionario y agregar cada DataFrame a la lista
for dataset_name, dataset_values in datasets_resumen.items():
    dataset_values['Fuente'] = dataset_name
    dataframes.append(dataset_values)

# Concatenar los DataFrames en la lista
datos = pd.concat(dataframes, axis=0, ignore_index=True)

# Contar el número de puntos con las mismas coordenadas y fuente
conteo = datos.groupby(['Diferencia de tiempo', 'Coste en wei', 'Fuente']).size().reset_index(name='coincidencia')

# Ordenar los resultados por la columna 'coincidencia' de mayor a menor
conteo = conteo.sort_values(by=['coincidencia'], ascending=False)

# Crear una columna que indique la fuente de cada punto
for dataset_name in datasets_resumen:
    conteo['Fuente'] = conteo['Fuente'].apply(lambda x: dataset_name if x == dataset_name else x)

# Mostrar los resultados
display(conteo)
# Out:
#     Diferencia de tiempo  Coste en wei         Fuente  coincidencia
# 5               0.000000      0.001572        sepolia             9
# 11              1.000000      0.000052   sepolia_bear             9
# 1               0.000000      0.000059           boba             7
# 0               0.000000      0.000052       arbitrum             4
# 10              1.000000      0.000052       arbitrum             4
# 19              1.000000      0.000053  optimism_bear             3
# 12              1.000000      0.000052  arbitrum_bear             3
# 35              1.000000      0.000096   polygon_bear             3
# 28              1.000000      0.000069   sepolia_bear             2
# 22              1.000000      0.000053  optimism_bear             2
# 7               0.000000      0.002085        sepolia             2
# 4               0.000000      0.000076           boba             2
# 32              1.000000      0.000070  optimism_bear             1
# 31              1.000000      0.000070  arbitrum_bear             1
# 33              1.000000      0.000070  optimism_bear             1
# 30              1.000000      0.000070  arbitrum_bear             1
# 34              1.000000      0.000070  optimism_bear             1
# 39              1.000000      0.000126   polygon_bear             1
# 36              1.000000      0.000102   polygon_bear             1
# 37              1.000000      0.000109   polygon_bear             1
# 38              1.000000      0.000117   polygon_bear             1
# 40              1.000000      0.000148   polygon_bear             1
# 41              1.000000      0.000177   polygon_bear             1
# 42              1.000000      0.000181   polygon_bear             1
# 43              1.000000      0.000215   polygon_bear             1
# 44              1.000000      0.000235   polygon_bear             1
# 29              1.000000      0.000070  arbitrum_bear             1
# 23              1.000000      0.000053  optimism_bear             1
# 27              1.000000      0.000069       arbitrum             1
# 26              1.000000      0.000069   sepolia_bear             1
# 2               0.000000      0.000069       arbitrum             1
# 3               0.000000      0.000076           boba             1
# 6               0.000000      0.002084        sepolia             1
# 8               0.454545      0.000059           boba             1
# 9               0.545455      0.000052       arbitrum             1
# 13              1.000000      0.000052  arbitrum_bear             1
# 14              1.000000      0.000052  arbitrum_bear             1
# 15              1.000000      0.000052  arbitrum_bear             1
# 16              1.000000      0.000052  arbitrum_bear             1
# 17              1.000000      0.000052  arbitrum_bear             1
# 18              1.000000      0.000052  arbitrum_bear             1
# 20              1.000000      0.000053  optimism_bear             1
# 21              1.000000      0.000053  optimism_bear             1
# 24              1.000000      0.000053  optimism_bear             1
# 25              1.000000      0.000069       arbitrum             1
# 45              5.000000      0.000059           boba             1

# %% [markdown]
# ## BoxPlot

# %% [markdown]
# <section id="boxplot-gas">
#   <h2>Representación mediante BoxPlot del Gas utilizado</h2>
#
# </section>

# %% [markdown]
# El Boxplot nos permite visualizar la distribución de un conjunto de datos. El boxplot muestra la mediana (línea dentro de la caja), el rango intercuartil (la caja que va desde el primer cuartil al tercer cuartil), los valores mínimo y máximo (los bigotes), y los posibles valores atípicos o extremos (los puntos fuera de los bigotes)

# %% [markdown]
# <section id="boxplot-coste">
#   <h2>Representación mediante BoxPlot del Coste en wei</h2>
#
# </section>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Configuración del gráfico
data = []
labels = []
colors = []

for dataset_name, dataset_values in datasets_resumen.items():
    data.append(dataset_values['Gas utilizado'])
    labels.append(dataset_name)
    colors.append(np.random.rand(3,))

# Crear el gráfico
fig, ax = plt.subplots(figsize=(13, 6))

# Cambiar el color de cada boxplot y guardar las cajas en una lista
boxes = ax.boxplot(data, labels=labels, patch_artist=True, whiskerprops=dict(linestyle='-', linewidth=1.5))
for box, color in zip(boxes['boxes'], colors):
    box.set_facecolor(color)

# Obtener la mediana de cada set de datos y mostrarla en el gráfico
for i, median in enumerate(boxes['medians']):
    median_val = np.median(data[i])
    ax.text(i + 1, median_val, f"{median_val:.4f}", horizontalalignment='center', fontsize=10)

# Configurar las etiquetas y leyendas del gráfico
ax.set_ylabel('Gas utilizado')
ax.set_title('Boxplot de Gas utilizado por cada dataset')
plt.xticks(range(1, len(labels) + 1), labels)
ax.tick_params(axis='x', which='major', pad=15)

# Ajustar los límites del eje y
ymin, ymax = ax.get_ylim()
margin = (ymax - ymin) * 0.1
ax.set_ylim(ymin - margin, ymax + margin)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# <section id="boxplot-coste">
#   <h2>Representación mediante BoxPlot del Coste en wei</h2>
#
# </section>

# %% [markdown]
# Se va a observar una representación de coste en ether y a continuación se va a poder apreciar una lista con el valor de la mediana para cada box

# %%
import numpy as np
import matplotlib.pyplot as plt

data = []
labels = []
colors = []

for dataset_name, dataset_values in datasets_resumen.items():
    data.append(dataset_values['Coste en wei'])
    labels.append(dataset_name)
    colors.append(np.random.rand(3,))

# Crear el gráfico
fig, ax = plt.subplots(figsize=(13, 8))

# Cambiar el color de cada boxplot y guardar las cajas en una lista
boxes = ax.boxplot(data, labels=labels, patch_artist=True, whiskerprops=dict(linestyle='-', linewidth=1.5))
for box, color in zip(boxes['boxes'], colors):
    box.set(facecolor=color)

# Obtener la mediana de cada set de datos y mostrarla debajo de la grafica
medians = [np.median(d) for d in data]
median_labels = [f"{dataset_name}: {median:.9f}" for dataset_name, median in zip(labels, medians)]

# Agregar leyenda con rectángulos de colores
rects = [plt.Rectangle((0, 0), 1, 1, color=color) for color in colors]
ax.legend(rects, labels, loc='upper right')

# Configurar las etiquetas y leyendas del gráfico
ax.set_ylabel('Coste en wei')
ax.set_title('Boxplot de Coste en wei por cada dataset')
ax.tick_params(axis='x', which='major', pad=15)

# Ajustar los límites del eje y
ymin, ymax = ax.get_ylim()
margin = (ymax - ymin) * 0.1
ax.set_ylim(ymin - margin, ymax + margin)

# Mostrar el gráfico
plt.show()

# Mostrar texto con la mediana debajo de la gráfica
fig, ax = plt.subplots(figsize=(12, 1))
ax.axis('off')
ax.text(0, 0, '\n'.join(median_labels), ha='left', va='center', fontsize=12)
plt.show()

# %% [markdown]
# #  Dataset resumen

# %% [markdown]
# <section id="resumen">
#   <h2>Resumen</h2>
#
# </section>

# %% [markdown]
# Importamos los datastes de datos y creamos un diccionario llamado datasets_resumen2 que contiene los datos anteriormente importandos

# %%
import pandas as pd
import os

# Obtener la lista de carpetas en la carpeta datos/paralelo/
carpetas = [f for f in os.listdir('datos/paralelo/') if os.path.isdir(os.path.join('datos/paralelo/', f))]

# Crear un diccionario vacío para almacenar los DataFrames
datasets_resumen2 = {}

# Lista de archivos a excluir
archivos_excluidos = ['avalanche', 'celo']

# Leer cada archivo CSV en cada carpeta y asignarlo a una variable con el nombre de la carpeta
for carpeta in carpetas:
    csv_files = [f for f in os.listdir(os.path.join('datos/paralelo/', carpeta)) if f.endswith('_paralelo_resumen1.csv') and not any(x in f for x in archivos_excluidos)]
    for f in csv_files:
        name = os.path.splitext(f)[0]
        name_without_suffix = name.replace('_paralelo_resumen1', '')
        vars()[name] = pd.read_csv(os.path.join('datos/paralelo/', carpeta, f))
        datasets_resumen2[name_without_suffix] = eval(name)

# Imprimir los nombres de las variables creadas que contengan "_paralelodatos1"
print("Los siguientes DataFrames se han creado:")
for var in sorted(datasets_resumen2.keys()):
    print(var)
# Out:
# Los siguientes DataFrames se han creado:
# arbitrum
# arbitrum_bear
# boba
# optimism_bear
# polygon_bear
# sepolia
# sepolia_bear

# %% [markdown]
# ## Procesamos los datos

# %% [markdown]
# <section id="modificacion-coste-total">
#   <h2>Modificación de la columna Coste Total</h2>
#
# </section>

# %% [markdown]
# Se procede a modificar la columna de Coste Total, haciendo que sea el valor de la última posición de la columna coste total de los datasets que hemos estado representando hasta ahpra

# %%
datasets_resumen2
# Out:
# {'sepolia_bear':    Antes  Despues  Duración  Transacciones  Coste Total
#  0   1278    10634      9356             12      0.00068,
#  'sepolia':    Antes  Despues  Duración  Transacciones  Coste Total
#  0    312    13196     12884             12      0.00068,
#  'polygon_bear':    Antes  Despues  Duración  Transacciones  Coste Total
#  0   1283    10789      9506             12     0.001696,
#  'optimism_bear':    Antes  Despues  Duración  Transacciones  Coste Total
#  0   1054    10070      9016             12     0.000685,
#  'boba':    Antes  Despues  Duración  Transacciones  Coste Total
#  0    769     8458      7689             12     0.000759,
#  'arbitrum_bear':    Antes  Despues  Duración  Transacciones  Coste Total
#  0   1020     9982      8962             12      0.00068,
#  'arbitrum':    Antes  Despues  Duración  Transacciones  Coste Total
#  0    716     8948      8232             12     0.000068}

# %%
datasets_resumen
# Out:
# {'sepolia_bear':                                           Transacción  Estado  Gas utilizado  \
#  0   0x08c730b44b5ba6bc4ff1d5ff0a979bf140ab3b90bf01...    True          69484
#  1   0x94a8323c4edf758ee5a92ef24773209843129ae0fa2e...    True          69484
#  2   0x2593ff761d26c7777fffed51c140cb4dab0fbd85ecf8...    True          52384
#  3   0xc5a58f6aef579c07331cfb3546e1b07569892a82fd3a...    True          69472
#  4   0x88e95411fc55bde9539b84bdee532ee09e6cbb30c086...    True          52384
#  5   0xfb4b96250a48e97d3a0ded833c01a29fa389156d831e...    True          52384
#  6   0xafe6d6800f2a2af8673c16de02aa0488d07014822316...    True          52384
#  7   0x95b229d9c0f5bd9b7c49791a51626edde8cada3c0285...    True          52384
#  8   0x5a9efb8988ae1e11897e49661514e4266584478c4cd8...    True          52384
#  9   0x9c61d5dc227090b9cf497a7dc850f8e671b33b3aac13...    True          52384
#  10  0xf7855022b7aa4b66ea815833185a33dcca5a64f17932...    True          52384
#  11  0xba90006e079171bf2962e9cb8a2c9c7c0ffdaa9ba734...    True          52384
#
#      Coste en wei   Bloque              Tiempo  Diferencia de tiempo  Duración  \
#  0       0.000069  3318750 2023-05-12 12:34:42                   1.0       1.0
#  1       0.000069  3318751 2023-05-12 12:34:43                   1.0       2.0
#  2       0.000052  3318752 2023-05-12 12:34:44                   1.0       3.0
#  3       0.000069  3318753 2023-05-12 12:34:45                   1.0       4.0
#  4       0.000052  3318754 2023-05-12 12:34:46                   1.0       5.0
#  5       0.000052  3318755 2023-05-12 12:34:47                   1.0       6.0
#  6       0.000052  3318756 2023-05-12 12:34:48                   1.0       7.0
#  7       0.000052  3318757 2023-05-12 12:34:49                   1.0       8.0
#  8       0.000052  3318758 2023-05-12 12:34:50                   1.0       9.0
#  9       0.000052  3318759 2023-05-12 12:34:51                   1.0      10.0
#  10      0.000052  3318760 2023-05-12 12:34:52                   1.0      11.0
#  11      0.000052  3318761 2023-05-12 12:34:53                   1.0      12.0
#
#      Coste total        Fuente
#  0      0.000069  sepolia_bear
#  1      0.000139  sepolia_bear
#  2      0.000191  sepolia_bear
#  3      0.000261  sepolia_bear
#  4      0.000313  sepolia_bear
#  5      0.000366  sepolia_bear
#  6      0.000418  sepolia_bear
#  7      0.000470  sepolia_bear
#  8      0.000523  sepolia_bear
#  9      0.000575  sepolia_bear
#  10     0.000628  sepolia_bear
#  11     0.000680  sepolia_bear  ,
#  'sepolia':                                           Transacción  Estado  Gas utilizado  \
#  0   0x147a75b85c2cf9547c52f394c59b579482c65b7bcdd8...    True          69484
#  1   0x6a1de4587245844ba1b507d115c6d043ac52c4fc1b7c...    True          52384
#  2   0x3b88b7d998c4106ecd5e61e55757773f0ba4587d61f6...    True          52384
#  3   0x5dccd7fc47553e271758fb47b1bad0c0e64788338c31...    True          52384
#  4   0x574d10d73267dfdb896fc0288a9be2a77acf317b68bb...    True          52384
#  5   0xf179e1af24f65a0720666e05b3f568dc19a4a6adf049...    True          52384
#  6   0x8c068f781805a01cf95a09513fca1874fcbc86554022...    True          52384
#  7   0xb2b643a33128457c6247eb32b969a3d40417f119dee1...    True          52384
#  8   0x7941ead11982c9299c5c4f18a70df38bad6f1866371b...    True          69472
#  9   0x68556ec3386da7383b2cfc2a83e3874b2f2ec936115c...    True          52384
#  10  0xa3c190eae93c7d59f64e4de70bbb0d405502ee2a305d...    True          52384
#  11  0xb4295efda5034650e9157824dfd3c19379363aab0e2e...    True          69484
#
#      Coste en wei   Bloque              Tiempo  Diferencia de tiempo  Duración  \
#  0       0.002085  3333098 2023-05-12 08:02:24                   0.0       0.0
#  1       0.001572  3333098 2023-05-12 08:02:24                   0.0       0.0
#  2       0.001572  3333098 2023-05-12 08:02:24                   0.0       0.0
#  3       0.001572  3333098 2023-05-12 08:02:24                   0.0       0.0
#  4       0.001572  3333098 2023-05-12 08:02:24                   0.0       0.0
#  5       0.001572  3333098 2023-05-12 08:02:24                   0.0       0.0
#  6       0.001572  3333098 2023-05-12 08:02:24                   0.0       0.0
#  7       0.001572  3333098 2023-05-12 08:02:24                   0.0       0.0
#  8       0.002084  3333098 2023-05-12 08:02:24                   0.0       0.0
#  9       0.001572  3333098 2023-05-12 08:02:24                   0.0       0.0
#  10      0.001572  3333098 2023-05-12 08:02:24                   0.0       0.0
#  11      0.002085  3333098 2023-05-12 08:02:24                   0.0       0.0
#
#      Coste total   Fuente
#  0      0.002085  sepolia
#  1      0.003656  sepolia
#  2      0.005228  sepolia
#  3      0.006799  sepolia
#  4      0.008371  sepolia
#  5      0.009942  sepolia
#  6      0.011514  sepolia
#  7      0.013085  sepolia
#  8      0.015169  sepolia
#  9      0.016741  sepolia
#  10     0.018312  sepolia
#  11     0.020397  sepolia  ,
#  'polygon_bear':                                           Transacción  Estado  Gas utilizado  \
#  0   0xd7fb8efc46c40437de8061eb5a4b95e4233e8f7b3dca...    True          69484
#  1   0xc80feeb1dcb5b33f6c8a657e23dfa39b5094e3b7373a...    True          52384
#  2   0xcc54e685db95c61d2614eb4ff2dbc109ee409e4a3fa2...    True          69472
#  3   0x20965e4f4515572eafeb26585e67fae1481d509b4170...    True          52384
#  4   0x6ca2abec22e6e83eab716544d7c9c712fa40d8a1cac5...    True          69484
#  5   0xc9e0679ad3c5e7d0e50ee0d2dcaa9b4ea662c252b4b3...    True          52384
#  6   0x65dadbcae7815d81f822f0f14fb2d8fa922e19e5b14b...    True          52384
#  7   0x80062953f3f2fbc5c3c901b35afeb7cdd0596952ba53...    True          52384
#  8   0x89a7579fd6fc2173f49581d351d2a1cd5042e2044e23...    True          52384
#  9   0x1cc3aa7c6bb5d028c02007386bda315720b1e092a929...    True          52384
#  10  0x77f36cb9d0fe432d8bfa7ad3a30511095dd16e030f92...    True          52384
#  11  0xb5bb4f0edbc9394bf439f4b47a1994e178eb9f2e1a3b...    True          52384
#
#      Coste en wei    Bloque              Tiempo  Diferencia de tiempo  \
#  0       0.000235  41666854 2023-05-12 02:38:06                   1.0
#  1       0.000177  41666855 2023-05-12 02:38:07                   1.0
#  2       0.000215  41666856 2023-05-12 02:38:08                   1.0
#  3       0.000148  41666857 2023-05-12 02:38:09                   1.0
#  4       0.000181  41666858 2023-05-12 02:38:10                   1.0
#  5       0.000126  41666859 2023-05-12 02:38:11                   1.0
#  6       0.000117  41666860 2023-05-12 02:38:12                   1.0
#  7       0.000109  41666861 2023-05-12 02:38:13                   1.0
#  8       0.000102  41666862 2023-05-12 02:38:14                   1.0
#  9       0.000096  41666863 2023-05-12 02:38:15                   1.0
#  10      0.000096  41666864 2023-05-12 02:38:16                   1.0
#  11      0.000096  41666865 2023-05-12 02:38:17                   1.0
#
#      Duración  Coste total        Fuente
#  0        1.0     0.000235  polygon_bear
#  1        2.0     0.000413  polygon_bear
#  2        3.0     0.000627  polygon_bear
#  3        4.0     0.000775  polygon_bear
#  4        5.0     0.000956  polygon_bear
#  5        6.0     0.001082  polygon_bear
#  6        7.0     0.001199  polygon_bear
#  7        8.0     0.001307  polygon_bear
#  8        9.0     0.001409  polygon_bear
#  9       10.0     0.001505  polygon_bear
#  10      11.0     0.001600  polygon_bear
#  11      12.0     0.001696  polygon_bear  ,
#  'optimism_bear':                                           Transacción  Estado  Gas utilizado  \
#  0   0xec64d612a36f517786d8d386ea2a1991effc34792010...    True          69484
#  1   0xef131b78081c8a5f04b3f53c589a701ffdf55a6a2fca...    True          69472
#  2   0x8ab1fa92f0a0290fa7656124d99982f664422c62421b...    True          69484
#  3   0xb81c678d7d4ad3cf840eb4d4667d9d330c29bed811d0...    True          52384
#  4   0x2924cededceef76366be35dd1bd5a92fc71f841c0c25...    True          52384
#  5   0xa3e3956d213320322054f974662ca712c32b716ae01f...    True          52384
#  6   0x2fa713d8f9ade2f1246f612e7df830932d9189949b17...    True          52384
#  7   0x4a29e73e0fafa59022be580fe862ee7ada3f69ecf705...    True          52384
#  8   0x8f5d9c059d997da24e73089e13422410ed7551f283cd...    True          52384
#  9   0x4db913aaad94b35172203d9aec3409e39eebeef6b601...    True          52384
#  10  0x83e0f41006089dcd293588475d5a083800dfbd838840...    True          52384
#  11  0x11c0b0d5483a4fe966fda9e13e24b4d5f2ee566d34cc...    True          52384
#
#      Coste en wei    Bloque              Tiempo  Diferencia de tiempo  \
#  0       0.000070  91823109 2023-05-12 01:12:38                   1.0
#  1       0.000070  91823110 2023-05-12 01:12:39                   1.0
#  2       0.000070  91823111 2023-05-12 01:12:40                   1.0
#  3       0.000053  91823112 2023-05-12 01:12:41                   1.0
#  4       0.000053  91823113 2023-05-12 01:12:42                   1.0
#  5       0.000053  91823114 2023-05-12 01:12:43                   1.0
#  6       0.000053  91823115 2023-05-12 01:12:44                   1.0
#  7       0.000053  91823116 2023-05-12 01:12:45                   1.0
#  8       0.000053  91823117 2023-05-12 01:12:46                   1.0
#  9       0.000053  91823118 2023-05-12 01:12:47                   1.0
#  10      0.000053  91823119 2023-05-12 01:12:48                   1.0
#  11      0.000053  91823120 2023-05-12 01:12:49                   1.0
#
#      Duración  Coste total         Fuente
#  0        1.0     0.000070  optimism_bear
#  1        2.0     0.000141  optimism_bear
#  2        3.0     0.000211  optimism_bear
#  3        4.0     0.000264  optimism_bear
#  4        5.0     0.000316  optimism_bear
#  5        6.0     0.000369  optimism_bear
#  6        7.0     0.000422  optimism_bear
#  7        8.0     0.000475  optimism_bear
#  8        9.0     0.000527  optimism_bear
#  9       10.0     0.000580  optimism_bear
#  10      11.0     0.000632  optimism_bear
#  11      12.0     0.000685  optimism_bear  ,
#  'boba':                                           Transacción  Estado  Gas utilizado  \
#  0   0x9cfedb3f1ea2616385a3bf78ee637758179b362143b3...    True          58999
#  1   0xe2af2d58189425e2ec70cd746841a1d6fba31c9fb179...    True          76099
#  2   0xe68724db3153bb0a4d9fda7c9c152d814f7329798f05...    True          76099
#  3   0xa4ef98e04b9c38db4822b1ccb3b10e253c68c7351ed7...    True          76069
#  4   0xad9a3cc6e20804c240036b72c88f7d60c1876f8602e0...    True          58999
#  5   0x5286054399122b6bea309908a2f2976b6e9ef16ed4e6...    True          58999
#  6   0x68447e9e1d29f9e339daa3fad98b9daa0a4f826cd79c...    True          58999
#  7   0x80ce25e749da1d523295594311bdf1950e0f44bde920...    True          58999
#  8   0xf8e07c0f7ff111f9d851877c0511411e9798bf034eb1...    True          58999
#  9   0x846c04ee9df4317fccf0b1504335a52c5aaef1f618c9...    True          58999
#  10  0xf5866d34a6e6a0a802a70d4a6f727209a02e4d6a4710...    True          58999
#  11  0x4df3f0cda61bafa5b1f0b92360a40ee9586020fea989...    True          58999
#
#      Coste en wei  Bloque              Tiempo  Diferencia de tiempo  Duración  \
#  0       0.000059    9246 2023-05-12 03:06:00              0.454545  0.454545
#  1       0.000076    9247 2023-05-12 03:06:00              0.000000  0.454545
#  2       0.000076    9248 2023-05-12 03:06:00              0.000000  0.454545
#  3       0.000076    9249 2023-05-12 03:06:00              0.000000  0.454545
#  4       0.000059    9250 2023-05-12 03:06:00              0.000000  0.454545
#  5       0.000059    9251 2023-05-12 03:06:00              0.000000  0.454545
#  6       0.000059    9252 2023-05-12 03:06:05              5.000000  5.454545
#  7       0.000059    9253 2023-05-12 03:06:05              0.000000  5.454545
#  8       0.000059    9254 2023-05-12 03:06:05              0.000000  5.454545
#  9       0.000059    9255 2023-05-12 03:06:05              0.000000  5.454545
#  10      0.000059    9256 2023-05-12 03:06:05              0.000000  5.454545
#  11      0.000059    9257 2023-05-12 03:06:05              0.000000  5.454545
#
#      Coste total Fuente
#  0      0.000059   boba
#  1      0.000135   boba
#  2      0.000211   boba
#  3      0.000287   boba
#  4      0.000346   boba
#  5      0.000405   boba
#  6      0.000464   boba
#  7      0.000523   boba
#  8      0.000582   boba
#  9      0.000641   boba
#  10     0.000700   boba
#  11     0.000759   boba  ,
#  'arbitrum_bear':                                           Transacción  Estado  Gas utilizado  \
#  0   0x5559358454b1255d9404335f7020016d6903cb013c8c...    True          69484
#  1   0xc900cec1573cab343e127f05bb3ad6bda2b75b5b8fdb...    True          52384
#  2   0x83170e0fbe7834d7cf5a39d6eecdab69c7789c6a7c82...    True          69472
#  3   0xd92138b44df7d746e6b4418d76fcff5146e6a995925a...    True          52384
#  4   0x1a16e05cf7d97ede34de7e652e02d48637fb25caa746...    True          52384
#  5   0x49b364eecdb41cbbea06422bd85bc86598da5439647e...    True          52384
#  6   0x6fe66979fcd24a35c898e37a27716394a718030e8ba6...    True          52384
#  7   0x50a80308e9d67b3f332766eb27f8a054b5bbd9bbe700...    True          69484
#  8   0x01283b7a67d5f979e685e425ffc805dc05a182e0d90a...    True          52384
#  9   0xa469c4ff1a5e368b0e494a99a3aeddeb774cad1c8c0a...    True          52384
#  10  0xfb414fad76a911167d58198f7006db1298bdebd83eeb...    True          52384
#  11  0x54cca2dfb2f81c6f518e4158e861015b9d5259b6bc6e...    True          52384
#
#      Coste en wei    Bloque              Tiempo  Diferencia de tiempo  \
#  0       0.000070  81696848 2023-05-12 02:23:44                   1.0
#  1       0.000052  81696849 2023-05-12 02:23:45                   1.0
#  2       0.000070  81696850 2023-05-12 02:23:46                   1.0
#  3       0.000052  81696851 2023-05-12 02:23:47                   1.0
#  4       0.000052  81696852 2023-05-12 02:23:48                   1.0
#  5       0.000052  81696853 2023-05-12 02:23:49                   1.0
#  6       0.000052  81696854 2023-05-12 02:23:50                   1.0
#  7       0.000070  81696855 2023-05-12 02:23:51                   1.0
#  8       0.000052  81696856 2023-05-12 02:23:52                   1.0
#  9       0.000052  81696857 2023-05-12 02:23:53                   1.0
#  10      0.000052  81696858 2023-05-12 02:23:54                   1.0
#  11      0.000052  81696859 2023-05-12 02:23:55                   1.0
#
#      Duración  Coste total         Fuente
#  0        1.0     0.000070  arbitrum_bear
#  1        2.0     0.000122  arbitrum_bear
#  2        3.0     0.000192  arbitrum_bear
#  3        4.0     0.000244  arbitrum_bear
#  4        5.0     0.000296  arbitrum_bear
#  5        6.0     0.000349  arbitrum_bear
#  6        7.0     0.000401  arbitrum_bear
#  7        8.0     0.000471  arbitrum_bear
#  8        9.0     0.000523  arbitrum_bear
#  9       10.0     0.000576  arbitrum_bear
#  10      11.0     0.000628  arbitrum_bear
#  11      12.0     0.000680  arbitrum_bear  ,
#  'arbitrum':                                           Transacción  Estado  Gas utilizado  \
#  0   0x9d0573fdea524eb2bd38f30de88c4fc31a040497aa77...    True          52384
#  1   0x83ffa7606541df62cbbed9974cd6d861f1018ff0f9d3...    True          52384
#  2   0x9c226beba2280a0272437963d6e857015834c1a92464...    True          52384
#  3   0xcf7849ad011c1a0d0eba758d239ec34106dae2dc0d85...    True          52384
#  4   0xe384ad6547197efac720ed7cdf5b1f08bbab51705fc0...    True          69484
#  5   0x180b4f8dcd01325a10fbb2f37ba055083f1f6e0029ab...    True          69484
#  6   0x6f7e8c7cf2e977c32bbe06bc12d6592d1c8e15e9103c...    True          52384
#  7   0xb65a2ffb7004030e349b7dd5c3529541b57b55033e40...    True          52384
#  8   0x9f92ffecc80560d8f3cc6e9ff0510ad658e22b6732dc...    True          52384
#  9   0x4b14dc9bf7001c879bd74dc2c36587aaf8b65e8960a1...    True          69472
#  10  0x21752d7549abe0c6e8914f08dea22ad2a8f1d518d5b4...    True          52384
#  11  0x908e71c7a11a9f80dce737c474cf1ce7e6ebea243130...    True          52384
#
#      Coste en wei    Bloque              Tiempo  Diferencia de tiempo  \
#  0       0.000052  16948685 2023-05-12 02:44:03              0.545455
#  1       0.000052  16948687 2023-05-12 02:44:03              0.000000
#  2       0.000052  16948689 2023-05-12 02:44:04              1.000000
#  3       0.000052  16948690 2023-05-12 02:44:04              0.000000
#  4       0.000069  16948691 2023-05-12 02:44:05              1.000000
#  5       0.000069  16948694 2023-05-12 02:44:05              0.000000
#  6       0.000052  16948698 2023-05-12 02:44:06              1.000000
#  7       0.000052  16948699 2023-05-12 02:44:07              1.000000
#  8       0.000052  16948701 2023-05-12 02:44:07              0.000000
#  9       0.000069  16948702 2023-05-12 02:44:08              1.000000
#  10      0.000052  16948704 2023-05-12 02:44:08              0.000000
#  11      0.000052  16948705 2023-05-12 02:44:09              1.000000
#
#      Duración  Coste total    Fuente
#  0   0.545455     0.000052  arbitrum
#  1   0.545455     0.000105  arbitrum
#  2   1.545455     0.000157  arbitrum
#  3   1.545455     0.000210  arbitrum
#  4   2.545455     0.000279  arbitrum
#  5   2.545455     0.000349  arbitrum
#  6   3.545455     0.000401  arbitrum
#  7   4.545455     0.000453  arbitrum
#  8   4.545455     0.000506  arbitrum
#  9   5.545455     0.000575  arbitrum
#  10  5.545455     0.000628  arbitrum
#  11  6.545455     0.000680  arbitrum  }

# %% [markdown]
# Actualizamos el valor de CosteTotal con la suma de la columan de Coste Total de los dataframes que hemos estado representando anteriormente.

# %%
for dataset_name, dataset_values in datasets_resumen2.items():
    # Verificar si la clave existe en el diccionario "datasets_resumen"
    if dataset_name in datasets_resumen:
        # Obtener el último valor de la columna "Coste Total" del DataFrame correspondiente en "datasets_resumen"
        last_coste_total = datasets_resumen[dataset_name]['Coste total'].iloc[-1]
        
        # Reemplazar el valor de la columna "Coste Total" del DataFrame correspondiente en "datasets_resumen2"
        datasets_resumen2[dataset_name]['Coste Total'] = last_coste_total
    
    # Imprimir el nombre del conjunto de datos y el valor actual de la columna "Coste Total" del DataFrame en "datasets_resumen2"
    print("Conjunto de datos:", dataset_name)
    print("Valor actual de la columna 'Coste Total' en datasets_resumen2:")
    print(dataset_values['Coste Total'])
# Out:
# Conjunto de datos: sepolia_bear
# Valor actual de la columna 'Coste Total' en datasets_resumen2:
# 0    0.00068
# Name: Coste Total, dtype: float64
# Conjunto de datos: sepolia
# Valor actual de la columna 'Coste Total' en datasets_resumen2:
# 0    0.020397
# Name: Coste Total, dtype: float64
# Conjunto de datos: polygon_bear
# Valor actual de la columna 'Coste Total' en datasets_resumen2:
# 0    0.001696
# Name: Coste Total, dtype: float64
# Conjunto de datos: optimism_bear
# Valor actual de la columna 'Coste Total' en datasets_resumen2:
# 0    0.000685
# Name: Coste Total, dtype: float64
# Conjunto de datos: boba
# Valor actual de la columna 'Coste Total' en datasets_resumen2:
# 0    0.000759
# Name: Coste Total, dtype: float64
# Conjunto de datos: arbitrum_bear
# Valor actual de la columna 'Coste Total' en datasets_resumen2:
# 0    0.00068
# Name: Coste Total, dtype: float64
# Conjunto de datos: arbitrum
# Valor actual de la columna 'Coste Total' en datasets_resumen2:
# 0    0.00068
# Name: Coste Total, dtype: float64

# %% [markdown]
# ## Representación

# %% [markdown]
# <section id="representacion-coste-total">
#   <h2>Representación de Coste Total</h2>
#
# </section>

# %% [markdown]
# Representamos de forma gráfica el valor en ether del coste total que ha costado realizar estas operaciones

# %%
import matplotlib.pyplot as plt

# Configuración del gráfico
fig, ax = plt.subplots(figsize=(12, 8))

# Crear el gráfico de barras para cada conjunto de datos en datasets_resumen
for dataset_name, dataset_values in datasets_resumen2.items():
    y = dataset_values['Coste Total']
    ax.bar(dataset_name, y, label=dataset_name)
    
# Configurar las etiquetas y leyendas del gráfico
ax.set_xlabel('Conjunto de datos')
ax.set_ylabel('Coste Total (ETH)')
ax.legend(loc='right')
fig.suptitle('Coste total de transacciones por conjunto de datos')

plt.show()

# %% [markdown]
# <section id="representacion-coste-duracion">
#   <h2>Representación de Coste Total y la duración</h2>
#
# </section>

# %% [markdown]
# Para finalizar, representamos la duración y el coste total en ether de los datos

# %%
import matplotlib.pyplot as plt

# Configuración del gráfico
fig, ax = plt.subplots(figsize=(8, 6))

# Crear el gráfico de dispersión para cada conjunto de datos en datasets_resumen
for dataset_name, dataset_values in datasets_resumen2.items():
    x = dataset_values['Duración']
    y = dataset_values['Coste Total']
    ax.scatter(x, y, s=60, label=dataset_name)
    
# Configurar las etiquetas y leyendas del gráfico
ax.set_xlabel('Duración  (ms)')
ax.set_ylabel('Coste Total (ETH)')
ax.legend()
fig.suptitle('Relación entre duración y coste total de transacciones')
plt.show()
