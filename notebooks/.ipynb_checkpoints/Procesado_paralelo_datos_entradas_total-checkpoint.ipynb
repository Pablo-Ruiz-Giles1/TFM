# %% [markdown]
# ![](files/images/EscUpmPolit_p.gif "UPM")

# %% [markdown]
# <header style="width:100%;position:relative">
#   <div style="width:80%;float:right;">
#     <h1>Procesado de datos de Blockchain</h1>
#     <h3>TFM</h3>
#     <h5>Universidad Politécnica de Madrid. © Pablo Ruiz Giles </h5>
#   </div>
#         <img style="width:15%;" src="../logo.jpg" alt="UPM" />
# </header>

# %% [markdown]
# # Cargamos los datasets

# %% [markdown]
# ### Importamos paralelo_ganache

# %%
import numpy as np
import pandas as pd
import os

# Obtener la lista de archivos CSV en la carpeta datos/paralelo_ganache/
csv_files = [f for f in os.listdir('datos/paralelo_ganache/') if f.endswith('.csv')]

# Leer cada archivo CSV y asignarlo a una variable
for f in csv_files:
    # Obtener el nombre del archivo sin la extensión
    name = os.path.splitext(f)[0]
    # Leer el archivo CSV y asignarlo a una variable con el nombre del archivo
    vars()[name] = pd.read_csv(os.path.join('datos/paralelo_ganache/', f))

# Imprimir los nombres de las variables creadas que empiezan con "paralelo_ganache"
print("Los siguientes DataFrames se han creado:")
for var in sorted(vars()):
    if var.startswith('paralelo_ganache'):
        print(var)
# Out:
# Los siguientes DataFrames se han creado:
# paralelo_ganache_resumen1
# paralelo_ganache_resumen2
# paralelo_ganache_resumen3
# paralelo_ganache_total
# paralelo_ganachedatos1
# paralelo_ganachedatos2
# paralelo_ganachedatos3

# %% [markdown]
# ### Importamos paralelo_3_ganache

# %%
import numpy as np
import pandas as pd
import os

# Obtener la lista de archivos CSV en la carpeta datos/paralelo_ganache/
csv_files = [f for f in os.listdir('datos/paralelo_3_ganache/') if f.endswith('.csv')]

# Leer cada archivo CSV y asignarlo a una variable
for f in csv_files:
    # Obtener el nombre del archivo sin la extensión
    name = os.path.splitext(f)[0]
    # Leer el archivo CSV y asignarlo a una variable con el nombre del archivo
    vars()[name] = pd.read_csv(os.path.join('datos/paralelo_3_ganache/', f))

# Imprimir los nombres de las variables creadas que empiezan con "paralelo_ganache"
print("Los siguientes DataFrames se han creado:")
for var in sorted(vars()):
    if var.startswith('paralelo_3_ganache'):
        print(var)
# Out:
# Los siguientes DataFrames se han creado:
# paralelo_3_ganache_resumen1
# paralelo_3_ganache_resumen2
# paralelo_3_ganache_resumen3
# paralelo_3_ganache_total
# paralelo_3_ganachedatos1
# paralelo_3_ganachedatos2
# paralelo_3_ganachedatos3

# %%
paralelo_3_ganache_total
# Out:
#    Creadas  Coste en gas (wei)  Coste en ether  Empezar  Acabar  Duracion
# 0       81     277276272373125        0.000277       35   86884     86849

# %%
paralelo_3_ganache_resumen1
# Out:
#    Antes  Despues  Duración  Transacciones  Coste Total
# 0     68    12402     12334             40     0.000178

# %%
paralelo_3_ganachedatos1
# Out:
#                                           Transacción  Estado Gas utilizado  \
# 0   0x5562323d592a18dd82cf25ffd0e99875a802b1e2b690...    True       0x10b2a
# 1   0x49632837f00e584710fafe1e1cdf7d1fcf125ef936ef...    True       0x10b36
# 2   0x90664853ff57bb93f195e49d93e0dcd57a77fc323516...    True       0x10b36
# 37  0x5412887dcddd80c2d86113a6e87f3ed148b2d4c594b1...    True        0xd09e
# 38  0x931785d3737bd0ebe37ab9693684c2916f3fe5578a75...    True        0xd09e
# 39  0x41d26b1f0169ce038173cadb5f586279ad9c1a40c11b...    True        0xd09e
#
#     Coste en wei  Bloque    Tiempo
# 0       0.000005     338  01:36:41
# 1       0.000005     338  01:36:41
# 2       0.000005     338  01:36:41
# 3       0.000005     338  01:36:41
# 4       0.000005     338  01:36:41
# 5       0.000005     338  01:36:41
# 6       0.000005     338  01:36:41
# 7       0.000005     338  01:36:41
# 8       0.000005     338  01:36:41
# 9       0.000005     338  01:36:41
# 10      0.000004     338  01:36:41
# 11      0.000004     338  01:36:41
# 12      0.000004     338  01:36:41
# 13      0.000004     338  01:36:41
# 14      0.000004     338  01:36:41
# 15      0.000004     338  01:36:41
# 16      0.000004     338  01:36:41
# 17      0.000004     338  01:36:41
# 18      0.000004     338  01:36:41
# 19      0.000004     338  01:36:41
# 20      0.000004     338  01:36:41
# 21      0.000004     338  01:36:41
# 22      0.000004     338  01:36:41
# 23      0.000004     338  01:36:41
# 24      0.000004     338  01:36:41
# 25      0.000004     338  01:36:41
# 26      0.000004     338  01:36:41
# 27      0.000004     338  01:36:41
# 28      0.000004     338  01:36:41
# 29      0.000004     338  01:36:41
# 30      0.000004     338  01:36:41
# 31      0.000004     338  01:36:41
# 32      0.000004     338  01:36:41
# 33      0.000004     338  01:36:41
# 34      0.000004     338  01:36:41
# 35      0.000004     338  01:36:41
# 36      0.000004     338  01:36:41
# 37      0.000004     338  01:36:41
# 38      0.000004     338  01:36:41
# 39      0.000004     338  01:36:41

# %% [markdown]
# # Preprocesamos

# %% [markdown]
# ### Añadimos columna que sea la diferencia de tiempos entre transacciones

# %%
# Crear una lista con los nombres de los datasets
datasets = ["paralelo_3_ganachedatos1", "paralelo_3_ganachedatos2", "paralelo_3_ganachedatos3","paralelo_ganachedatos1", "paralelo_ganachedatos2", "paralelo_ganachedatos3"]

# Iterar sobre la lista de nombres de datasets
for dataset in datasets:
    # Convertir la columna "Tiempo" a tipo datetime
    globals()[dataset]["Tiempo"] = pd.to_datetime(globals()[dataset]["Tiempo"])

    # Calcular la diferencia de tiempo entre cada fila y la anterior, en segundos
    globals()[dataset]["Diferencia de tiempo"] = (globals()[dataset]["Tiempo"] - globals()[dataset]["Tiempo"].shift(1)).dt.total_seconds()

    # Calcular la media de la columna "Diferencia de tiempo"
    media_diferencia_tiempo = globals()[dataset]["Diferencia de tiempo"].mean()

    # Reemplazar los valores NaN con la media de las otras filas
    globals()[dataset]["Diferencia de tiempo"].fillna(media_diferencia_tiempo, inplace=True)

# %%
paralelo_3_ganachedatos1
# Out:
#                                           Transacción  Estado Gas utilizado  \
# 0   0x5562323d592a18dd82cf25ffd0e99875a802b1e2b690...    True       0x10b2a
# 1   0x49632837f00e584710fafe1e1cdf7d1fcf125ef936ef...    True       0x10b36
# 2   0x90664853ff57bb93f195e49d93e0dcd57a77fc323516...    True       0x10b36
# 3   0x1bab669bd25fc219db609eade2ab74e69c150fddc301...    True       0x10b36
# 37  0x5412887dcddd80c2d86113a6e87f3ed148b2d4c594b1...    True        0xd09e
# 38  0x931785d3737bd0ebe37ab9693684c2916f3fe5578a75...    True        0xd09e
# 39  0x41d26b1f0169ce038173cadb5f586279ad9c1a40c11b...    True        0xd09e
#
#     Coste en wei  Bloque              Tiempo  Diferencia de tiempo
# 0       0.000005     338 2023-04-13 01:36:41                   0.0
# 1       0.000005     338 2023-04-13 01:36:41                   0.0
# 2       0.000005     338 2023-04-13 01:36:41                   0.0
# 3       0.000005     338 2023-04-13 01:36:41                   0.0
# 4       0.000005     338 2023-04-13 01:36:41                   0.0
# 5       0.000005     338 2023-04-13 01:36:41                   0.0
# 6       0.000005     338 2023-04-13 01:36:41                   0.0
# 7       0.000005     338 2023-04-13 01:36:41                   0.0
# 8       0.000005     338 2023-04-13 01:36:41                   0.0
# 9       0.000005     338 2023-04-13 01:36:41                   0.0
# 10      0.000004     338 2023-04-13 01:36:41                   0.0
# 11      0.000004     338 2023-04-13 01:36:41                   0.0
# 12      0.000004     338 2023-04-13 01:36:41                   0.0
# 13      0.000004     338 2023-04-13 01:36:41                   0.0
# 14      0.000004     338 2023-04-13 01:36:41                   0.0
# 15      0.000004     338 2023-04-13 01:36:41                   0.0
# 16      0.000004     338 2023-04-13 01:36:41                   0.0
# 17      0.000004     338 2023-04-13 01:36:41                   0.0
# 18      0.000004     338 2023-04-13 01:36:41                   0.0
# 19      0.000004     338 2023-04-13 01:36:41                   0.0
# 20      0.000004     338 2023-04-13 01:36:41                   0.0
# 21      0.000004     338 2023-04-13 01:36:41                   0.0
# 22      0.000004     338 2023-04-13 01:36:41                   0.0
# 23      0.000004     338 2023-04-13 01:36:41                   0.0
# 24      0.000004     338 2023-04-13 01:36:41                   0.0
# 25      0.000004     338 2023-04-13 01:36:41                   0.0
# 26      0.000004     338 2023-04-13 01:36:41                   0.0
# 27      0.000004     338 2023-04-13 01:36:41                   0.0
# 28      0.000004     338 2023-04-13 01:36:41                   0.0
# 29      0.000004     338 2023-04-13 01:36:41                   0.0
# 30      0.000004     338 2023-04-13 01:36:41                   0.0
# 31      0.000004     338 2023-04-13 01:36:41                   0.0
# 32      0.000004     338 2023-04-13 01:36:41                   0.0
# 33      0.000004     338 2023-04-13 01:36:41                   0.0
# 34      0.000004     338 2023-04-13 01:36:41                   0.0
# 35      0.000004     338 2023-04-13 01:36:41                   0.0
# 36      0.000004     338 2023-04-13 01:36:41                   0.0
# 37      0.000004     338 2023-04-13 01:36:41                   0.0
# 38      0.000004     338 2023-04-13 01:36:41                   0.0
# 39      0.000004     338 2023-04-13 01:36:41                   0.0

# %% [markdown]
# ### Pasamos de hexadecimal a decimal Gas utilizado

# %%
#Gas utilizado 
import pandas as pd

def hex_to_dec(datos):
    # Convierte la columna "Gas utilizado" de hexadecimal a decimal
    datos["Gas utilizado"] = datos["Gas utilizado"].apply(lambda x: int(x, 16))
    
    # Devuelve el DataFrame modificado
    return datos


# Iterar sobre la lista de nombres de datasets
for dataset in datasets:
    # Aplicar la función a la columna "Gas utilizado" del DataFrame
    globals()[dataset] = hex_to_dec(globals()[dataset])
    
    # Imprimir el DataFrame resultante
    print(globals()[dataset].head())
# Out:
#                                          Transacción  Estado  Gas utilizado  \
# 0  0
#
#    Coste en wei  Bloque              Tiempo  Diferencia de tiempo
# 0      0.000002      13 2023-04-13 01:40:00              0.153846
# 1      0.000002      13 2023-04-13 01:40:00              0.000000
# 2      0.000002      13 2023-04-13 01:40:00              0.000000
# 3      0.000002      13 2023-04-13 01:40:00              0.000000
# 4      0.000002      13 2023-04-13 01:40:00              0.000000
#                                          Transacción  Estado  Gas utilizado  \
# 0  0x42a822e6bd6357a58ef9a573fe0fda55809285c25e79...    True          14485
#
#    Coste en wei  Bloque              Tiempo  Diferencia de tiempo
# 0  9.673898e-07      19 2023-04-13 01:40:41                   NaN

# %% [markdown]
# # Comparativa

# %% [markdown]
# ### Generamos distintos datasets

# %%
datasets_comprar = {
    "paralelo_3_ganachedatos1": paralelo_3_ganachedatos1,
    "paralelo_ganachedatos1": paralelo_ganachedatos1
}


datasets_revender = {
    "paralelo_3_ganachedatos2": paralelo_3_ganachedatos2,
    "paralelo_ganachedatos2": paralelo_ganachedatos2
}


datasets_eliminar = {
    "paralelo_3_ganachedatos3": paralelo_3_ganachedatos3,
    "paralelo_ganachedatos3": paralelo_ganachedatos3
}

# %% [markdown]
# #  Dataset Total

# %%
paralelo_3_ganache_total
# Out:
#    Creadas  Coste en gas (wei)  Coste en ether  Empezar  Acabar  Duracion
# 0       81     277276272373125        0.000277       35   86884     86849

# %%
paralelo_ganache_total
# Out:
#    Creadas  Coste en gas (wei)  Coste en ether  Empezar  Acabar  Duracion
# 0       81     238065441373125        0.000238       67   67337     67270

# %%
datasets_resumen = {
    "paralelo_3_ganache_total": paralelo_3_ganache_total,
    "paralelo_ganache_total": paralelo_ganache_total
}

# %%
for dataset_name, dataset_values in datasets_resumen.items():
    # Obtener la media de la duración y el coste en ether
    media_duracion = dataset_values['Duracion'].mean()
    media_coste_ether = dataset_values['Coste en ether'].mean()

    # Imprimir las estadísticas para el conjunto de datos actual
    print("Estadísticas para el conjunto de datos", dataset_name)
    print("Media de Duración:", media_duracion)
    print("Media de Coste en ether:", media_coste_ether)
# Out:
# Estadísticas para el conjunto de datos paralelo_3_ganache_total
# Media de Duración: 86849.0
# Media de Coste en ether: 0.0002772762723731
# Estadísticas para el conjunto de datos paralelo_ganache_total
# Media de Duración: 67270.0
# Media de Coste en ether: 0.0002380654413731

# %%
import matplotlib.pyplot as plt

# Crear una lista de colores para cada conjunto de datos
colores = ['blue', 'orange']

# Configurar el gráfico de dispersión
fig, ax = plt.subplots()
for i, (dataset_name, dataset_values) in enumerate(datasets_resumen.items()):
    duracion_media = dataset_values['Duracion']
    coste_media = dataset_values['Coste en ether']
    ax.scatter(duracion_media, coste_media, color=colores[i], label=dataset_name)

ax.set_xlabel('Duración')
ax.set_ylabel('Coste en ether')
ax.set_title('Duración y Coste en ether por conjunto de datos')
ax.legend()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Licence
# The notebook is freely licensed under under the [Creative Commons Attribution Share-Alike license](https://creativecommons.org/licenses/by/2.0/).
#
# ©  Carlos A. Iglesias, Universidad Politécnica de Madrid.
