# %% [markdown]
# ![](files/images/EscUpmPolit_p.gif "UPM")

# %% [markdown]
# <header style="width:100%;position:relative">
#   <div style="width:80%;float:right;">
#     <h1>Procesado de datos de Blockchain</h1>
#     <h3>TFM</h3>
#     <h5>Universidad Politécnica de Madrid. © Pablo Ruiz Giles </h5>
#   </div>
#         <img style="width:15%;" src="../logo.jpg" alt="UPM" />
# </header>

# %% [markdown]
# # Cargamos los datasets

# %%
import pandas as pd
import os

# Obtener los archivos CSV en todas las subcarpetas que contengan '_secuencial' en su nombre
csv_files = []
for root, dirs, files in os.walk('datos/secuencial/'):
    for f in files:
        if '_secuencial' in f and f.endswith('.csv'):
            csv_files.append(os.path.join(root, f))

# Leer cada archivo CSV y asignarlo a una variable
for f in csv_files:
    # Obtener el nombre del archivo sin la extensión
    name = os.path.splitext(os.path.basename(f))[0]
    # Leer el archivo CSV y asignarlo a una variable con el nombre del archivo
    vars()[name] = pd.read_csv(f)

# Imprimir los nombres de las variables creadas que contengan "_secuencial"
print("Los siguientes DataFrames se han creado:")
for var in sorted(vars()):
    if '_secuencial' in var:
        print(var)
# Out:
# Los siguientes DataFrames se han creado:
# arbitrum_bear_secuencial_datos
# arbitrum_bear_secuencial_total
# arbitrum_secuencial_datos
# arbitrum_secuencial_total
# avalanche_secuencial_datos
# avalanche_secuencial_total
# boba_secuencial_total
# celo_secuencial_datos
# celo_secuencial_total
# goerli_secuencial_datos
# goerli_secuencial_total
# optimism_bear_secuencial_datos
# optimism_bear_secuencial_total
# optimism_secuencial_datos
# optimism_secuencial_total
# polygon_bear_secuencial_datos
# polygon_bear_secuencial_total
# sepolia_bear_secuencial_datos
# sepolia_bear_secuencial_total
# sepolia_secuencial_datos
# sepolia_secuencial_total

# %%
sepolia_secuencial_datos
# Out:
#                                           Transacción  Estado Gas utilizado  \
# 0   0x077cb3e6ff194f3729523b84ea838d2f11952bfde8a1...    True       0x10f60
# 1   0xb4479ebe8f4e6b71d09a5a2fd19426676ab5e5ae90fd...    True       0x10f6c
# 2   0x2bc1727c89dc7cf06a86e664b0d79841c83a46ba53be...    True       0x10f6c
# 3   0xe08b3925bce33c104117e0255ff47ce606cfaf4dc317...    True        0xcca0
# 4   0xe2d7bb2a681fb1a8a107888dbb5a44702e3e81ae4cba...    True        0xcca0
# 5   0x21f480de3345e99e772245b7079429651032257731d5...    True        0xcca0
# 6   0xf832a71f35f4b2ea62d5f5b98cac88635f6e483709cb...    True        0xcca0
# 7   0x90a142493b649a0d3c1d5135f31dc00117b4b3807c56...    True        0xcca0
# 8   0x42980e4e05256428e3dc7f58ce5049c2394437d092fb...    True        0xcca0
# 9   0xdb9086ae4d7c0e1af3646a0de9a5ea92ce1ee63ae432...    True        0xcca0
# 10  0xced68f6587222d6610ee74cfb5cd06ec022f8b5f4214...    True        0xcca0
# 11  0xcb138568106e7d9b41ce9c86eb12540c07e3a81aeb72...    True        0xcca0
# 12  0x4a27aec2e5a78d4d01a23e0d79bb3ef07528a88da9ae...    True        0x7245
# 13  0x3261dc73a32b9512af993ce4a702d2cc76999a804b69...    True        0x7251
# 14  0x31c1abef541f35346003bc763cae028beb6835be0c5b...    True        0x7251
# 15  0xddc81f25622443344abfce9edfa1372bfb462d7e26aa...    True        0x7251
# 16  0x01669bd96ea3db55c6e2faf580ccdbc411b4476d0944...    True        0x7251
# 17  0xc8511b4d2338ab84b5851a78168c81f5d8a7eda179ab...    True        0x7251
# 18  0x59466cc0d655e8911edcbab98d0d65993b0a21e6da26...    True        0x7251
# 19  0xe02fcf7c392a437a0ecc18d07e82b5432a45772ca992...    True        0x7251
# 20  0x2f09a60507da3f46cbfba99a3c3bc0f237645bfa1ed9...    True        0x7251
# 21  0x393f43f6a7bbdd2ca33da043e81b6c8418028b4e9efc...    True        0x7251
# 22  0x1982851616af9e81e3af8a9827b737e30f7025d64dae...    True        0x7251
# 23  0xf9f47ae4994c600ade0b7a2b402373c16fe137f6a972...    True        0x7251
# 24  0xb9520fac9ddf2bce1743ff4a4e2cc5da7d1942ae31ed...    True        0x7895
#
#     Coste en wei   Bloque    Tiempo
# 0       0.000069  3287900  03:17:48
# 1       0.000069  3287901  03:18:00
# 2       0.000069  3287902  03:18:12
# 3       0.000052  3287903  03:18:24
# 4       0.000052  3287904  03:18:36
# 5       0.000052  3287905  03:19:00
# 6       0.000052  3287906  03:19:12
# 7       0.000052  3287907  03:19:36
# 8       0.000052  3287908  03:19:48
# 9       0.000052  3287909  03:20:00
# 10      0.000052  3287910  03:20:12
# 11      0.000052  3287911  03:20:24
# 12      0.000029  3287912  03:20:36
# 13      0.000029  3287913  03:20:48
# 14      0.000029  3287914  03:21:00
# 15      0.000029  3287915  03:21:12
# 16      0.000029  3287916  03:21:24
# 17      0.000029  3287917  03:21:36
# 18      0.000029  3287918  03:21:48
# 19      0.000029  3287919  03:22:00
# 20      0.000029  3287920  03:22:12
# 21      0.000029  3287921  03:22:24
# 22      0.000029  3287922  03:22:36
# 23      0.000029  3287923  03:22:48
# 24      0.000031  3287924  03:23:00

# %%
sepolia_secuencial_total
# Out:
#    Creadas  Coste en gas (wei)  Coste en ether  Empezar  Acabar  Duracion
# 0       25    1061933009557397        0.001062      325  332304    331979

# %% [markdown]
# ### Creamos un diccionario

# %%
import numpy as np
import pandas as pd
import os

# Obtener la lista de carpetas en la carpeta datos/secuencial/
carpetas = [f for f in os.listdir('datos/secuencial/') if os.path.isdir(os.path.join('datos/secuencial/', f))]

# Crear un diccionario vacío para almacenar los DataFrames
datasets_resumen = {}

# Leer cada archivo CSV en cada carpeta y asignarlo a una variable con el nombre de la carpeta
for carpeta in carpetas:
    csv_files = [f for f in os.listdir(os.path.join('datos/secuencial/', carpeta)) if f.endswith('_datos.csv')]
    for f in csv_files:
        name = os.path.splitext(f)[0]
        vars()[name] = pd.read_csv(os.path.join('datos/secuencial/', carpeta, f))
        datasets_resumen[name] = eval(name)

# Imprimir los nombres de las variables creadas que contengan "_secuencial"
print("Los siguientes DataFrames se han creado:")
for var in sorted(datasets_resumen.keys()):
    print(var)
# Out:
# Los siguientes DataFrames se han creado:
# arbitrum_bear_secuencial_datos
# arbitrum_secuencial_datos
# avalanche_secuencial_datos
# celo_secuencial_datos
# goerli_secuencial_datos
# optimism_bear_secuencial_datos
# optimism_secuencial_datos
# polygon_bear_secuencial_datos
# sepolia_bear_secuencial_datos
# sepolia_secuencial_datos

# %%
import numpy as np
import pandas as pd
import os

# Obtener la lista de carpetas en la carpeta datos/secuencial/
carpetas = [f for f in os.listdir('datos/secuencial/') if os.path.isdir(os.path.join('datos/secuencial/', f))]

# Crear un diccionario vacío para almacenar los DataFrames
datasets_resumen = {}

# Leer cada archivo CSV en cada carpeta y asignarlo a una variable con el nombre de la carpeta
for carpeta in carpetas:
    csv_files = [f for f in os.listdir(os.path.join('datos/secuencial/', carpeta)) if f.endswith('_datos.csv')]
    for f in csv_files:
        name = os.path.splitext(f)[0]
        name_without_suffix = name.replace('_secuencial_datos', '')
        vars()[name] = pd.read_csv(os.path.join('datos/secuencial/', carpeta, f))
        datasets_resumen[name_without_suffix] = eval(name)

# Imprimir los nombres de las variables creadas que contengan "_secuencial"
print("Los siguientes DataFrames se han creado:")
for var in sorted(datasets_resumen.keys()):
    print(var)
# Out:
# Los siguientes DataFrames se han creado:
# arbitrum
# arbitrum_bear
# avalanche
# celo
# goerli
# optimism
# optimism_bear
# polygon_bear
# sepolia
# sepolia_bear

# %% [markdown]
# # Preprocesamos

# %% [markdown]
# ### Añadimos columna que sea la diferencia de tiempos entre transacciones y otra que sea Duración

# %% [markdown]
# Duración: Es la suma de las transacciones anteriores para ver como va aumentando el tiempo con la suma de transaccioens

# %% [markdown]
# #### Crear una lista con los nombres de los datasets

# %%
import os

# Obtener la lista de carpetas en la carpeta datos/secuencial/
carpetas = [f for f in os.listdir('datos/secuencial/') if os.path.isdir(os.path.join('datos/secuencial/', f))]

# Crear una lista para almacenar los nombres de los datasets
datasets = []

# Leer cada archivo CSV en cada carpeta y agregarlo a la lista datasets si termina en "_datos.csv"
for carpeta in carpetas:
    csv_files = [f for f in os.listdir(os.path.join('datos/secuencial/', carpeta)) if f.endswith('_datos.csv')]
    for f in csv_files:
        datasets.append(os.path.splitext(f)[0])

# Imprimir los nombres de los datasets creados
print("Los siguientes datasets se han creado:")
for dataset in datasets:
    print(dataset)
# Out:
# Los siguientes datasets se han creado:
# goerli_secuencial_datos
# arbitrum_secuencial_datos
# avalanche_secuencial_datos
# optimism_secuencial_datos
# optimism_bear_secuencial_datos
# celo_secuencial_datos
# sepolia_bear_secuencial_datos
# arbitrum_bear_secuencial_datos
# sepolia_secuencial_datos
# polygon_bear_secuencial_datos

# %%
# Iterar sobre la lista de nombres de datasets
for dataset in datasets:
    # Convertir la columna "Tiempo" a tipo datetime
    globals()[dataset]["Tiempo"] = pd.to_datetime(globals()[dataset]["Tiempo"])

    # Calcular la diferencia de tiempo entre cada fila y la anterior, en segundos
    globals()[dataset]["Diferencia de tiempo"] = (globals()[dataset]["Tiempo"] - globals()[dataset]["Tiempo"].shift(1)).dt.total_seconds()

    # Inicializar el primer valor de la columna "Duración" con el valor de la primera fila de la columna "Diferencia de tiempo"
    globals()[dataset].loc[0, "Duración"] = globals()[dataset].loc[0, "Diferencia de tiempo"]

    # Sumar el primer valor de la columna "Duración" al resto de los valores en la columna "Duración"
    globals()[dataset]["Duración"] = globals()[dataset]["Duración"] + globals()[dataset].loc[0, "Duración"]

    # Sumar la columna "Diferencia de tiempo" al resto de los valores en la columna "Duración"
    globals()[dataset]["Duración"] = globals()[dataset]["Diferencia de tiempo"].cumsum().fillna(method='ffill')

    # Calcular la media de la columna "Diferencia de tiempo"
    media_diferencia_tiempo = globals()[dataset]["Diferencia de tiempo"].mean()

    # Reemplazar los valores NaN con la media de las otras filas
    globals()[dataset]["Diferencia de tiempo"].fillna(media_diferencia_tiempo, inplace=True)
    # Reemplazar los valores NaN con la media de las otras filas
    globals()[dataset]["Duración"].fillna(globals()[dataset]["Diferencia de tiempo"][0], inplace=True)

# %%
# Iterar sobre la lista de nombres de datasets, pero saltarse la primera iteración
for dataset in datasets:
    globals()[dataset]["Duración"] =  globals()[dataset]["Duración"] +  globals()[dataset]["Duración"][0]

# %%
# Iterar sobre la lista de nombres de datasets
for dataset in datasets:
    # Modificar el valor de Duración de la primera fila en el DataFrame original
    globals()[dataset].loc[0, "Duración"] = globals()[dataset]["Diferencia de tiempo"][0]

# %% [markdown]
# ### Pasamos de hexadecimal a decimal Gas utilizado

# %%
#Gas utilizado 
import pandas as pd

def hex_to_dec(datos):
    # Convierte la columna "Gas utilizado" de hexadecimal a decimal
    datos["Gas utilizado"] = datos["Gas utilizado"].apply(lambda x: int(x, 16))
    
    # Devuelve el DataFrame modificado
    return datos


# Iterar sobre la lista de nombres de datasets
for dataset in datasets:
    # Aplicar la función a la columna "Gas utilizado" del DataFrame
    globals()[dataset] = hex_to_dec(globals()[dataset])
    
    # Imprimir el DataFrame resultante
    print(globals()[dataset].head())
# Out:
#                                          Transacción  Estado  Gas utilizado  \
# 0  0x558f599a705443df2c2344ac1c918a3f7e3aee376f18...    True          69472
# 1  0xfaa0f2e7e2cb175cac8fdd1f5374763604de79264aab...    True          69484
# 2  0x3d56897ff6be097b0d0f5883c93294f0afa1b6bc3d0a...    True          69484
# 3  0x235d5dc3158ba7685d1805579c64dec5bcbfd9202915...    True          52384
# 4  0x906a89c0105ea0a3b3092976859e3ff64df7a5eea9a3...    True          52384
#
#    Coste en wei   Bloque              Tiempo  Diferencia de tiempo  Duración
# 0      0.000002  8852430 2023-04-19 03:17:48                  18.0      18.0
# 1      0.000001  8852431 2023-04-19 03:18:00                  12.0      30.0
# 2      0.000002  8852432 2023-04-19 03:18:36                  36.0      66.0
# 3      0.000001  8852433 2023-04-19 03:18:48                  12.0      78.0
# 4      0.000001  8852434 2023-04-19 03:19:00                  12.0      90.0
#                                          Transacción  Estado  Gas utilizado  \
# 0  0x8b38451f53fc4fc2e530797fcd336826012b19cbb516...    True          69472
# 1  0x59532e68c65f2fbbd8ebe06979c94ea95352b9a5111c...    True          69484
# 2  0x024f325c51a35f15b9f3fd3e1651d6885664c535f09c...    True          69484
# 3  0xb5d19fa0a77b436533a21a03f634ccea6ba82026b75b...    True          52384
# 4  0x84f1d84f941c4ae674a1f3c2afed7616e6bce4095f97...    True          52384
#
#    Coste en wei    Bloque              Tiempo  Diferencia de tiempo  Duración
# 0      0.000007  16948423 2023-04-19 02:41:31                  2.25      2.25
# 1      0.000007  16948428 2023-04-19 02:41:33                  2.00      4.25
# 2      0.000007  16948433 2023-04-19 02:41:36                  3.00      7.25
# 3      0.000005  16948437 2023-04-19 02:41:38                  2.00      9.25
# 4      0.000005  16948442 2023-04-19 02:41:40                  2.00     11.25
#                                          Transacción  Estado  Gas utilizado  \
# 0  0xc2c0546e65e61d7c950970d9609401a0fb1365aacc1d...    True          69472
# 1  0x96c04baab5c727fc254fb23e4d2fd2ce4775ea5af1cb...    True          69484
# 2  0xcaf72e2df3156dc196274e8464b17f4af2873d0aceab...    True          69484
# 3  0x1dc8b4e7a522112340de32fb9d287ef30ea4fb75bcee...    True          52384
# 4  0x8e3b9f51b8bc4130238034fdb694bb40a4eeda66aefb...    True          52384
#
#    Coste en wei    Bloque              Tiempo  Diferencia de tiempo   Duración
# 0      0.001737  20978944 2023-04-19 02:43:47              5.916667   5.916667
# 1      0.001737  20978945 2023-04-19 02:43:54              7.000000  12.916667
# 2      0.001737  20978947 2023-04-19 02:43:59              5.000000  17.916667
# 3      0.001310  20978948 2023-04-19 02:44:04              5.000000  22.916667
# 4      0.001310  20978950 2023-04-19 02:44:10              6.000000  28.916667
#                                          Transacción  Estado  Gas utilizado  \
# 0  0xee91c9a5ecadc787e3261190de328d87ecf25567ab1e...    True          69472
# 1  0x7a77edeb3c5e1d700b68f731e305a954dcbb1bca38c7...    True          69484
# 2  0xb2492c23aeb92cfd651e4b08fe7c958662b3a3a4ac78...    True          69484
# 3  0x269bfd8d1aa137f1210449d6789c7683e59b37408dc4...    True          52384
# 4  0xe603f73e9beb0b3598ef2d50f15b93ef56e7d9f2d167...    True          52384
#
#    Coste en wei   Bloque              Tiempo  Diferencia de tiempo  Duración
# 0      0.034736  8213209 2023-04-19 02:48:06                   6.0       6.0
# 1      0.034742  8213213 2023-04-19 02:48:14                   8.0      14.0
# 2      0.034742  8213215 2023-04-19 02:48:18                   4.0      18.0
# 3      0.026192  8213218 2023-04-19 02:48:24                   6.0      24.0
# 4      0.026192  8213221 2023-04-19 02:48:30                   6.0      30.0
#                                          Transacción  Estado  Gas utilizado  \
# 0  0x36738546e6c6b9100534f2e24fe4cdc1597cda0fff3c...    True          69472
# 1  0x39d2b879f54f504fe73fe45259ae61008103e502b9cf...    True          69484
# 2  0x0c53c774d8604870e87a5c34961c215031a5fa59efd7...    True          69484
# 3  0x139fd1176be728d5efa9c2ac2ee8d7875ce6cecc3f5d...    True          52384
# 4  0x635a53e0fd9173c33b78d97514ba4cd614605a2f93eb...    True          52384
#
#    Coste en wei    Bloque              Tiempo  Diferencia de tiempo   Duración
# 0      0.000107  91823083 2023-04-19 01:08:21              3.041667   3.041667
# 1      0.000102  91823084 2023-04-19 01:08:24              3.000000   6.041667
# 2      0.000098  91823085 2023-04-19 01:08:27              3.000000   9.041667
# 3      0.000071  91823086 2023-04-19 01:08:30              3.000000  12.041667
# 4      0.000069  91823087 2023-04-19 01:08:33              3.000000  15.041667
#                                          Transacción  Estado  Gas utilizado  \
# 0  0xd79e7e2e53cc1f6f1fb13a8c36893aceaf3b7a90d2fa...    True          65572
# 1  0x030a747d12f8b9d7ad7c8a0bbdac807e1a7dd0ebdb57...    True          65584
# 2  0xeb4c2d9130d47eafe2ee9f0601a9bd1114f75702def3...    True          65584
# 3  0xf5e2695ed79dc4bf95d3cdd97f0d1af031c3fa42f96e...    True          49784
# 4  0x2c1c385761d3b85eb6ced76c0580b473e93a87882979...    True          49784
#
#    Coste en wei    Bloque              Tiempo  Diferencia de tiempo   Duración
# 0      0.001639  17287188 2023-04-19 01:20:44              5.416667   5.416667
# 1      0.001640  17287189 2023-04-19 01:20:49              5.000000  10.416667
# 2      0.001640  17287190 2023-04-19 01:20:54              5.000000  15.416667
# 3      0.001245  17287191 2023-04-19 01:20:59              5.000000  20.416667
# 4      0.001245  17287192 2023-04-19 01:21:04              5.000000  25.416667
#                                          Transacción  Estado  Gas utilizado  \
# 0  0x7a7093f0b1265d74707de1b44f196c41106625cef5e4...    True          69472
# 1  0x94f05d6301fd75952ba8cbc1cf5be2759d66fcde8999...    True          69484
# 2  0xf015c3d0b85c27e8f05a13ac064b6dbfbb929c7de694...    True          69484
# 3  0x62a047075cdca8a9f5bec60d74edfb103efc2aa4a0d2...    True          52384
# 4  0xbd4c7203140db7aee18c747543cc2eca9d5f765d0267...    True          52384
#
#    Coste en wei   Bloque              Tiempo  Diferencia de tiempo   Duración
# 0      0.000069  3318724 2023-04-19 12:32:27              3.083333   3.083333
# 1      0.000069  3318725 2023-04-19 12:32:31              4.000000   7.083333
# 2      0.000069  3318726 2023-04-19 12:32:34              3.000000  10.083333
# 3      0.000052  3318727 2023-04-19 12:32:36              2.000000  12.083333
# 4      0.000052  3318728 2023-04-19 12:32:39              3.000000  15.083333
#                                          Transacción  Estado  Gas utilizado  \
# 0  0x9b10a2d349c2fdc7280128d62498c1fb91d282ccd3a9...    True          69472
# 1  0x893bebf3ac28f16654e26669887fdd1226ce27504ef5...    True          69484
# 2  0x14b8cb534a7017fefc18069edc9453ef16e998f0b67d...    True          69484
# 3  0x9108af0f78f43633437a5f4146ba746a50652428b950...    True          52384
# 4  0x580cce11836291faffe00d71b1fdf6f093506f56ea16...    True          52384
#
#    Coste en wei    Bloque              Tiempo  Diferencia de tiempo  Duración
# 0      0.000073  81696822 2023-04-19 02:20:59                   3.0       3.0
# 1      0.000073  81696823 2023-04-19 02:21:02                   3.0       6.0
# 2      0.000072  81696824 2023-04-19 02:21:05                   3.0       9.0
# 3      0.000054  81696825 2023-04-19 02:21:08                   3.0      12.0
# 4      0.000054  81696826 2023-04-19 02:21:11                   3.0      15.0
#                                          Transacción  Estado  Gas utilizado  \
# 0  0x077cb3e6ff194f3729523b84ea838d2f11952bfde8a1...    True          69472
# 1  0xb4479ebe8f4e6b71d09a5a2fd19426676ab5e5ae90fd...    True          69484
# 2  0x2bc1727c89dc7cf06a86e664b0d79841c83a46ba53be...    True          69484
# 3  0xe08b3925bce33c104117e0255ff47ce606cfaf4dc317...    True          52384
# 4  0xe2d7bb2a681fb1a8a107888dbb5a44702e3e81ae4cba...    True          52384
#
#    Coste en wei   Bloque              Tiempo  Diferencia de tiempo  Duración
# 0      0.000069  3287900 2023-04-19 03:17:48                  13.0      13.0
# 1      0.000069  3287901 2023-04-19 03:18:00                  12.0      25.0
# 2      0.000069  3287902 2023-04-19 03:18:12                  12.0      37.0
# 3      0.000052  3287903 2023-04-19 03:18:24                  12.0      49.0
# 4      0.000052  3287904 2023-04-19 03:18:36                  12.0      61.0
#                                          Transacción  Estado  Gas utilizado  \
# 0  0xcf7270689993a9d9a50b0f36cce3e7fd505c90df7e03...    True          69472
# 1  0xce8513ea50d261faede47cf3682df37180978bde55ba...    True          69484
# 2  0x10df309d7527f7da0fc0a1cc1cc12a061ded48749c6d...    True          69484
# 3  0x1e1bc27c7269528d0aebe8761ec505120ef75c4e66c1...    True          52384
# 4  0x04fbe0c54cf700969e9fb4555532236c257375cd6b4e...    True          52384
#
#    Coste en wei    Bloque              Tiempo  Diferencia de tiempo   Duración
# 0      0.007779  41666828 2023-04-19 02:34:52              3.708333   3.708333
# 1      0.006821  41666829 2023-04-19 02:34:55              3.000000   6.708333
# 2      0.005981  41666830 2023-04-19 02:34:58              3.000000   9.708333
# 3      0.003954  41666831 2023-04-19 02:35:01              3.000000  12.708333
# 4      0.003468  41666832 2023-04-19 02:35:04              3.000000  15.708333

# %%
goerli_secuencial_datos
# Out:
#                                           Transacción  Estado  Gas utilizado  \
# 0   0x558f599a705443df2c2344ac1c918a3f7e3aee376f18...    True          69472
# 1   0xfaa0f2e7e2cb175cac8fdd1f5374763604de79264aab...    True          69484
# 2   0x3d56897ff6be097b0d0f5883c93294f0afa1b6bc3d0a...    True          69484
# 3   0x235d5dc3158ba7685d1805579c64dec5bcbfd9202915...    True          52384
# 4   0x906a89c0105ea0a3b3092976859e3ff64df7a5eea9a3...    True          52384
# 5   0x96727d2042b8db7107ba8cd47bfe4d03ef14702b1dff...    True          52384
# 6   0xeca32227f92c987d3d4162785ee18084690310c12060...    True          52384
# 7   0x448dfd0adc345f61ff433457c224bac582296b368fa1...    True          52384
# 8   0x30484d5e39bcb904b40b70ca28608e8a86f9d6e79b91...    True          52384
# 9   0xe83fd5c4400129f1908c999784022173ca14a3d67b39...    True          52384
# 10  0x04040b5ad38d84fbc6cc7425419756c0c06fbda37b52...    True          52384
# 11  0xfae64da078138e1bc5970c62d37d0d6e78be8fe3668a...    True          52384
# 12  0x478ea5a476efb76a0a3a378ba735aa8bc514e56b2ef6...    True          29253
# 13  0xae97c9f943baae3e44c95e1d287a59cf3502e99b1924...    True          29265
# 14  0xcae466b0a931db49a4638bee479f47b82276f63968bc...    True          29265
# 15  0xbac50527669e25a2c99398615e1ab2b64589a2f08e1e...    True          29265
# 16  0x7f06685a0a36e05b8504b3c18e83545c0d1ee3069b67...    True          29265
# 17  0x3eea94ca844cc55623e98b45e1981c697c04af3d6ecc...    True          29265
# 18  0x2a29eccdec8acbb2b695b23acc8a11c1e21f245b025a...    True          29265
# 19  0x6e6bbf3a00198e54417fcf45a9b405b7fcb28b6cb65f...    True          29265
# 20  0x6d41b8878488f7eef16490ef22c8804b41f094594cf3...    True          29265
# 21  0x94be5424288a00960e4f3581511ace73df7eb4912265...    True          29265
# 22  0x73e0e9d3cc55d9e304883bfbd1602910d722b6a68d55...    True          29265
# 23  0x53ad47c50a55108fe63447160c1efc53ed0a28604a70...    True          29265
# 24  0x0a0640dc7a2f486f45749885693dc08cbc59e1c18dd3...    True          30869
#
#     Coste en wei   Bloque              Tiempo  Diferencia de tiempo  Duración
# 0   1.627711e-06  8852430 2023-04-19 03:17:48                  18.0      18.0
# 1   1.473751e-06  8852431 2023-04-19 03:18:00                  12.0      30.0
# 2   1.645658e-06  8852432 2023-04-19 03:18:36                  36.0      66.0
# 3   1.360373e-06  8852433 2023-04-19 03:18:48                  12.0      78.0
# 4   1.291193e-06  8852434 2023-04-19 03:19:00                  12.0      90.0
# 5   1.262286e-06  8852435 2023-04-19 03:19:12                  12.0     102.0
# 6   1.223915e-06  8852436 2023-04-19 03:19:36                  24.0     126.0
# 7   1.317388e-06  8852437 2023-04-19 03:19:48                  12.0     138.0
# 8   1.219251e-06  8852438 2023-04-19 03:20:00                  12.0     150.0
# 9   1.148914e-06  8852439 2023-04-19 03:20:12                  12.0     162.0
# 10  1.103115e-06  8852440 2023-04-19 03:20:24                  12.0     174.0
# 11  1.042624e-06  8852441 2023-04-19 03:20:48                  24.0     198.0
# 12  5.657650e-07  8852442 2023-04-19 03:21:00                  12.0     210.0
# 13  5.275546e-07  8852443 2023-04-19 03:21:12                  12.0     222.0
# 14  4.912893e-07  8852444 2023-04-19 03:21:36                  24.0     246.0
# 15  4.817028e-07  8852445 2023-04-19 03:22:12                  36.0     282.0
# 16  4.949481e-07  8852446 2023-04-19 03:22:24                  12.0     294.0
# 17  4.547409e-07  8852447 2023-04-19 03:22:48                  24.0     318.0
# 18  4.609094e-07  8852448 2023-04-19 03:23:00                  12.0     330.0
# 19  4.333441e-07  8852449 2023-04-19 03:23:12                  12.0     342.0
# 20  4.153742e-07  8852450 2023-04-19 03:23:48                  36.0     378.0
# 21  4.504176e-07  8852451 2023-04-19 03:24:24                  36.0     414.0
# 22  4.697864e-07  8852452 2023-04-19 03:24:36                  12.0     426.0
# 23  4.382935e-07  8852453 2023-04-19 03:24:48                  12.0     438.0
# 24  4.458534e-07  8852454 2023-04-19 03:25:00                  12.0     450.0

# %% [markdown]
# # Comparativa

# %% [markdown]
# ### Comparativa de Coste de Wei (Ambas graficas)

# %%
datasets_resumen
# Out:
# {'goerli':                                           Transacción  Estado  Gas utilizado  \
#  0   0x558f599a705443df2c2344ac1c918a3f7e3aee376f18...    True          69472
#  1   0xfaa0f2e7e2cb175cac8fdd1f5374763604de79264aab...    True          69484
#  2   0x3d56897ff6be097b0d0f5883c93294f0afa1b6bc3d0a...    True          69484
#  3   0x235d5dc3158ba7685d1805579c64dec5bcbfd9202915...    True          52384
#  4   0x906a89c0105ea0a3b3092976859e3ff64df7a5eea9a3...    True          52384
#  5   0x96727d2042b8db7107ba8cd47bfe4d03ef14702b1dff...    True          52384
#  6   0xeca32227f92c987d3d4162785ee18084690310c12060...    True          52384
#  7   0x448dfd0adc345f61ff433457c224bac582296b368fa1...    True          52384
#  8   0x30484d5e39bcb904b40b70ca28608e8a86f9d6e79b91...    True          52384
#  9   0xe83fd5c4400129f1908c999784022173ca14a3d67b39...    True          52384
#  10  0x04040b5ad38d84fbc6cc7425419756c0c06fbda37b52...    True          52384
#  11  0xfae64da078138e1bc5970c62d37d0d6e78be8fe3668a...    True          52384
#  12  0x478ea5a476efb76a0a3a378ba735aa8bc514e56b2ef6...    True          29253
#  13  0xae97c9f943baae3e44c95e1d287a59cf3502e99b1924...    True          29265
#  14  0xcae466b0a931db49a4638bee479f47b82276f63968bc...    True          29265
#  15  0xbac50527669e25a2c99398615e1ab2b64589a2f08e1e...    True          29265
#  16  0x7f06685a0a36e05b8504b3c18e83545c0d1ee3069b67...    True          29265
#  17  0x3eea94ca844cc55623e98b45e1981c697c04af3d6ecc...    True          29265
#  18  0x2a29eccdec8acbb2b695b23acc8a11c1e21f245b025a...    True          29265
#  19  0x6e6bbf3a00198e54417fcf45a9b405b7fcb28b6cb65f...    True          29265
#  20  0x6d41b8878488f7eef16490ef22c8804b41f094594cf3...    True          29265
#  21  0x94be5424288a00960e4f3581511ace73df7eb4912265...    True          29265
#  22  0x73e0e9d3cc55d9e304883bfbd1602910d722b6a68d55...    True          29265
#  23  0x53ad47c50a55108fe63447160c1efc53ed0a28604a70...    True          29265
#  24  0x0a0640dc7a2f486f45749885693dc08cbc59e1c18dd3...    True          30869
#
#      Coste en wei   Bloque              Tiempo  Diferencia de tiempo  Duración
#  0   1.627711e-06  8852430 2023-04-19 03:17:48                  18.0      18.0
#  1   1.473751e-06  8852431 2023-04-19 03:18:00                  12.0      30.0
#  2   1.645658e-06  8852432 2023-04-19 03:18:36                  36.0      66.0
#  3   1.360373e-06  8852433 2023-04-19 03:18:48                  12.0      78.0
#  4   1.291193e-06  8852434 2023-04-19 03:19:00                  12.0      90.0
#  5   1.262286e-06  8852435 2023-04-19 03:19:12                  12.0     102.0
#  6   1.223915e-06  8852436 2023-04-19 03:19:36                  24.0     126.0
#  7   1.317388e-06  8852437 2023-04-19 03:19:48                  12.0     138.0
#  8   1.219251e-06  8852438 2023-04-19 03:20:00                  12.0     150.0
#  9   1.148914e-06  8852439 2023-04-19 03:20:12                  12.0     162.0
#  10  1.103115e-06  8852440 2023-04-19 03:20:24                  12.0     174.0
#  11  1.042624e-06  8852441 2023-04-19 03:20:48                  24.0     198.0
#  12  5.657650e-07  8852442 2023-04-19 03:21:00                  12.0     210.0
#  13  5.275546e-07  8852443 2023-04-19 03:21:12                  12.0     222.0
#  14  4.912893e-07  8852444 2023-04-19 03:21:36                  24.0     246.0
#  15  4.817028e-07  8852445 2023-04-19 03:22:12                  36.0     282.0
#  16  4.949481e-07  8852446 2023-04-19 03:22:24                  12.0     294.0
#  17  4.547409e-07  8852447 2023-04-19 03:22:48                  24.0     318.0
#  18  4.609094e-07  8852448 2023-04-19 03:23:00                  12.0     330.0
#  19  4.333441e-07  8852449 2023-04-19 03:23:12                  12.0     342.0
#  20  4.153742e-07  8852450 2023-04-19 03:23:48                  36.0     378.0
#  21  4.504176e-07  8852451 2023-04-19 03:24:24                  36.0     414.0
#  22  4.697864e-07  8852452 2023-04-19 03:24:36                  12.0     426.0
#  23  4.382935e-07  8852453 2023-04-19 03:24:48                  12.0     438.0
#  24  4.458534e-07  8852454 2023-04-19 03:25:00                  12.0     450.0  ,
#  'arbitrum':                                           Transacción  Estado  Gas utilizado  \
#  0   0x8b38451f53fc4fc2e530797fcd336826012b19cbb516...    True          69472
#  1   0x59532e68c65f2fbbd8ebe06979c94ea95352b9a5111c...    True          69484
#  2   0x024f325c51a35f15b9f3fd3e1651d6885664c535f09c...    True          69484
#  3   0xb5d19fa0a77b436533a21a03f634ccea6ba82026b75b...    True          52384
#  4   0x84f1d84f941c4ae674a1f3c2afed7616e6bce4095f97...    True          52384
#  5   0x762098f31d2693089a7de10f9e042fb75b5c8c489f3f...    True          52384
#  6   0x94f84cc9804055c06f5ae19f77772148c64398c64cea...    True          52384
#  7   0xd83b2b327263f591087adac59ca12413d35f9360ddca...    True          52384
#  8   0x71105fa0332a79d71bf1527e08d84f93cc488d7ed30e...    True          52384
#  9   0x8f3642d6a8087af3481fc3d8dee64a6b151f4538f49a...    True          52384
#  10  0x65669a2b25238b4cd7fb7c9f60dab89f07462a55ec5c...    True          52384
#  11  0xe7ee81e817e652d9b904e24f9f164f92803981c6fb32...    True          52384
#  12  0xa8674e67439a6046b0487bbdace00f735d24bc57fdaa...    True          29253
#  13  0x5f56dd126cdb568148a795d6f316a30363906387ad85...    True          29265
#  14  0x0a86136f3623ff61d0a2b57b757f8823e5c6997d5bdd...    True          29265
#  15  0x456b5d848fec7314dd9176ea75a8b5773758aced4c56...    True          29265
#  16  0x969849f8054fda94946b5a3688e6a8bfd013e5df2e86...    True          29265
#  17  0x684f799b827efc2a9a3047788d049ea813750f5be158...    True          29265
#  18  0xe324c0ce676cb358bd0240e6ca46e1b5b78a1f425dc0...    True          29265
#  19  0xe85f17add1a910d310d9b7e9129c5b8cb2e32e4612df...    True          29265
#  20  0x4053c353f5a18130f2fbf662d964f78ac41b4dc6ca2b...    True          29265
#  21  0xa5d9473e45bc895c2680bc1c1cfa8170fa3c684c03e9...    True          29265
#  22  0x909016954abe2b3436dc355926e0710b3d7cc33c6ba2...    True          29265
#  23  0xa661981ff2856c69452df6dd3c16780dc612a78c1149...    True          29265
#  24  0x6633a3c82004ff47f0722e30c62b680374d67ebf5331...    True          30869
#
#      Coste en wei    Bloque              Tiempo  Diferencia de tiempo  Duración
#  0       0.000007  16948423 2023-04-19 02:41:31                  2.25      2.25
#  1       0.000007  16948428 2023-04-19 02:41:33                  2.00      4.25
#  2       0.000007  16948433 2023-04-19 02:41:36                  3.00      7.25
#  3       0.000005  16948437 2023-04-19 02:41:38                  2.00      9.25
#  4       0.000005  16948442 2023-04-19 02:41:40                  2.00     11.25
#  5       0.000005  16948446 2023-04-19 02:41:42                  2.00     13.25
#  6       0.000005  16948449 2023-04-19 02:41:45                  3.00     16.25
#  7       0.000005  16948453 2023-04-19 02:41:47                  2.00     18.25
#  8       0.000005  16948460 2023-04-19 02:41:49                  2.00     20.25
#  9       0.000005  16948464 2023-04-19 02:41:51                  2.00     22.25
#  10      0.000005  16948468 2023-04-19 02:41:53                  2.00     24.25
#  11      0.000005  16948472 2023-04-19 02:41:55                  2.00     26.25
#  12      0.000003  16948475 2023-04-19 02:41:58                  3.00     29.25
#  13      0.000003  16948478 2023-04-19 02:42:00                  2.00     31.25
#  14      0.000003  16948482 2023-04-19 02:42:02                  2.00     33.25
#  15      0.000003  16948485 2023-04-19 02:42:04                  2.00     35.25
#  16      0.000003  16948490 2023-04-19 02:42:07                  3.00     38.25
#  17      0.000003  16948494 2023-04-19 02:42:09                  2.00     40.25
#  18      0.000003  16948499 2023-04-19 02:42:11                  2.00     42.25
#  19      0.000003  16948505 2023-04-19 02:42:13                  2.00     44.25
#  20      0.000003  16948509 2023-04-19 02:42:16                  3.00     47.25
#  21      0.000003  16948511 2023-04-19 02:42:18                  2.00     49.25
#  22      0.000003  16948517 2023-04-19 02:42:20                  2.00     51.25
#  23      0.000003  16948520 2023-04-19 02:42:22                  2.00     53.25
#  24      0.000003  16948526 2023-04-19 02:42:25                  3.00     56.25  ,
#  'avalanche':                                           Transacción  Estado  Gas utilizado  \
#  0   0xc2c0546e65e61d7c950970d9609401a0fb1365aacc1d...    True          69472
#  1   0x96c04baab5c727fc254fb23e4d2fd2ce4775ea5af1cb...    True          69484
#  2   0xcaf72e2df3156dc196274e8464b17f4af2873d0aceab...    True          69484
#  3   0x1dc8b4e7a522112340de32fb9d287ef30ea4fb75bcee...    True          52384
#  4   0x8e3b9f51b8bc4130238034fdb694bb40a4eeda66aefb...    True          52384
#  5   0x45b0a7fb14e537291fc70f154903451c676c8adc01d9...    True          52384
#  6   0x086e0979874459980b17fe6f2afd4538ca0869e7e184...    True          52384
#  7   0xfdfb6edf35275b321d2e4a90cea2f5c4059d6dcf0257...    True          52384
#  8   0x6fd4412bec626080af12218cb411483646824c3f0b61...    True          52384
#  9   0x0054e5f5c6752acfbb683acd41fba2ae525920511a8e...    True          52384
#  10  0xb885fcfb5f94040360ad4726fde3298e46ed0ec9e874...    True          52384
#  11  0x4e2e04e3c34fea46ef68e836d1b10877395da2879e19...    True          52384
#  12  0x5398f0f5c38e021fc7d7b76d91c61bdedbe639ded22b...    True          29253
#  13  0xcc8b53ce186b5d0bd4d2e0232f74e2f0ffd3faf106ff...    True          29265
#  14  0xe01778b56f6c0e25714986e8de95851194b3de464428...    True          29265
#  15  0xf555426239186f64940b0ab341de21d902d1ea441471...    True          29265
#  16  0x2df16258b655cc9523d22fc209efdf35ae01977ccef8...    True          29265
#  17  0x776401f0a9195e2083ac5c4ef5062c241e545bef0696...    True          29265
#  18  0x7015039cfe677107b2c16f3a3b98848eac441f067326...    True          29265
#  19  0x602d2edcafc0ef24570a4c051acd93445b895f8e90f2...    True          29265
#  20  0x4eae5aaf8a2530d91411ffb86961d78a479b076110b7...    True          29265
#  21  0x0cf8dae2f92f87b4bbaa05cc1064c225a80dfbbb6413...    True          29265
#  22  0xf9febad2aca79f7130e8af1f3b46e010805d627f41b1...    True          29265
#  23  0xce9c26196f0748698727fedc7da2a08b84d5237fd56c...    True          29265
#  24  0xae60e4d958bea03a5ced728e7c5d92d119b52b780b8a...    True          30869
#
#      Coste en wei    Bloque              Tiempo  Diferencia de tiempo  \
#  0       0.001737  20978944 2023-04-19 02:43:47              5.916667
#  1       0.001737  20978945 2023-04-19 02:43:54              7.000000
#  2       0.001737  20978947 2023-04-19 02:43:59              5.000000
#  3       0.001310  20978948 2023-04-19 02:44:04              5.000000
#  4       0.001310  20978950 2023-04-19 02:44:10              6.000000
#  5       0.001310  20978953 2023-04-19 02:44:17              7.000000
#  6       0.001310  20978955 2023-04-19 02:44:21              4.000000
#  7       0.001310  20978957 2023-04-19 02:44:28              7.000000
#  8       0.001310  20978958 2023-04-19 02:44:32              4.000000
#  9       0.001310  20978960 2023-04-19 02:44:39              7.000000
#  10      0.001310  20978961 2023-04-19 02:44:44              5.000000
#  11      0.001310  20978962 2023-04-19 02:44:51              7.000000
#  12      0.000731  20978964 2023-04-19 02:44:58              7.000000
#  13      0.000732  20978966 2023-04-19 02:45:02              4.000000
#  14      0.000732  20978969 2023-04-19 02:45:08              6.000000
#  15      0.000732  20978972 2023-04-19 02:45:15              7.000000
#  16      0.000732  20978973 2023-04-19 02:45:19              4.000000
#  17      0.000732  20978975 2023-04-19 02:45:28              9.000000
#  18      0.000732  20978977 2023-04-19 02:45:33              5.000000
#  19      0.000732  20978980 2023-04-19 02:45:40              7.000000
#  20      0.000732  20978982 2023-04-19 02:45:45              5.000000
#  21      0.000732  20978985 2023-04-19 02:45:51              6.000000
#  22      0.000732  20978988 2023-04-19 02:45:57              6.000000
#  23      0.000732  20978991 2023-04-19 02:46:03              6.000000
#  24      0.000772  20978994 2023-04-19 02:46:09              6.000000
#
#        Duración
#  0     5.916667
#  1    12.916667
#  2    17.916667
#  3    22.916667
#  4    28.916667
#  5    35.916667
#  6    39.916667
#  7    46.916667
#  8    50.916667
#  9    57.916667
#  10   62.916667
#  11   69.916667
#  12   76.916667
#  13   80.916667
#  14   86.916667
#  15   93.916667
#  16   97.916667
#  17  106.916667
#  18  111.916667
#  19  118.916667
#  20  123.916667
#  21  129.916667
#  22  135.916667
#  23  141.916667
#  24  147.916667  ,
#  'optimism_bear':                                           Transacción  Estado  Gas utilizado  \
#  0   0x36738546e6c6b9100534f2e24fe4cdc1597cda0fff3c...    True          69472
#  1   0x39d2b879f54f504fe73fe45259ae61008103e502b9cf...    True          69484
#  2   0x0c53c774d8604870e87a5c34961c215031a5fa59efd7...    True          69484
#  3   0x139fd1176be728d5efa9c2ac2ee8d7875ce6cecc3f5d...    True          52384
#  4   0x635a53e0fd9173c33b78d97514ba4cd614605a2f93eb...    True          52384
#  5   0xba0615574d67496830055958510b8dfb8d4f88f77e34...    True          52384
#  6   0x996d6693b14d4523fb78c60e74c066ae1b4c66576721...    True          52384
#  7   0x4161e9f475f9de612c469a0cb2d1a7331ce3ddef06c8...    True          52384
#  8   0xb224fd46096b05840fb181e1cafdfd86682e71d8f650...    True          52384
#  9   0xb201db505af19b1f70b35df15a75519859b303427f7f...    True          52384
#  10  0xe54bf337b6301b5de2a2075022c2f69fe38e77f9e87c...    True          52384
#  11  0xb64ecf4f4db6a6ed38ad439c902ce008fdb0955d87fc...    True          52384
#  12  0x51525d2c4efeab70542ed0e4131f6c9bd60ec5575198...    True          29253
#  13  0xc033a99173b1b41e5cf2c48eeec8ee62811ee2308287...    True          29265
#  14  0x03babe4b329b2e8f97f90a987371bb4dac130bc54787...    True          29265
#  15  0x3f22a5a4d4249c885b938aa6763010374a940c9bf008...    True          29265
#  16  0xabd4b27d53fbc59ea498c932c9ebda17654d7d150cf0...    True          29265
#  17  0xffbe63405cc785cfa8a0da7a375c2c3641cfc00e1c96...    True          29265
#  18  0x7be05608f632548550635d65f809aba28d2c581b590b...    True          29265
#  19  0x79cef313dd029e8f0e25c2f6c00ea94642524a63aee9...    True          29265
#  20  0xbd515632645070d89ce23d18c8440c44259dc55a8549...    True          29265
#  21  0xe8911133a6e1164c6bc20bf95b68f680ca08181f2f7a...    True          29265
#  22  0xf1c683855c14ebae7b6a6659c6036322265e06ef77df...    True          29265
#  23  0x457120cad87b1a215224eede05a334553ac81b2909ea...    True          29265
#  24  0xa2aceef8c405eccf3ce83adcaab9451b58e02d16062c...    True          30869
#
#      Coste en wei    Bloque              Tiempo  Diferencia de tiempo  \
#  0       0.000107  91823083 2023-04-19 01:08:21              3.041667
#  1       0.000102  91823084 2023-04-19 01:08:24              3.000000
#  2       0.000098  91823085 2023-04-19 01:08:27              3.000000
#  3       0.000071  91823086 2023-04-19 01:08:30              3.000000
#  4       0.000069  91823087 2023-04-19 01:08:33              3.000000
#  5       0.000067  91823088 2023-04-19 01:08:36              3.000000
#  6       0.000065  91823089 2023-04-19 01:08:39              3.000000
#  7       0.000063  91823090 2023-04-19 01:08:42              3.000000
#  8       0.000062  91823091 2023-04-19 01:08:45              3.000000
#  9       0.000061  91823092 2023-04-19 01:08:48              3.000000
#  10      0.000060  91823093 2023-04-19 01:08:51              3.000000
#  11      0.000059  91823094 2023-04-19 01:08:55              4.000000
#  12      0.000032  91823095 2023-04-19 01:08:57              2.000000
#  13      0.000032  91823096 2023-04-19 01:09:00              3.000000
#  14      0.000032  91823097 2023-04-19 01:09:03              3.000000
#  15      0.000031  91823098 2023-04-19 01:09:07              4.000000
#  16      0.000031  91823099 2023-04-19 01:09:10              3.000000
#  17      0.000031  91823100 2023-04-19 01:09:13              3.000000
#  18      0.000031  91823101 2023-04-19 01:09:16              3.000000
#  19      0.000031  91823102 2023-04-19 01:09:19              3.000000
#  20      0.000030  91823103 2023-04-19 01:09:22              3.000000
#  21      0.000030  91823104 2023-04-19 01:09:25              3.000000
#  22      0.000030  91823105 2023-04-19 01:09:28              3.000000
#  23      0.000030  91823106 2023-04-19 01:09:31              3.000000
#  24      0.000032  91823107 2023-04-19 01:09:34              3.000000
#
#       Duración
#  0    3.041667
#  1    6.041667
#  2    9.041667
#  3   12.041667
#  4   15.041667
#  5   18.041667
#  6   21.041667
#  7   24.041667
#  8   27.041667
#  9   30.041667
#  10  33.041667
#  11  37.041667
#  12  39.041667
#  13  42.041667
#  14  45.041667
#  15  49.041667
#  16  52.041667
#  17  55.041667
#  18  58.041667
#  19  61.041667
#  20  64.041667
#  21  67.041667
#  22  70.041667
#  23  73.041667
#  24  76.041667  ,
#  'celo':                                           Transacción  Estado  Gas utilizado  \
#  0   0xd79e7e2e53cc1f6f1fb13a8c36893aceaf3b7a90d2fa...    True          65572
#  1   0x030a747d12f8b9d7ad7c8a0bbdac807e1a7dd0ebdb57...    True          65584
#  2   0xeb4c2d9130d47eafe2ee9f0601a9bd1114f75702def3...    True          65584
#  3   0xf5e2695ed79dc4bf95d3cdd97f0d1af031c3fa42f96e...    True          49784
#  4   0x2c1c385761d3b85eb6ced76c0580b473e93a87882979...    True          49784
#  5   0x7a3e08ca5ab86f4625748b27f3bc5b5f9c7b1332d997...    True          49784
#  6   0x5744eb486659101d6dc42eb629b35c8b8b685a20aec8...    True          49784
#  7   0x175b6b51be7d03daa788d8d6eadb2055a6e6964225b6...    True          49784
#  8   0x83507b13b26f217486e6efc72d79dbd63ed7f43bae81...    True          49784
#  9   0xd2fd5bf4b45dd3eaf70815883a929c0007fa729f6e72...    True          49784
#  10  0x4820e281eae9649f032198e5b3ef0f6d6c4b62373ca1...    True          49784
#  11  0x4f82e787fe222d2e3e9f6a152bf028cf58f4d7f266b9...    True          49784
#  12  0x4bb52ca1607de5bda54688158450cb597a79150df0a3...    True          25353
#  13  0x4dfa6448698324713b8fc5c3c5899d6fecb1fddb65e7...    True          25365
#  14  0x2102f323f0ac68abec0daae7c482e384469109a22db7...    True          25365
#  15  0x0ba1450733f6eb381f893ebcaf4c779faf648ac4a0bf...    True          25365
#  16  0x3f0af62ee34868b32a58d5805e20913d81df6edc314c...    True          25365
#  17  0xb7b81c2ccdd10be816b40f9f79d9bc92de9f27979245...    True          25365
#  18  0x5f07698b59d43905682f97747ef2d694d8886b9b1209...    True          25365
#  19  0xe43d1815712323d0443159c179d84725860463665383...    True          25365
#  20  0xec3ebcc535b322f45cc2a5dc59b3a895257776d26afe...    True          25365
#  21  0x6e7a540470995a096461e350d366aebbc37c28f415e2...    True          25365
#  22  0xefd66e47c36d7274f11913850ce10c8d674500597835...    True          25365
#  23  0xab3ddf4cca6ea6e471c60a8234e33459b3294a345e51...    True          25365
#  24  0x39b1b977928caa711b1e5d8f4d54daacf7cbff126aea...    True          28269
#
#      Coste en wei    Bloque              Tiempo  Diferencia de tiempo  \
#  0       0.001639  17287188 2023-04-19 01:20:44              5.416667
#  1       0.001640  17287189 2023-04-19 01:20:49              5.000000
#  2       0.001640  17287190 2023-04-19 01:20:54              5.000000
#  3       0.001245  17287191 2023-04-19 01:20:59              5.000000
#  4       0.001245  17287192 2023-04-19 01:21:04              5.000000
#  5       0.001245  17287193 2023-04-19 01:21:09              5.000000
#  6       0.001245  17287194 2023-04-19 01:21:14              5.000000
#  7       0.001245  17287195 2023-04-19 01:21:19              5.000000
#  8       0.001245  17287196 2023-04-19 01:21:24              5.000000
#  9       0.001245  17287197 2023-04-19 01:21:29              5.000000
#  10      0.001245  17287198 2023-04-19 01:21:34              5.000000
#  11      0.001245  17287199 2023-04-19 01:21:39              5.000000
#  12      0.000634  17287200 2023-04-19 01:21:44              5.000000
#  13      0.000634  17287201 2023-04-19 01:21:49              5.000000
#  14      0.000634  17287202 2023-04-19 01:21:54              5.000000
#  15      0.000634  17287203 2023-04-19 01:21:59              5.000000
#  16      0.000634  17287204 2023-04-19 01:22:04              5.000000
#  17      0.000634  17287205 2023-04-19 01:22:09              5.000000
#  18      0.000634  17287208 2023-04-19 01:22:24             15.000000
#  19      0.000634  17287209 2023-04-19 01:22:29              5.000000
#  20      0.000634  17287210 2023-04-19 01:22:34              5.000000
#  21      0.000634  17287211 2023-04-19 01:22:39              5.000000
#  22      0.000634  17287212 2023-04-19 01:22:44              5.000000
#  23      0.000634  17287213 2023-04-19 01:22:49              5.000000
#  24      0.000707  17287214 2023-04-19 01:22:54              5.000000
#
#        Duración
#  0     5.416667
#  1    10.416667
#  2    15.416667
#  3    20.416667
#  4    25.416667
#  5    30.416667
#  6    35.416667
#  7    40.416667
#  8    45.416667
#  9    50.416667
#  10   55.416667
#  11   60.416667
#  12   65.416667
#  13   70.416667
#  14   75.416667
#  15   80.416667
#  16   85.416667
#  17   90.416667
#  18  105.416667
#  19  110.416667
#  20  115.416667
#  21  120.416667
#  22  125.416667
#  23  130.416667
#  24  135.416667  ,
#  'sepolia_bear':                                           Transacción  Estado  Gas utilizado  \
#  0   0x7a7093f0b1265d74707de1b44f196c41106625cef5e4...    True          69472
#  1   0x94f05d6301fd75952ba8cbc1cf5be2759d66fcde8999...    True          69484
#  2   0xf015c3d0b85c27e8f05a13ac064b6dbfbb929c7de694...    True          69484
#  3   0x62a047075cdca8a9f5bec60d74edfb103efc2aa4a0d2...    True          52384
#  4   0xbd4c7203140db7aee18c747543cc2eca9d5f765d0267...    True          52384
#  5   0x37683573d037b37d54d8a072e25a02906eaa834a3e32...    True          52384
#  6   0x5648fdff90433e5f9a365f08587940420f919cee58dc...    True          52384
#  7   0x7b162b2878a0c53f5ffdb05e15bd61f428dc6b1a9922...    True          52384
#  8   0x36ab468eafc4db8ab0ee3d5bdb4e54a135d15757e1e7...    True          52384
#  9   0xc187485c302fed5ec021ea741b86beb00b59a77a7f20...    True          52384
#  10  0xcc8c5d6846eaa19b636224a2f7a02b9d5f858c1dced0...    True          52384
#  11  0xba385b123a2b3f11b925398e73108d149a25c08649bf...    True          52384
#  12  0xa69484765b5393ef85231ab605918803276827e8c2ff...    True          29253
#  13  0xb7b2c94cfa4c645cddf1757a5a34bf023f07ec859fbc...    True          29265
#  14  0xa7dfeab97fc5ab271c117852a95b03404cbe3a8f1c2f...    True          29265
#  15  0xad1c21a83635c5caf4cd663bf97cae32ac47f01c927d...    True          29265
#  16  0xa4c3601ad437ffe5c7a83690e812f649068dfecdb898...    True          29265
#  17  0xb6f49a84bc456b8274fd5b0aacba42b2fe39367c0baf...    True          29265
#  18  0x0fc0879768a468e243f3b187f014e2ed6416c4adc19e...    True          29265
#  19  0x19995db9c78f110496a0bcbbcd7906a7ffc384418154...    True          29265
#  20  0x1e7073b9a9e61b6863b8256d76f8e472e8597d9d8c36...    True          29265
#  21  0x9f175cb26669edb26cbcb1413b0eadc48cf5d102c1bf...    True          29265
#  22  0x2fc6f24ec617566329befda2f9512cc38b74771523bf...    True          29265
#  23  0x68001bbdb0f5511f56742a2d6d6ad4e430aed67a9f01...    True          29265
#  24  0xaa16d922834635d72c22c499e8287bf9393a22b8614d...    True          30869
#
#      Coste en wei   Bloque              Tiempo  Diferencia de tiempo   Duración
#  0       0.000069  3318724 2023-04-19 12:32:27              3.083333   3.083333
#  1       0.000069  3318725 2023-04-19 12:32:31              4.000000   7.083333
#  2       0.000069  3318726 2023-04-19 12:32:34              3.000000  10.083333
#  3       0.000052  3318727 2023-04-19 12:32:36              2.000000  12.083333
#  4       0.000052  3318728 2023-04-19 12:32:39              3.000000  15.083333
#  5       0.000052  3318729 2023-04-19 12:32:42              3.000000  18.083333
#  6       0.000052  3318730 2023-04-19 12:32:45              3.000000  21.083333
#  7       0.000052  3318731 2023-04-19 12:32:48              3.000000  24.083333
#  8       0.000052  3318732 2023-04-19 12:32:51              3.000000  27.083333
#  9       0.000052  3318733 2023-04-19 12:32:54              3.000000  30.083333
#  10      0.000052  3318734 2023-04-19 12:32:57              3.000000  33.083333
#  11      0.000052  3318735 2023-04-19 12:33:00              3.000000  36.083333
#  12      0.000029  3318736 2023-04-19 12:33:03              3.000000  39.083333
#  13      0.000029  3318737 2023-04-19 12:33:06              3.000000  42.083333
#  14      0.000029  3318738 2023-04-19 12:33:09              3.000000  45.083333
#  15      0.000029  3318739 2023-04-19 12:33:13              4.000000  49.083333
#  16      0.000029  3318740 2023-04-19 12:33:16              3.000000  52.083333
#  17      0.000029  3318741 2023-04-19 12:33:19              3.000000  55.083333
#  18      0.000029  3318742 2023-04-19 12:33:22              3.000000  58.083333
#  19      0.000029  3318743 2023-04-19 12:33:26              4.000000  62.083333
#  20      0.000029  3318744 2023-04-19 12:33:29              3.000000  65.083333
#  21      0.000029  3318745 2023-04-19 12:33:32              3.000000  68.083333
#  22      0.000029  3318746 2023-04-19 12:33:35              3.000000  71.083333
#  23      0.000029  3318747 2023-04-19 12:33:38              3.000000  74.083333
#  24      0.000031  3318748 2023-04-19 12:33:41              3.000000  77.083333  ,
#  'arbitrum_bear':                                           Transacción  Estado  Gas utilizado  \
#  0   0x9b10a2d349c2fdc7280128d62498c1fb91d282ccd3a9...    True          69472
#  1   0x893bebf3ac28f16654e26669887fdd1226ce27504ef5...    True          69484
#  2   0x14b8cb534a7017fefc18069edc9453ef16e998f0b67d...    True          69484
#  3   0x9108af0f78f43633437a5f4146ba746a50652428b950...    True          52384
#  4   0x580cce11836291faffe00d71b1fdf6f093506f56ea16...    True          52384
#  5   0x4f77b07f7524ca57ebf582b427dd7541ce5ee6e07b9b...    True          52384
#  6   0x44c1f85daae34228f333a47eecd74f915b6834f3e62f...    True          52384
#  7   0xcd08a94ed54f14e8f14e60080dd29663a971d8470658...    True          52384
#  8   0x6e2a0315c9ef466c7538caaacce8a2036df1b625f540...    True          52384
#  9   0x4c11d739fdffe0253636811f9f534a3d3e1b5caf79cf...    True          52384
#  10  0x9832a97915cb8c1ed04054ab58a0da10d6965b9ee66d...    True          52384
#  11  0x063a10f6f2081ea360a09fde494abdb5581e6362cc68...    True          52384
#  12  0x5f8718236511ac7e3ddc72225551f46bd8ee1e4e66e5...    True          29253
#  13  0x853f116cfb90a476811ff4a782fbc6a052b8277ec8fb...    True          29265
#  14  0x9184c86ddaad8a136fb41ed39a44f196abcf724c9027...    True          29265
#  15  0x6e12e5c48aa8697073e55a412ecf1ad62a61dea2fbb4...    True          29265
#  16  0x4007cb8eeafca435566dca2e749b92182fa49c2e915d...    True          29265
#  17  0x2f01e24beed62be2093b6494b0dc7e2a98f975bcbd48...    True          29265
#  18  0x8b03a893e85f0637e1ea33b3d8f1967cf3ced534f37d...    True          29265
#  19  0xd98b2f03fed0d95b7f88307cad7ef878fdc0b115779e...    True          29265
#  20  0x70d642f6ec22ece9d9f8ffe815631b33b394b69c7e1a...    True          29265
#  21  0xde9419d2b77e0643a3e5bd4c7971704c3f2c6f060365...    True          29265
#  22  0x2466bb2dc2cd38b542ebb8b248caca54ea493a0bc9ab...    True          29265
#  23  0x6fe0434af94efe09c4a48aa6c85a9cf57ef22e258843...    True          29265
#  24  0x77f9db4aae82eabbfc4517e8fde43ef2096530d35d05...    True          30869
#
#      Coste en wei    Bloque              Tiempo  Diferencia de tiempo  Duración
#  0       0.000073  81696822 2023-04-19 02:20:59                   3.0       3.0
#  1       0.000073  81696823 2023-04-19 02:21:02                   3.0       6.0
#  2       0.000072  81696824 2023-04-19 02:21:05                   3.0       9.0
#  3       0.000054  81696825 2023-04-19 02:21:08                   3.0      12.0
#  4       0.000054  81696826 2023-04-19 02:21:11                   3.0      15.0
#  5       0.000054  81696827 2023-04-19 02:21:14                   3.0      18.0
#  6       0.000054  81696828 2023-04-19 02:21:17                   3.0      21.0
#  7       0.000053  81696829 2023-04-19 02:21:20                   3.0      24.0
#  8       0.000053  81696830 2023-04-19 02:21:23                   3.0      27.0
#  9       0.000053  81696831 2023-04-19 02:21:26                   3.0      30.0
#  10      0.000053  81696832 2023-04-19 02:21:29                   3.0      33.0
#  11      0.000053  81696833 2023-04-19 02:21:32                   3.0      36.0
#  12      0.000030  81696834 2023-04-19 02:21:35                   3.0      39.0
#  13      0.000030  81696835 2023-04-19 02:21:38                   3.0      42.0
#  14      0.000030  81696836 2023-04-19 02:21:41                   3.0      45.0
#  15      0.000029  81696837 2023-04-19 02:21:44                   3.0      48.0
#  16      0.000029  81696838 2023-04-19 02:21:47                   3.0      51.0
#  17      0.000029  81696839 2023-04-19 02:21:50                   3.0      54.0
#  18      0.000029  81696840 2023-04-19 02:21:53                   3.0      57.0
#  19      0.000029  81696841 2023-04-19 02:21:56                   3.0      60.0
#  20      0.000029  81696842 2023-04-19 02:21:59                   3.0      63.0
#  21      0.000029  81696843 2023-04-19 02:22:02                   3.0      66.0
#  22      0.000029  81696844 2023-04-19 02:22:05                   3.0      69.0
#  23      0.000029  81696845 2023-04-19 02:22:08                   3.0      72.0
#  24      0.000031  81696846 2023-04-19 02:22:11                   3.0      75.0  ,
#  'sepolia':                                           Transacción  Estado  Gas utilizado  \
#  0   0x077cb3e6ff194f3729523b84ea838d2f11952bfde8a1...    True          69472
#  1   0xb4479ebe8f4e6b71d09a5a2fd19426676ab5e5ae90fd...    True          69484
#  2   0x2bc1727c89dc7cf06a86e664b0d79841c83a46ba53be...    True          69484
#  3   0xe08b3925bce33c104117e0255ff47ce606cfaf4dc317...    True          52384
#  4   0xe2d7bb2a681fb1a8a107888dbb5a44702e3e81ae4cba...    True          52384
#  5   0x21f480de3345e99e772245b7079429651032257731d5...    True          52384
#  6   0xf832a71f35f4b2ea62d5f5b98cac88635f6e483709cb...    True          52384
#  7   0x90a142493b649a0d3c1d5135f31dc00117b4b3807c56...    True          52384
#  8   0x42980e4e05256428e3dc7f58ce5049c2394437d092fb...    True          52384
#  9   0xdb9086ae4d7c0e1af3646a0de9a5ea92ce1ee63ae432...    True          52384
#  10  0xced68f6587222d6610ee74cfb5cd06ec022f8b5f4214...    True          52384
#  11  0xcb138568106e7d9b41ce9c86eb12540c07e3a81aeb72...    True          52384
#  12  0x4a27aec2e5a78d4d01a23e0d79bb3ef07528a88da9ae...    True          29253
#  13  0x3261dc73a32b9512af993ce4a702d2cc76999a804b69...    True          29265
#  14  0x31c1abef541f35346003bc763cae028beb6835be0c5b...    True          29265
#  15  0xddc81f25622443344abfce9edfa1372bfb462d7e26aa...    True          29265
#  16  0x01669bd96ea3db55c6e2faf580ccdbc411b4476d0944...    True          29265
#  17  0xc8511b4d2338ab84b5851a78168c81f5d8a7eda179ab...    True          29265
#  18  0x59466cc0d655e8911edcbab98d0d65993b0a21e6da26...    True          29265
#  19  0xe02fcf7c392a437a0ecc18d07e82b5432a45772ca992...    True          29265
#  20  0x2f09a60507da3f46cbfba99a3c3bc0f237645bfa1ed9...    True          29265
#  21  0x393f43f6a7bbdd2ca33da043e81b6c8418028b4e9efc...    True          29265
#  22  0x1982851616af9e81e3af8a9827b737e30f7025d64dae...    True          29265
#  23  0xf9f47ae4994c600ade0b7a2b402373c16fe137f6a972...    True          29265
#  24  0xb9520fac9ddf2bce1743ff4a4e2cc5da7d1942ae31ed...    True          30869
#
#      Coste en wei   Bloque              Tiempo  Diferencia de tiempo  Duración
#  0       0.000069  3287900 2023-04-19 03:17:48                  13.0      13.0
#  1       0.000069  3287901 2023-04-19 03:18:00                  12.0      25.0
#  2       0.000069  3287902 2023-04-19 03:18:12                  12.0      37.0
#  3       0.000052  3287903 2023-04-19 03:18:24                  12.0      49.0
#  4       0.000052  3287904 2023-04-19 03:18:36                  12.0      61.0
#  5       0.000052  3287905 2023-04-19 03:19:00                  24.0      85.0
#  6       0.000052  3287906 2023-04-19 03:19:12                  12.0      97.0
#  7       0.000052  3287907 2023-04-19 03:19:36                  24.0     121.0
#  8       0.000052  3287908 2023-04-19 03:19:48                  12.0     133.0
#  9       0.000052  3287909 2023-04-19 03:20:00                  12.0     145.0
#  10      0.000052  3287910 2023-04-19 03:20:12                  12.0     157.0
#  11      0.000052  3287911 2023-04-19 03:20:24                  12.0     169.0
#  12      0.000029  3287912 2023-04-19 03:20:36                  12.0     181.0
#  13      0.000029  3287913 2023-04-19 03:20:48                  12.0     193.0
#  14      0.000029  3287914 2023-04-19 03:21:00                  12.0     205.0
#  15      0.000029  3287915 2023-04-19 03:21:12                  12.0     217.0
#  16      0.000029  3287916 2023-04-19 03:21:24                  12.0     229.0
#  17      0.000029  3287917 2023-04-19 03:21:36                  12.0     241.0
#  18      0.000029  3287918 2023-04-19 03:21:48                  12.0     253.0
#  19      0.000029  3287919 2023-04-19 03:22:00                  12.0     265.0
#  20      0.000029  3287920 2023-04-19 03:22:12                  12.0     277.0
#  21      0.000029  3287921 2023-04-19 03:22:24                  12.0     289.0
#  22      0.000029  3287922 2023-04-19 03:22:36                  12.0     301.0
#  23      0.000029  3287923 2023-04-19 03:22:48                  12.0     313.0
#  24      0.000031  3287924 2023-04-19 03:23:00                  12.0     325.0  }

# %%
for key, dataset_values in datasets_resumen.items():
    print(f"Longitud de la columna 'Coste en wei' en el DataFrame {key}: {len(dataset_values['Coste en wei'])}")
# Out:
# Longitud de la columna 'Coste en wei' en el DataFrame goerli: 25
# Longitud de la columna 'Coste en wei' en el DataFrame arbitrum: 25
# Longitud de la columna 'Coste en wei' en el DataFrame avalanche: 25
# Longitud de la columna 'Coste en wei' en el DataFrame optimism_bear: 25
# Longitud de la columna 'Coste en wei' en el DataFrame celo: 25
# Longitud de la columna 'Coste en wei' en el DataFrame sepolia_bear: 25
# Longitud de la columna 'Coste en wei' en el DataFrame arbitrum_bear: 25
# Longitud de la columna 'Coste en wei' en el DataFrame sepolia: 25

# %%
import matplotlib.pyplot as plt
import numpy as np

# Configuración del gráfico
max_len = max([len(dataset_values['Coste en wei']) for dataset_values in datasets_resumen.values()])
for dataset_values in datasets_resumen.values():
    dataset_values['Coste en wei'] = np.pad(dataset_values['Coste en wei'], (0, max_len - len(dataset_values['Coste en wei'])), mode='constant')
labels = [f"{i}" for i in range(1, max_len+1)]
x = np.arange(len(labels))
width = 0.45

# Crear el gráfico con figsize
fig, ax = plt.subplots(figsize=(12, 6))

# Iterar sobre el diccionario de datasets y agregar los datos al gráfico
for i, (dataset_name, dataset_values) in enumerate(datasets_resumen.items()):
    ax.bar(x + ((-1)**i) * width/2, dataset_values['Coste en wei'], width, label=f'{dataset_name}')

# Configurar las etiquetas y leyendas del gráfico
ax.set_ylabel('Coste en wei')
ax.set_xlabel('Numero de transaccion')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
fig.suptitle("Comparativa coste en wei de cada operación")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# #### Forma individual

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_comparativa_compra(dataset_name, dataset):
    # Configuración del gráfico
    labels = [f"{i}" for i in range(1, len(dataset['Coste en wei'])+1)]
    x = np.arange(len(labels))
    width = 0.45

    # Crear el gráfico con figsize
    fig, ax = plt.subplots(figsize=(12, 6))

    # Agregar los datos al gráfico
    ax.bar(x, dataset['Coste en wei'], width)

    # Configurar las etiquetas y leyendas del gráfico
    ax.set_ylabel('Coste en wei')
    ax.set_xlabel('Numero de transaccion')
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    fig.suptitle(f"Coste en wei de cada operación - {dataset_name}")

    # Mostrar el gráfico
    plt.show()

# Generar la gráfica para cada dataset
for dataset_name, dataset_values in datasets_resumen.items():
    plot_comparativa_compra(dataset_name, dataset_values)

# %% [markdown]
# ### Comparativa de tiempo que tarda en confirmarse cada transacción

# %% [markdown]
# ## hacer

# %% [raw]
# import matplotlib.pyplot as plt
# import numpy as np
#
#
# # Configuración del gráfico
# labels = [f"{i}" for i in range(1, len(entradas_ganache_3_datos['Diferencia de tiempo'])+1)]
# x = np.arange(len(labels))
# width = 0.35
#
# # Crear el gráfico
# fig, ax = plt.subplots()
# rects1 = ax.bar(x - width/2, datos_ganache['Diferencia de tiempo'], width, label='ganache')
# rects2 = ax.bar(x + width/2, datos_ganache3['Diferencia de tiempo'], width, label='ganache3')
#
# # Configurar las etiquetas y leyendas del gráfico
# ax.set_ylabel('Tiempo')
# ax.set_xlabel('Numero de transaccion')
# ax.set_xticks(x)
# ax.set_xticklabels(labels)
# ax.legend()
#
# # Mostrar el gráfico
# plt.show()

# %% [markdown]
# ### Comparativa de tiempo que tarda en cada transacción con diagrama de dispersión

# %%
import matplotlib.pyplot as plt
import numpy as np

# Configuración del gráfico
fig, ax = plt.subplots(figsize=(12, 6))

for dataset_name, dataset_values in datasets_resumen.items():
    ax.scatter(dataset_values.index, dataset_values['Diferencia de tiempo'], label=dataset_name)

# Configurar las etiquetas y leyendas del gráfico
ax.set_ylabel('Diferencia de tiempo (segundos)')
ax.set_xlabel('Número de transacción')
ax.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Comparativa de coste en wei y tiempo que tarda en cada transacción

# %%
import matplotlib.pyplot as plt
import numpy as np

# Configuración del gráfico
size = 50
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']
max_len = max([len(dataset_values['Coste en wei']) for dataset_values in datasets_resumen.values()])
for dataset_values in datasets_resumen.values():
    dataset_values['Coste en wei'] = np.pad(dataset_values['Coste en wei'], (0, max_len - len(dataset_values['Coste en wei'])), mode='constant')
labels = [f"{i}" for i in range(1, max_len+1)]
x = np.arange(len(labels))
width = 0.45

# Crear el gráfico con figsize
fig, ax = plt.subplots(figsize=(12, 6))

# Iterar sobre el diccionario de datasets y agregar los datos al gráfico de dispersión
for i, (dataset_name, dataset_values) in enumerate(datasets_resumen.items()):
    ax.scatter(dataset_values['Coste en wei'], dataset_values['Diferencia de tiempo'], s=size, c=colors[i%len(colors)], alpha=0.5, label=f'{dataset_name}')
    
    # Agregar el número de puntos en cada posición
    points_dict = {}
    for j in range(len(dataset_values['Coste en wei'])):
        point = (dataset_values['Coste en wei'][j], dataset_values['Diferencia de tiempo'][j])
        if point in points_dict:
            points_dict[point] += 1
        else:
            points_dict[point] = 1
    for point, count in points_dict.items():
        if count > 1:
            ax.annotate(f"{count}", xy=point, xytext=(10, 10), textcoords='offset points', fontsize=8, color='white')

# Configurar las etiquetas y leyendas del gráfico
ax.set_xlabel('Coste en wei')
ax.set_ylabel('Diferencia de tiempo (s)')
ax.legend()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Vemos de forma numérica la cantidad de transaccione que han coincidido en coste y tiempo para poder hacernos una idea del tiempo que tardaría y el coste que supondría cada transacción de media

# %%
import warnings
warnings.filterwarnings('ignore')

# Crear una lista vacía para almacenar los DataFrames
dataframes = []

# Recorrer el diccionario y agregar cada DataFrame a la lista
# Agregar columna 'Fuente' a cada DataFrame
for dataset_name, dataset_values in datasets_resumen.items():
    dataset_values['Fuente'] = dataset_name.replace("_secuencial_datos", "")
    dataframes.append(dataset_values)

# Concatenar los DataFrames en la lista
datos = pd.concat(dataframes, axis=0, ignore_index=True)

# Contar el número de puntos con las mismas coordenadas y fuente
conteo = datos.groupby(['Diferencia de tiempo', 'Coste en wei', 'Fuente']).size().reset_index(name='coincidencia')

# Ordenar los resultados por la columna 'coincidencia' de mayor a menor
conteo = conteo.sort_values(by=['coincidencia'], ascending=False)

# Crear una columna que indique la fuente de cada punto
for dataset_name in datasets_resumen:
    conteo['Fuente'] = conteo['Fuente'].apply(lambda x: dataset_name if x == dataset_name else x)

# Mostrar los resultados en formato de tabla
display(conteo.style.set_properties(**{'text-align': 'center'}).hide_index())
# Out:
# <style type="text/css">
# #T_0189d_row0_col0, #T_0189d_row0_col1, #T_0189d_row0_col2, #T_0189d_row0_col3, #T_0189d_row1_col0, #T_0189d_row1_col1, #T_0189d_row1_col2, #T_0189d_row1_col3, #T_0189d_row2_col0, #T_0189d_row2_col1, #T_0189d_row2_col2, #T_0189d_row2_col3, #T_0189d_row3_col0, #T_0189d_row3_col1, #T_0189d_row3_col2, #T_0189d_row3_col3, #T_0189d_row4_col0, #T_0189d_row4_col1, #T_0189d_row4_col2, #T_0189d_row4_col3, #T_0189d_row5_col0, #T_0189d_row5_col1, #T_0189d_row5_col2, #T_0189d_row5_col3, #T_0189d_row6_col0, #T_0189d_row6_col1, #T_0189d_row6_col2, #T_0189d_row6_col3, #T_0189d_row7_col0, #T_0189d_row7_col1, #T_0189d_row7_col2, #T_0189d_row7_col3, #T_0189d_row8_col0, #T_0189d_row8_col1, #T_0189d_row8_col2, #T_0189d_row8_col3, #T_0189d_row9_col0, #T_0189d_row9_col1, #T_0189d_row9_col2, #T_0189d_row9_col3, #T_0189d_row10_col0, #T_0189d_row10_col1, #T_0189d_row10_col2, #T_0189d_row10_col3, #T_0189d_row11_col0, #T_0189d_row11_col1, #T_0189d_row11_col2, #T_0189d_row11_col3, #T_0189d_row12_col0, #T_0189d_row12_col1, #T_0189d_row12_col2, #T_0189d_row12_col3, #T_0189d_row13_col0, #T_0189d_row13_col1, #T_0189d_row13_col2, #T_0189d_row13_col3, #T_0189d_row14_col0, #T_0189d_row14_col1, #T_0189d_row14_col2, #T_0189d_row14_col3, #T_0189d_row15_col0, #T_0189d_row15_col1, #T_0189d_row15_col2, #T_0189d_row15_col3, #T_0189d_row16_col0, #T_0189d_row16_col1, #T_0189d_row16_col2, #T_0189d_row16_col3, #T_0189d_row17_col0, #T_0189d_row17_col1, #T_0189d_row17_col2, #T_0189d_row17_col3, #T_0189d_row18_col0, #T_0189d_row18_col1, #T_0189d_row18_col2, #T_0189d_row18_col3, #T_0189d_row19_col0, #T_0189d_row19_col1, #T_0189d_row19_col2, #T_0189d_row19_col3, #T_0189d_row20_col0, #T_0189d_row20_col1, #T_0189d_row20_col2, #T_0189d_row20_col3, #T_0189d_row21_col0, #T_0189d_row21_col1, #T_0189d_row21_col2, #T_0189d_row21_col3, #T_0189d_row22_col0, #T_0189d_row22_col1, #T_0189d_row22_col2, #T_0189d_row22_col3, #T_0189d_row23_col0, #T_0189d_row23_col1, #T_0189d_row23_col2, #T_0189d_row23_col3, #T_0189d_row24_col0, #T_0189d_row24_col1, #T_0189d_row24_col2, #T_0189d_row24_col3, #T_0189d_row25_col0, #T_0189d_row25_col1, #T_0189d_row25_col2, #T_0189d_row25_col3, #T_0189d_row26_col0, #T_0189d_row26_col1, #T_0189d_row26_col2, #T_0189d_row26_col3, #T_0189d_row27_col0, #T_0189d_row27_col1, #T_0189d_row27_col2, #T_0189d_row27_col3, #T_0189d_row28_col0, #T_0189d_row28_col1, #T_0189d_row28_col2, #T_0189d_row28_col3, #T_0189d_row29_col0, #T_0189d_row29_col1, #T_0189d_row29_col2, #T_0189d_row29_col3, #T_0189d_row30_col0, #T_0189d_row30_col1, #T_0189d_row30_col2, #T_0189d_row30_col3, #T_0189d_row31_col0, #T_0189d_row31_col1, #T_0189d_row31_col2, #T_0189d_row31_col3, #T_0189d_row32_col0, #T_0189d_row32_col1, #T_0189d_row32_col2, #T_0189d_row32_col3, #T_0189d_row33_col0, #T_0189d_row33_col1, #T_0189d_row33_col2, #T_0189d_row33_col3, #T_0189d_row34_col0, #T_0189d_row34_col1, #T_0189d_row34_col2, #T_0189d_row34_col3, #T_0189d_row35_col0, #T_0189d_row35_col1, #T_0189d_row35_col2, #T_0189d_row35_col3, #T_0189d_row36_col0, #T_0189d_row36_col1, #T_0189d_row36_col2, #T_0189d_row36_col3, #T_0189d_row37_col0, #T_0189d_row37_col1, #T_0189d_row37_col2, #T_0189d_row37_col3, #T_0189d_row38_col0, #T_0189d_row38_col1, #T_0189d_row38_col2, #T_0189d_row38_col3, #T_0189d_row39_col0, #T_0189d_row39_col1, #T_0189d_row39_col2, #T_0189d_row39_col3, #T_0189d_row40_col0, #T_0189d_row40_col1, #T_0189d_row40_col2, #T_0189d_row40_col3, #T_0189d_row41_col0, #T_0189d_row41_col1, #T_0189d_row41_col2, #T_0189d_row41_col3, #T_0189d_row42_col0, #T_0189d_row42_col1, #T_0189d_row42_col2, #T_0189d_row42_col3, #T_0189d_row43_col0, #T_0189d_row43_col1, #T_0189d_row43_col2, #T_0189d_row43_col3, #T_0189d_row44_col0, #T_0189d_row44_col1, #T_0189d_row44_col2, #T_0189d_row44_col3, #T_0189d_row45_col0, #T_0189d_row45_col1, #T_0189d_row45_col2, #T_0189d_row45_col3, #T_0189d_row46_col0, #T_0189d_row46_col1, #T_0189d_row46_col2, #T_0189d_row46_col3, #T_0189d_row47_col0, #T_0189d_row47_col1, #T_0189d_row47_col2, #T_0189d_row47_col3, #T_0189d ...

# %% [markdown]
# ### Representación del gas y su equivalencia en Coste en wei

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Ajustar el tamaño de la figura
fig, axs = plt.subplots(len(datasets_resumen), 2, figsize=(12, 6*len(datasets_resumen)), sharex=True)
fig.subplots_adjust(hspace=0.5)

# Crear el gráfico de barras para cada conjunto de datos en datasets_resumen
for i, (dataset_name, dataset_values) in enumerate(datasets_resumen.items()):
    axs[i, 0].bar(dataset_values.index, dataset_values["Gas utilizado"], label="Gas utilizado")
    axs[i, 0].legend()
    axs[i, 0].set_title("Gas utilizado")

    axs[i, 1].bar(dataset_values.index, dataset_values["Coste en wei"], label="Coste en wei")
    axs[i, 1].legend()
    axs[i, 1].set_title("Coste en wei")
    axs[i, 1].set_xticks(dataset_values.index)
    axs[i, 1].set_xticklabels(dataset_values.index)

    # Añadir título a cada conjunto de gráficas
    axs[i, 0].set_title(f"Datos de {dataset_name}")

# Mostrar el gráfico
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_comparativa_compra(dataset_name, dataset):
    # Configuración del gráfico
    labels = [f"{i}" for i in range(1, len(dataset['Coste en wei'])+1)]
    x = np.arange(len(labels))
    width = 0.45

    # Crear el gráfico con figsize
    fig, axs = plt.subplots(2, 1, sharex=True, figsize=(12, 6))
    fig.subplots_adjust(hspace=0.5)

    # Gráfico para Coste en wei
    axs[0].bar(x, dataset['Coste en wei'], width)
    axs[0].set_ylabel('Coste en wei')
    axs[0].set_xticks(x)
    axs[0].set_xticklabels(labels)
    axs[0].set_title(f"Coste en wei - {dataset_name}")

    # Gráfico para Gas utilizado
    axs[1].bar(x, dataset['Gas utilizado'], width)
    axs[1].set_ylabel('Gas utilizado')
    axs[1].set_xticks(x)
    axs[1].set_xticklabels(labels)
    axs[1].set_title(f"Gas utilizado - {dataset_name}")

    # Mostrar el gráfico
    plt.show()

# Generar la gráfica para cada dataset
for dataset_name, dataset_values in datasets_resumen.items():
    plot_comparativa_compra(dataset_name, dataset_values)

# %% [markdown]
# ### Representación de dispersión para comparar el Gas utilizado y el Coste en wei por Bloque

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_scatter(dataset_name, dataset):
    # Configuración del gráfico
    x = dataset['Coste en wei']
    y = dataset['Gas utilizado']
    size = 50
    colors = 'b'

    # Crear el gráfico de dispersión
    fig, ax = plt.subplots()
    ax.scatter(x, y, s=size, c=colors, alpha=0.5, label=dataset_name)

    # Configurar las etiquetas y leyendas del gráfico
    ax.set_xlabel('Coste en wei')
    ax.set_ylabel('Gas utilizado')
    ax.legend()

    # Añadir título al gráfico
    plt.title(f"Diagrama de dispersión: Gas utilizado vs Coste en wei - {dataset_name}")

    # Mostrar el gráfico
    plt.show()

# Generar la gráfica de dispersión para cada dataset
for dataset_name, dataset_values in datasets_resumen.items():
    plot_scatter(dataset_name, dataset_values)

# %% [markdown]
# ### En conjunto

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


# Configuración del gráfico
fig, ax = plt.subplots()
for i, (dataset_name, dataset_values) in enumerate(datasets_resumen.items()):
    x = dataset_values['Coste en wei']
    y = dataset_values['Gas utilizado']
    size = 50

    # Crear el gráfico de dispersión
    ax.scatter(x, y, s=size,  alpha=0.5, label=dataset_name)

# Configurar las etiquetas y leyendas del gráfico
ax.set_xlabel('Coste en wei')
ax.set_ylabel('Gas utilizado')
ax.legend(title='Datasets', bbox_to_anchor=(1.05, 1), loc='upper left')

# Añadir título al gráfico
plt.title("Diagrama de dispersión: Gas utilizado vs Coste en wei")

# Mostrar el gráfico
plt.show()

# %%
# Crear una lista vacía para almacenar los DataFrames
dataframes = []

# Recorrer el diccionario y agregar cada DataFrame a la lista
for dataset_name, dataset_values in datasets_resumen.items():
    dataset_values['Fuente'] = dataset_name
    dataframes.append(dataset_values)

# Concatenar los DataFrames en la lista
datos = pd.concat(dataframes, axis=0, ignore_index=True)

# Contar el número de puntos con las mismas coordenadas y fuente
conteo = datos.groupby(['Diferencia de tiempo', 'Coste en wei', 'Fuente']).size().reset_index(name='coincidencia')

# Ordenar los resultados por la columna 'coincidencia' de mayor a menor
conteo = conteo.sort_values(by=['coincidencia'], ascending=False)

# Crear una columna que indique la fuente de cada punto
for dataset_name in datasets_resumen:
    conteo['Fuente'] = conteo['Fuente'].apply(lambda x: dataset_name if x == dataset_name else x)


# Mostrar los resultados en formato de tabla
display(conteo.style.set_properties(**{'text-align': 'center'}).hide_index())
# Out:
# <style type="text/css">
# #T_45d5d_row0_col0, #T_45d5d_row0_col1, #T_45d5d_row0_col2, #T_45d5d_row0_col3, #T_45d5d_row1_col0, #T_45d5d_row1_col1, #T_45d5d_row1_col2, #T_45d5d_row1_col3, #T_45d5d_row2_col0, #T_45d5d_row2_col1, #T_45d5d_row2_col2, #T_45d5d_row2_col3, #T_45d5d_row3_col0, #T_45d5d_row3_col1, #T_45d5d_row3_col2, #T_45d5d_row3_col3, #T_45d5d_row4_col0, #T_45d5d_row4_col1, #T_45d5d_row4_col2, #T_45d5d_row4_col3, #T_45d5d_row5_col0, #T_45d5d_row5_col1, #T_45d5d_row5_col2, #T_45d5d_row5_col3, #T_45d5d_row6_col0, #T_45d5d_row6_col1, #T_45d5d_row6_col2, #T_45d5d_row6_col3, #T_45d5d_row7_col0, #T_45d5d_row7_col1, #T_45d5d_row7_col2, #T_45d5d_row7_col3, #T_45d5d_row8_col0, #T_45d5d_row8_col1, #T_45d5d_row8_col2, #T_45d5d_row8_col3, #T_45d5d_row9_col0, #T_45d5d_row9_col1, #T_45d5d_row9_col2, #T_45d5d_row9_col3, #T_45d5d_row10_col0, #T_45d5d_row10_col1, #T_45d5d_row10_col2, #T_45d5d_row10_col3, #T_45d5d_row11_col0, #T_45d5d_row11_col1, #T_45d5d_row11_col2, #T_45d5d_row11_col3, #T_45d5d_row12_col0, #T_45d5d_row12_col1, #T_45d5d_row12_col2, #T_45d5d_row12_col3, #T_45d5d_row13_col0, #T_45d5d_row13_col1, #T_45d5d_row13_col2, #T_45d5d_row13_col3, #T_45d5d_row14_col0, #T_45d5d_row14_col1, #T_45d5d_row14_col2, #T_45d5d_row14_col3, #T_45d5d_row15_col0, #T_45d5d_row15_col1, #T_45d5d_row15_col2, #T_45d5d_row15_col3, #T_45d5d_row16_col0, #T_45d5d_row16_col1, #T_45d5d_row16_col2, #T_45d5d_row16_col3, #T_45d5d_row17_col0, #T_45d5d_row17_col1, #T_45d5d_row17_col2, #T_45d5d_row17_col3, #T_45d5d_row18_col0, #T_45d5d_row18_col1, #T_45d5d_row18_col2, #T_45d5d_row18_col3, #T_45d5d_row19_col0, #T_45d5d_row19_col1, #T_45d5d_row19_col2, #T_45d5d_row19_col3, #T_45d5d_row20_col0, #T_45d5d_row20_col1, #T_45d5d_row20_col2, #T_45d5d_row20_col3, #T_45d5d_row21_col0, #T_45d5d_row21_col1, #T_45d5d_row21_col2, #T_45d5d_row21_col3, #T_45d5d_row22_col0, #T_45d5d_row22_col1, #T_45d5d_row22_col2, #T_45d5d_row22_col3, #T_45d5d_row23_col0, #T_45d5d_row23_col1, #T_45d5d_row23_col2, #T_45d5d_row23_col3, #T_45d5d_row24_col0, #T_45d5d_row24_col1, #T_45d5d_row24_col2, #T_45d5d_row24_col3, #T_45d5d_row25_col0, #T_45d5d_row25_col1, #T_45d5d_row25_col2, #T_45d5d_row25_col3, #T_45d5d_row26_col0, #T_45d5d_row26_col1, #T_45d5d_row26_col2, #T_45d5d_row26_col3, #T_45d5d_row27_col0, #T_45d5d_row27_col1, #T_45d5d_row27_col2, #T_45d5d_row27_col3, #T_45d5d_row28_col0, #T_45d5d_row28_col1, #T_45d5d_row28_col2, #T_45d5d_row28_col3, #T_45d5d_row29_col0, #T_45d5d_row29_col1, #T_45d5d_row29_col2, #T_45d5d_row29_col3, #T_45d5d_row30_col0, #T_45d5d_row30_col1, #T_45d5d_row30_col2, #T_45d5d_row30_col3, #T_45d5d_row31_col0, #T_45d5d_row31_col1, #T_45d5d_row31_col2, #T_45d5d_row31_col3, #T_45d5d_row32_col0, #T_45d5d_row32_col1, #T_45d5d_row32_col2, #T_45d5d_row32_col3, #T_45d5d_row33_col0, #T_45d5d_row33_col1, #T_45d5d_row33_col2, #T_45d5d_row33_col3, #T_45d5d_row34_col0, #T_45d5d_row34_col1, #T_45d5d_row34_col2, #T_45d5d_row34_col3, #T_45d5d_row35_col0, #T_45d5d_row35_col1, #T_45d5d_row35_col2, #T_45d5d_row35_col3, #T_45d5d_row36_col0, #T_45d5d_row36_col1, #T_45d5d_row36_col2, #T_45d5d_row36_col3, #T_45d5d_row37_col0, #T_45d5d_row37_col1, #T_45d5d_row37_col2, #T_45d5d_row37_col3, #T_45d5d_row38_col0, #T_45d5d_row38_col1, #T_45d5d_row38_col2, #T_45d5d_row38_col3, #T_45d5d_row39_col0, #T_45d5d_row39_col1, #T_45d5d_row39_col2, #T_45d5d_row39_col3, #T_45d5d_row40_col0, #T_45d5d_row40_col1, #T_45d5d_row40_col2, #T_45d5d_row40_col3, #T_45d5d_row41_col0, #T_45d5d_row41_col1, #T_45d5d_row41_col2, #T_45d5d_row41_col3, #T_45d5d_row42_col0, #T_45d5d_row42_col1, #T_45d5d_row42_col2, #T_45d5d_row42_col3, #T_45d5d_row43_col0, #T_45d5d_row43_col1, #T_45d5d_row43_col2, #T_45d5d_row43_col3, #T_45d5d_row44_col0, #T_45d5d_row44_col1, #T_45d5d_row44_col2, #T_45d5d_row44_col3, #T_45d5d_row45_col0, #T_45d5d_row45_col1, #T_45d5d_row45_col2, #T_45d5d_row45_col3, #T_45d5d_row46_col0, #T_45d5d_row46_col1, #T_45d5d_row46_col2, #T_45d5d_row46_col3, #T_45d5d_row47_col0, #T_45d5d_row47_col1, #T_45d5d_row47_col2, #T_45d5d_row47_col3, #T_45d5d ...

# %% [markdown]
# ### BoxPlot

# %% [markdown]
# EL Boxplot nos permite visualizar la distribución de un conjunto de datos. El boxplot muestra la mediana (línea dentro de la caja), el rango intercuartil (la caja que va desde el primer cuartil al tercer cuartil), los valores mínimo y máximo (los bigotes), y los posibles valores atípicos o extremos (los puntos fuera de los bigotes)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Configuración del gráfico
data = []
labels = []
colors = []

for dataset_name, dataset_values in datasets_resumen.items():
    data.append(dataset_values['Gas utilizado'])
    labels.append(dataset_name)
    colors.append(np.random.rand(3,))

# Crear el gráfico
fig, ax = plt.subplots(figsize=(13, 6))

# Cambiar el color de cada boxplot y guardar las cajas en una lista
boxes = ax.boxplot(data, labels=labels, patch_artist=True, whiskerprops=dict(linestyle='-', linewidth=1.5))
for box, color in zip(boxes['boxes'], colors):
    box.set_facecolor(color)

# Obtener la mediana de cada set de datos y mostrarla en el gráfico
for i, median in enumerate(boxes['medians']):
    median_val = np.median(data[i])
    ax.text(i + 1, median_val, f"{median_val:.4f}", horizontalalignment='center', fontsize=10)

# Configurar las etiquetas y leyendas del gráfico
ax.set_ylabel('Gas utilizado')
ax.set_title('Boxplot de Gas utilizado por cada dataset')
plt.xticks(range(1, len(labels) + 1), labels)
ax.tick_params(axis='x', which='major', pad=15)

# Ajustar los límites del eje y
ymin, ymax = ax.get_ylim()
margin = (ymax - ymin) * 0.1
ax.set_ylim(ymin - margin, ymax + margin)

# Mostrar el gráfico
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

data = []
labels = []
colors = []

for dataset_name, dataset_values in datasets_resumen.items():
    data.append(dataset_values['Coste en wei'])
    labels.append(dataset_name)
    colors.append(np.random.rand(3,))

# Crear el gráfico
fig, ax = plt.subplots(figsize=(13, 8))

# Cambiar el color de cada boxplot y guardar las cajas en una lista
boxes = ax.boxplot(data, labels=labels, patch_artist=True, whiskerprops=dict(linestyle='-', linewidth=1.5))
for box, color in zip(boxes['boxes'], colors):
    box.set(facecolor=color)

# Obtener la mediana de cada set de datos y mostrarla debajo de la grafica
medians = [np.median(d) for d in data]
median_labels = [f"{dataset_name}: {median:.9f}" for dataset_name, median in zip(labels, medians)]

# Agregar leyenda con rectángulos de colores
rects = [plt.Rectangle((0, 0), 1, 1, color=color) for color in colors]
ax.legend(rects, labels, loc='upper right')

# Configurar las etiquetas y leyendas del gráfico
ax.set_ylabel('Coste en wei')
ax.set_title('Boxplot de Coste en wei por cada dataset')
ax.tick_params(axis='x', which='major', pad=15)

# Ajustar los límites del eje y
ymin, ymax = ax.get_ylim()
margin = (ymax - ymin) * 0.1
ax.set_ylim(ymin - margin, ymax + margin)

# Mostrar el gráfico
plt.show()

# Mostrar texto con la mediana debajo de la gráfica
fig, ax = plt.subplots(figsize=(12, 1))
ax.axis('off')
ax.text(0, 0, '\n'.join(median_labels), ha='left', va='center', fontsize=12)
plt.show()

# %% [markdown]
# ### Variación del coste total en función de la duración de las transacciones Grafico de linea

# %%
import matplotlib.pyplot as plt

# Configuración del gráfico
fig, ax = plt.subplots(figsize=(8, 6))

# Crear el gráfico de línea para cada conjunto de datos en datasets_resumen
for dataset_name, dataset_values in datasets_resumen.items():
    x = dataset_values['Duración']
    y = dataset_values['Coste en wei']
    ax.plot(x, y, label=dataset_name)
    
# Configurar las etiquetas y leyendas del gráfico
ax.set_xlabel('Tiempo')
ax.set_ylabel('Coste en wei')
ax.legend()
fig.suptitle('Variación del costo total en función de la duración de las transacciones')
ax.xaxis.set_major_locator(plt.MaxNLocator(integer=True)) # Establece el eje x como continuo
plt.ylim(bottom=0) # Asegura que el eje y empiece desde cero
plt.ylim(bottom=0)  # Asegura que el eje y empiece desde cero
plt.show()

# %% [markdown]
# ## Licence
# The notebook is freely licensed under under the [Creative Commons Attribution Share-Alike license](https://creativecommons.org/licenses/by/2.0/).
#
# ©  Carlos A. Iglesias, Universidad Politécnica de Madrid.
