# %% [markdown]
# ![](files/images/EscUpmPolit_p.gif "UPM")

# %% [markdown]
# <header style="width: 100%; position: relative; text-align: center;">
#   <div style="width: 80%; display: inline-block;">
#     <h1 style="margin: 0; margin-bottom: 10px;">Procesado de datos de Blockchain</h1>
#     <h3 style="margin: 0; margin-bottom: 20px;">TFM</h3>
#     <h5 style="margin: 0;">Universidad Politécnica de Madrid. © Pablo Ruiz Giles</h5>
#   </div>
# </header>

# %% [markdown]
# # Cargamos los datasets

# %% [markdown]
# Importamos los datastes de datos y creamos un diccioanrio llamado datasets_resumen que contiene los datos anteriormente importandos

# %%
import pandas as pd
import os

# Obtener la lista de carpetas en la carpeta datos/secuencial/
carpetas = [f for f in os.listdir('datos/secuencial/') if os.path.isdir(os.path.join('datos/secuencial/', f))]

# Crear un diccionario vacío para almacenar los DataFrames
datasets_resumen = {}

# Leer cada archivo CSV en cada carpeta y asignarlo a una variable con el nombre de la carpeta
for carpeta in carpetas:
    csv_files = [f for f in os.listdir(os.path.join('datos/secuencial/', carpeta)) if f.endswith('_datos.csv')]
    for f in csv_files:
        name = os.path.splitext(f)[0]
        name_without_suffix = name.replace('_secuencial_datos', '')
        vars()[name] = pd.read_csv(os.path.join('datos/secuencial/', carpeta, f))
        datasets_resumen[name_without_suffix] = eval(name)

# Imprimir los nombres de las variables creadas que contengan "_secuencial"
print("Los siguientes DataFrames se han creado:")
for var in sorted(datasets_resumen.keys()):
    print(var)
# Out:
# Los siguientes DataFrames se han creado:
# arbitrum
# arbitrum_bear
# avalanche
# celo
# goerli
# optimism
# optimism_bear
# polygon_bear
# sepolia
# sepolia_bear

# %%
arbitrum_secuencial_datos['Coste en wei']
# Out:
# 0     0.000007
# 1     0.000007
# 2     0.000007
# 3     0.000005
# 4     0.000005
# 5     0.000005
# 6     0.000005
# 7     0.000005
# 8     0.000005
# 9     0.000005
# 10    0.000005
# 11    0.000005
# 12    0.000003
# 13    0.000003
# 14    0.000003
# 15    0.000003
# 16    0.000003
# 17    0.000003
# 18    0.000003
# 19    0.000003
# 20    0.000003
# 21    0.000003
# 22    0.000003
# 23    0.000003
# 24    0.000003
# Name: Coste en wei, dtype: float64

# %% [markdown]
# #### Visualizamos

# %%
datasets_resumen
# Out:
# {'goerli':                                           Transacción  Estado Gas utilizado  \
#  0   0x558f599a705443df2c2344ac1c918a3f7e3aee376f18...    True       0x10f60
#  1   0xfaa0f2e7e2cb175cac8fdd1f5374763604de79264aab...    True       0x10f6c
#  2   0x3d56897ff6be097b0d0f5883c93294f0afa1b6bc3d0a...    True       0x10f6c
#  3   0x235d5dc3158ba7685d1805579c64dec5bcbfd9202915...    True        0xcca0
#  4   0x906a89c0105ea0a3b3092976859e3ff64df7a5eea9a3...    True        0xcca0
#  5   0x96727d2042b8db7107ba8cd47bfe4d03ef14702b1dff...    True        0xcca0
#  6   0xeca32227f92c987d3d4162785ee18084690310c12060...    True        0xcca0
#  7   0x448dfd0adc345f61ff433457c224bac582296b368fa1...    True        0xcca0
#  8   0x30484d5e39bcb904b40b70ca28608e8a86f9d6e79b91...    True        0xcca0
#  9   0xe83fd5c4400129f1908c999784022173ca14a3d67b39...    True        0xcca0
#  10  0x04040b5ad38d84fbc6cc7425419756c0c06fbda37b52...    True        0xcca0
#  11  0xfae64da078138e1bc5970c62d37d0d6e78be8fe3668a...    True        0xcca0
#  21  0x0755468db6dffa385e7e6500376166a81557dcc21ef5...    True        0x7251
#  22  0x624a0c2532666d329a85c3e8f4c2fd2317a58f75fb80...    True        0x7251
#  23  0x21255ba55419f9674645b979a77fe1974678a146d694...    True        0x7251
#  24  0x59c959f438c295264a3461c931483edc83d365152bd3...    True        0x7895
#
#      Coste en wei    Bloque    Tiempo
#  0       0.007779  41666828  02:34:52
#  1       0.006821  41666829  02:34:55
#  2       0.005981  41666830  02:34:58
#  3       0.003954  41666831  02:35:01
#  4       0.003468  41666832  02:35:04
#  5       0.003042  41666833  02:35:07
#  6       0.002670  41666834  02:35:10
#  7       0.002344  41666835  02:35:13
#  8       0.002058  41666836  02:35:16
#  9       0.001809  41666837  02:35:19
#  10      0.001590  41666838  02:35:22
#  11      0.001398  41666839  02:35:25
#  12      0.000687  41666840  02:35:29
#  13      0.000605  41666841  02:35:31
#  14      0.000533  41666842  02:35:35
#  15      0.000471  41666843  02:35:38
#  16      0.000415  41666844  02:35:41
#  17      0.000367  41666845  02:35:44
#  18      0.000325  41666846  02:35:47
#  19      0.000288  41666847  02:35:50
#  20      0.000256  41666848  02:35:54
#  21      0.000228  41666849  02:35:58
#  22      0.000203  41666850  02:36:02
#  23      0.000181  41666851  02:36:05
#  24      0.000171  41666852  02:36:21  }

# %% [markdown]
# # Cargamos etherscan

# %% [markdown]
# Importamos los datastes de ethercan y creamos un diccionario llamado datasets_scan que contiene los datos anteriormente importandos

# %%
import pandas as pd
import os

# Crear un diccionario vacío para almacenar los DataFrames
datasets_scan = {}

# Obtener los archivos CSV en todas las subcarpetas que contengan '_secuencial' en su nombre
csv_files = []
for root, dirs, files in os.walk('datos/scan/'):
    for f in files:
        if 'scan' in f and f.endswith('.csv'):
            csv_file_path = os.path.join(root, f)
            name = os.path.splitext(os.path.basename(csv_file_path))[0]
            df = pd.read_csv(csv_file_path)
            vars()[name] = df
            datasets_scan[name] = df

# Imprimir los nombres de los DataFrames creados
print("Los siguientes DataFrames se han creado:")
for var_name in sorted(datasets_scan.keys()):
    print(var_name)
# Out:
# Los siguientes DataFrames se han creado:
# scan_arbitrum
# scan_avalanche
# scan_boba
# scan_celo
# scan_goerli
# scan_optimism
# scan_sepolia

# %% [markdown]
# #### Visualizamos el tipo de datos que contiene etherscan

# %%
# Imprimir los nombres de las variables creadas que contengan "scan"
print("Los siguientes DataFrames se han creado:")
for var in sorted(datasets_scan.keys()):
    if 'scan' in var:
        print(var)

        # Acceder a cada DataFrame y asignar el índice a la columna "index_col"
        datasets_scan[var]['index_col'] = datasets_scan[var].index
        datasets_scan[var].info()
# Out:
# Los siguientes DataFrames se han creado:
# scan_arbitrum
# <class 'pandas.core.frame.DataFrame'>
# Index: 117 entries, 0x60fefc9d415057be9422701b7b470afef223402020fdbcb9f642f5399294debf to 0xb98ba76b2aa7a6237947cf677e13d9a4f265c2d38b912dfca57d20c87b463101
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Txhash                 117 non-null    int64
#  1   Blockno                117 non-null    int64
#  2   UnixTimestamp          117 non-null    object
#  3   DateTime               117 non-null    object
#  4   From                   106 non-null    object
#  5   To                     11 non-null     object
#  6   ContractAddress        117 non-null    float64
#  7   Value_IN(ETH)          117 non-null    int64
#  8   Value_OUT(ETH)         117 non-null    float64
#  9   CurrentValue @ $0/Eth  117 non-null    float64
#  10  TxnFee(ETH)            117 non-null    float64
#  11  TxnFee(USD)            115 non-null    float64
#  12  Historical $Price/ETH  2 non-null      object
#  13  Status                 2 non-null      object
#  14  ErrCode                117 non-null    object
#  15  Method                 0 non-null      float64
#  16  index_col              117 non-null    object
# dtypes: float64(6), int64(3), object(8)
# memory usage: 16.5+ KB
# scan_avalanche
# <class 'pandas.core.frame.DataFrame'>
# Index: 83 entries, 0x24cd4afbf8c0f52567f806d859206d33c97c4b81b50ae00e21c76affcb63c630 to 0x28d0e0d45fd15719a80219c07bc913f776edd7430cd58abe61276dab0f89f37e
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Txhash                  83 non-null     int64
#  1   Blockno                 83 non-null     int64
#  2   UnixTimestamp           83 non-null     object
#  3   DateTime                83 non-null     object
#  4   From                    78 non-null     object
#  5   To                      5 non-null      object
#  6   ContractAddress         83 non-null     float64
#  7   Value_IN(AVAX)          83 non-null     float64
#  8   Value_OUT(AVAX)         83 non-null     float64
#  9   CurrentValue @ $0/Eth   83 non-null     float64
#  10  TxnFee(AVAX)            83 non-null     float64
#  11  TxnFee(USD)             81 non-null     float64
#  12  Historical $Price/AVAX  0 non-null      float64
#  13  Status                  0 non-null      float64
#  14  ErrCode                 83 non-null     object
#  15  Method                  0 non-null      float64
#  16  index_col               83 non-null     object
# dtypes: float64(9), int64(2), object(6)
# memory usage: 11.7+ KB
# scan_boba
# <class 'pandas.core.frame.DataFrame'>
# Index: 181 entries, 0x3490d7d03388958c0e257936095b20363b41abd72f42eff8772d8aa118a69a9f to 0x71fe7e478ec2aac05a0f246a98da2bfe048eb766c043dd75b806d3c4245d31c3
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Txhash                 181 non-null    int64
#  1   Blockno                181 non-null    int64
#  2   UnixTimestamp          181 non-null    object
#  3   DateTime               181 non-null    object
#  4   From                   171 non-null    object
#  5   To                     10 non-null     object
#  6   ContractAddress        181 non-null    float64
#  7   Value_IN(ETH)          181 non-null    int64
#  8   Value_OUT(ETH)         181 non-null    int64
#  9   CurrentValue @ $0/Eth  181 non-null    float64
#  10  TxnFee(ETH/Boba)       181 non-null    int64
#  11  TxnFee(USD)            0 non-null      float64
#  12  Historical $Price/Eth  0 non-null      float64
#  13  Status                 0 non-null      float64
#  14  ErrCode                181 non-null    object
#  15  Method                 0 non-null      float64
#  16  index_col              181 non-null    object
# dtypes: float64(6), int64(5), object(6)
# memory usage: 25.5+ KB
# scan_celo
# <class 'pandas.core.frame.DataFrame'>
# Index: 56 entries, 0x20ecffa91082ba63f0a188dca44018b708a49d614c0a7cdbe7f24ecb1eb107dc to 0x488470fa8d51ef795b93ccbec181d0ddcbc84736ac54d2a42f594d59a2459e2e
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Txhash                  56 non-null     int64
#  1   Blockno                 56 non-null     int64
#  2   UnixTimestamp           56 non-null     object
#  3   DateTime                56 non-null     object
#  4   From                    52 non-null     object
#  5   To                      4 non-null      object
#  6   ContractAddress         56 non-null     float64
#  7   Value_IN(CELO)          56 non-null     int64
#  8   Value_OUT(CELO)         56 non-null     float64
#  9   CurrentValue @ $0/Eth   56 non-null     float64
#  10  TxnFee(CELO)            56 non-null     float64
#  11  TxnFee(USD)             54 non-null     float64
#  12  Historical $Price/CELO  0 non-null      float64
#  13  Status                  0 non-null      float64
#  14  ErrCode                 56 non-null     object
#  15  Method                  0 non-null      float64
#  16  index_col               56 non-null     object
# dtypes: float64(8), int64(3), object(6)
# memory usage: 7.9+ KB
# scan_goerli
# <class 'pandas.core.frame.DataFrame'>
# Index: 53 entries, 0x7c47adafe7fda59be432ad055b1684e603cbd904dfc6daaa024d3af0d49aff13 to 0xb19ee428df955e0da32adc97e940331cd47ac3b09f8ead166b24136e86762d9b
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Txhash                 53 non-null     int64
#  1   Blockno                53 non-null     int64
#  2   UnixTimestamp          53 non-null     object
#  3   DateTime               53 non-null     object
#  4   From                   45 non-null     object
#  5   To                     8 non-null      object
#  6   ContractAddress        53 non-null     float64
#  7   Value_IN(ETH)          53 non-null     float64
#  8   Value_OUT(ETH)         53 non-null     int64
#  9   CurrentValue @ $0/Eth  53 non-null     float64
#  10  TxnFee(ETH)            53 non-null     int64
#  11  TxnFee(USD)            0 non-null      float64
#  12  Historical $Price/Eth  4 non-null      object
#  13  Status                 4 non-null      object
#  14  ErrCode                53 non-null     object
#  15  Method                 0 non-null      float64
#  16  index_col              53 non-null     object
# dtypes: float64(5), int64(4), object(8)
# memory usage: 7.5+ KB
# scan_optimism
# <class 'pandas.core.frame.DataFrame'>
# Index: 157 entries, 0x0eaa54a3fc2bcc3cb1fab12ce99ca36eddc4dce64bcaf874558a6cd2a8a1862e to 0x36f8c38db92a0fa37ab1f6a6f6cac044540bcf2ab845629859235b6f5dfbc843
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Txhash                 157 non-null    int64
#  1   Blockno                157 non-null    int64
#  2   UnixTimestamp          157 non-null    object
#  3   DateTime               157 non-null    object
#  4   From                   139 non-null    object
#  5   To                     18 non-null     object
#  6   ContractAddress        157 non-null    float64
#  7   Value_IN(ETH)          157 non-null    int64
#  8   Value_OUT(ETH)         157 non-null    int64
#  9   CurrentValue @ $0/Eth  157 non-null    float64
#  10  TxnFee(ETH)            157 non-null    int64
#  11  TxnFee(USD)            0 non-null      float64
#  12  Historical $Price/Eth  3 non-null      object
#  13  Status                 3 non-null      object
#  14  ErrCode                157 non-null    object
#  15  Method                 0 non-null      float64
#  16  index_col              157 non-null    object
# dtypes: float64(4), int64(5), object(8)
# memory usage: 22.1+ KB
# scan_sepolia
# <class 'pandas.core.frame.DataFrame'>
# Index: 209 entries, 0x6fe8e4de8b321310896e11ae14b1c97c6a605bfb7669873a5078e5c2a3a370db to 0x525e05268207b74135338fc675cdca800d8941ab694dfdcb911cd73217c6701e
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Txhash                 209 non-null    int64
#  1   Blockno                209 non-null    int64
#  2   UnixTimestamp          209 non-null    object
#  3   DateTime               209 non-null    object
#  4   From                   196 non-null    object
#  5   To                     13 non-null     object
#  6   ContractAddress        209 non-null    float64
#  7   Value_IN(ETH)          209 non-null    int64
#  8   Value_OUT(ETH)         209 non-null    int64
#  9   CurrentValue @ $0/Eth  209 non-null    float64
#  10  TxnFee(ETH)            209 non-null    int64
#  11  TxnFee(USD)            0 non-null      float64
#  12  Historical $Price/Eth  0 non-null      float64
#  13  Status                 0 non-null      float64
#  14  ErrCode                209 non-null    object
#  15  Method                 0 non-null      float64
#  16  index_col              209 non-null    object
# dtypes: float64(6), int64(5), object(6)
# memory usage: 29.4+ KB

# %%
scan_arbitrum['CurrentValue @ $0/Eth']
# Out:
# 0x60fefc9d415057be9422701b7b470afef223402020fdbcb9f642f5399294debf    0.002280
# 0xf23eebdf12cff06e725a3ae7dddb0676ce26b753dfc4b36f1c561ac6d43192f4    0.019765
# 0x8bad7bbde2fe3f330d07be36c02a22e61962ac79f5f8ada574c616f7d9944fd3    0.019526
# 0xea3c91f05d30e89eb24bdcabd735f0422eb97295c7055e5dee26bc332cfca452    0.000901
# 0x947dc3f9dc9461b6696856cb6dd6f6966ef5e6e68cd0a6f1328e1f554a54aff1    0.000901
#                                                                         ...
# 0x2d32586283e6b610c5b72b6a6b9f7c3bcb0dc4d7f18b651f7223405ea7e9c927    0.000029
# 0x3dc7f27b9af524d81d38e525192be00c7fd46756ee402c01d4bcb72667eef996    0.000029
# 0xb70d7fd60368a54bec106ab31c456453e56dba30f715323e6e3c0db44f8ca803    0.000031
# 0xc177595a3132214331ff400f5ec92d8a9eaa7182a5372936d7bc22a304ed2fdc    0.002234
# 0xb98ba76b2aa7a6237947cf677e13d9a4f265c2d38b912dfca57d20c87b463101    0.000031
# Name: CurrentValue @ $0/Eth, Length: 117, dtype: float64

# %% [markdown]
# # Preprocesamos

# %% [markdown]
# ### Modificación de la columna Coste en wei

# %% [markdown]
# Creamos una lista llamada formatted_transactions que contiene los hashes de las operaciones que hemos realizado. Estos hashes se obtienen de los datasets de datos que se encuentran dentro de datasets_resumen

# %%
# Crear una lista con todas las transacciones formateadas como cadenas
formatted_transactions = []
for dataset in datasets_resumen.values():
    transacciones = [valor for valor in dataset['Transacción']]
    formatted_transactions += [str(valor)[:-1] for valor in transacciones]

# %% [markdown]
# Creamos un nuevo dataframe llamado df que contiene los hashes de las transacciones que coinciden con las de formatted_transactions y guardamos el valor de CurrentValue @ $0/Eth que indica el coste de la transacción. A su vez también se crea una nueva columna llamada index_col que guarda la dirección del hash

# %%
import pandas as pd

# Crear un DataFrame vacío para almacenar los DataFrames filtrados concatenados
df = pd.DataFrame()

# Iterar sobre las direcciones
for direccion in formatted_transactions:
    # Buscar en los datasets que empiezan con 'scan_' y contienen la dirección actual
    dataframes_direccion = [datasets_scan[k][datasets_scan[k]['index_col'] == direccion][['index_col', 'CurrentValue @ $0/Eth']] for k in datasets_scan.keys() if k.startswith('scan_')]

    # Concatenar los DataFrames filtrados en un solo DataFrame
    df = pd.concat([df] + dataframes_direccion)

# Imprimir información sobre el DataFrame concatenado resultante
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150 entries, 0x558f599a705443df2c2344ac1c918a3f7e3aee376f18957f1da53b0b67da185e to 0xb9520fac9ddf2bce1743ff4a4e2cc5da7d1942ae31ed32aff3a47175821d73c6
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   index_col              150 non-null    object
#  1   CurrentValue @ $0/Eth  150 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 3.5+ KB
# None

# %% [markdown]
# Vemos la longitud del dataframe df. En este caso deberia de ser 25 * el numero de etherscan que se hayan cargado

# %%
# Imprimir la longitud del DataFrame
print(len(df))
# Out:
# 150

# %% [markdown]
# A continuación, vemos que valores de la columna index_col de df coinciden con la columna Transacción de los datasets de datos. Los que coincidan se sustituirá el valor de Coste en wei por el de CurrentValue @ $0/Eth que es el correcto

# %%
# Iterar sobre los DataFrames en el diccionario `datasets_resumen`
for k, df_resumen in datasets_resumen.items():
    # Iterar sobre las transacciones en el DataFrame `df`
    for index, row in df.iterrows():
        # Obtener la dirección de la transacción actual
        direccion = row['index_col']
        # Añadimos : para que sea igual a las transacciones de los datos
        direccion = row['index_col'] + ":"

        # Obtener el valor de la transacción actual
        valor = row['CurrentValue @ $0/Eth']
        # Buscar si la dirección de la transacción actual coincide con la columna "Transacción" del DataFrame del diccionario `datasets_resumen`
        mask = df_resumen['Transacción'] == direccion
        # Si hay una coincidencia, establecer el valor de "Coste en wei" en el valor de la transacción actual
        if mask.any():
            df_resumen.loc[mask, 'Coste en wei'] = valor

# %%
optimism_secuencial_datos['Coste en wei']
# Out:
# 0     0.001738
# 1     0.001739
# 2     0.001739
# 3     0.001311
# 4     0.001311
# 5     0.001311
# 6     0.001311
# 7     0.001311
# 8     0.001311
# 9     0.001311
# 10    0.001311
# 11    0.001311
# 12    0.000733
# 13    0.000733
# 14    0.000733
# 15    0.000733
# 16    0.000733
# 17    0.000733
# 18    0.000733
# 19    0.000733
# 20    0.000733
# 21    0.000733
# 22    0.000733
# 23    0.000733
# 24    0.000773
# Name: Coste en wei, dtype: float64

# %%
goerli_secuencial_datos['Coste en wei']
# Out:
# 0     0.001737
# 1     0.001737
# 2     0.001737
# 3     0.001310
# 4     0.001310
# 5     0.001310
# 6     0.001310
# 7     0.001310
# 8     0.001310
# 9     0.001310
# 10    0.001310
# 11    0.001310
# 12    0.000731
# 13    0.000732
# 14    0.000732
# 15    0.000732
# 16    0.000732
# 17    0.000732
# 18    0.000732
# 19    0.000732
# 20    0.000732
# 21    0.000732
# 22    0.000732
# 23    0.000732
# 24    0.000772
# Name: Coste en wei, dtype: float64

# %% [markdown]
# ### Añadimos columna que sea la diferencia de tiempos entre transacciones y otra que sea Duración

# %% [markdown]
# Duración: Es la suma de las transacciones anteriores para ver como va aumentando el tiempo con la suma de transacciones
#
# Coste total: Es la suma de las transacciones anteriores para ver como va aumentando el ether con la suma de transacciones

# %% [markdown]
# #### Crear una lista con los nombres de los datasets

# %%
import os

# Obtener la lista de carpetas en la carpeta datos/secuencial/
carpetas = [f for f in os.listdir('datos/secuencial/') if os.path.isdir(os.path.join('datos/secuencial/', f))]

# Crear una lista para almacenar los nombres de los datasets
datasets = []

# Leer cada archivo CSV en cada carpeta y agregarlo a la lista datasets si termina en "_datos.csv"
for carpeta in carpetas:
    csv_files = [f for f in os.listdir(os.path.join('datos/secuencial/', carpeta)) if f.endswith('_datos.csv')]
    for f in csv_files:
        datasets.append(os.path.splitext(f)[0])

# Imprimir los nombres de los datasets creados
print("Los siguientes datasets se han creado:")
for dataset in datasets:
    print(dataset)
# Out:
# Los siguientes datasets se han creado:
# goerli_secuencial_datos
# arbitrum_secuencial_datos
# avalanche_secuencial_datos
# optimism_secuencial_datos
# optimism_bear_secuencial_datos
# celo_secuencial_datos
# sepolia_bear_secuencial_datos
# arbitrum_bear_secuencial_datos
# sepolia_secuencial_datos
# polygon_bear_secuencial_datos

# %%
optimism_secuencial_datos['Coste en wei']
# Out:
# 0     0.001738
# 1     0.001739
# 2     0.001739
# 3     0.001311
# 4     0.001311
# 5     0.001311
# 6     0.001311
# 7     0.001311
# 8     0.001311
# 9     0.001311
# 10    0.001311
# 11    0.001311
# 12    0.000733
# 13    0.000733
# 14    0.000733
# 15    0.000733
# 16    0.000733
# 17    0.000733
# 18    0.000733
# 19    0.000733
# 20    0.000733
# 21    0.000733
# 22    0.000733
# 23    0.000733
# 24    0.000773
# Name: Coste en wei, dtype: float64

# %% [markdown]
# ## Incluye columna  de Diferencia de tiempo y DUración

# %%
# Iterar sobre la lista de nombres de datasets
for dataset in datasets:
    # Convertir la columna "Tiempo" a tipo datetime
    globals()[dataset]["Tiempo"] = pd.to_datetime(globals()[dataset]["Tiempo"])

    # Calcular la diferencia de tiempo entre cada fila y la anterior, en segundos
    globals()[dataset]["Diferencia de tiempo"] = (globals()[dataset]["Tiempo"] - globals()[dataset]["Tiempo"].shift(1)).dt.total_seconds()

    # Inicializar el primer valor de la columna "Duración" con el valor de la primera fila de la columna "Diferencia de tiempo"
    globals()[dataset].loc[0, "Duración"] = globals()[dataset].loc[0, "Diferencia de tiempo"]

    # Sumar el primer valor de la columna "Duración" al resto de los valores en la columna "Duración"
    globals()[dataset]["Duración"] = globals()[dataset]["Duración"] + globals()[dataset].loc[0, "Duración"]

    # Sumar la columna "Diferencia de tiempo" al resto de los valores en la columna "Duración"
    globals()[dataset]["Duración"] = globals()[dataset]["Diferencia de tiempo"].cumsum().fillna(method='ffill')

    # Calcular la media de la columna "Diferencia de tiempo"
    media_diferencia_tiempo = globals()[dataset]["Diferencia de tiempo"].mean()

    # Reemplazar los valores NaN con la media de las otras filas
    globals()[dataset]["Diferencia de tiempo"].fillna(media_diferencia_tiempo, inplace=True)
    # Reemplazar los valores NaN con la media de las otras filas
    globals()[dataset]["Duración"].fillna(globals()[dataset]["Diferencia de tiempo"][0], inplace=True)
    
    # Crear una columna llamada "Coste total" que sea la suma de la columna "Coste en wei"
    globals()[dataset]["Coste total"] = globals()[dataset]["Coste en wei"].cumsum()


# Iterar sobre la lista de nombres de datasets, pero saltarse la primera iteración
for dataset in datasets:
    globals()[dataset]["Duración"] =  globals()[dataset]["Duración"] +  globals()[dataset]["Duración"][0]

# Iterar sobre la lista de nombres de datasets
for dataset in datasets:
    # Modificar el valor de Duración de la primera fila en el DataFrame original
    globals()[dataset].loc[0, "Duración"] = globals()[dataset]["Diferencia de tiempo"][0]

# %% [raw]
# # Iterar sobre la lista de nombres de datasets, pero saltarse la primera iteración
# for dataset in datasets:
#     globals()[dataset]["Duración"] =  globals()[dataset]["Duración"] +  globals()[dataset]["Duración"][0]

# %% [raw]
# # Iterar sobre la lista de nombres de datasets
# for dataset in datasets:
#     # Modificar el valor de Duración de la primera fila en el DataFrame original
#     globals()[dataset].loc[0, "Duración"] = globals()[dataset]["Diferencia de tiempo"][0]

# %% [markdown]
# ### Pasamos de hexadecimal a decimal Gas utilizado

# %%
#Gas utilizado 
import pandas as pd

def hex_to_dec(datos):
    # Convierte la columna "Gas utilizado" de hexadecimal a decimal
    datos["Gas utilizado"] = datos["Gas utilizado"].apply(lambda x: int(x, 16))
    
    # Devuelve el DataFrame modificado
    return datos


# Iterar sobre la lista de nombres de datasets
for dataset in datasets:
    # Aplicar la función a la columna "Gas utilizado" del DataFrame
    globals()[dataset] = hex_to_dec(globals()[dataset])
    
    # Imprimir el DataFrame resultante
    print(globals()[dataset].head())
# Out:
#                                          Transacción  Estado  Gas utilizado  \
# 0  0x558f599a705443df2c2344ac1c918a3f7e3aee376f18...    True          69472
# 1  0xfaa0f2e7e2cb175cac8fdd1f5374763604de79264aab...    True          69484
# 2  0x3d56897ff6be097b0d0f5883c93294f0afa1b6bc3d0a...    True          69484
# 3  0x235d5dc3158ba7685d1805579c64dec5bcbfd9202915...    True          52384
# 4  0x906a89c0105ea0a3b3092976859e3ff64df7a5eea9a3...    True          52384
#
#    Coste en wei   Bloque              Tiempo  Diferencia de tiempo  Duración  \
# 0      0.001737  8852430 2023-04-22 03:17:48                  18.0      18.0
# 1      0.001737  8852431 2023-04-22 03:18:00                  12.0      30.0
# 2      0.001737  8852432 2023-04-22 03:18:36                  36.0      66.0
# 3      0.001310  8852433 2023-04-22 03:18:48                  12.0      78.0
# 4      0.001310  8852434 2023-04-22 03:19:00                  12.0      90.0
#
#    Coste total
# 0     0.001737
# 1     0.003474
# 2     0.005211
# 3     0.006521
# 4     0.007830
#                                          Transacción  Estado  Gas utilizado  \
# 0  0x8b38451f53fc4fc2e530797fcd336826012b19cbb516...    True          69472
# 1  0x59532e68c65f2fbbd8ebe06979c94ea95352b9a5111c...    True          69484
# 2  0x024f325c51a35f15b9f3fd3e1651d6885664c535f09c...    True          69484
# 3  0xb5d19fa0a77b436533a21a03f634ccea6ba82026b75b...    True          52384
# 4  0x84f1d84f941c4ae674a1f3c2afed7616e6bce4095f97...    True          52384
#
#    Coste en wei    Bloque              Tiempo  Diferencia de tiempo  Duración  \
# 0      0.000069  16948423 2023-04-22 02:41:31                  2.25      2.25
# 1      0.000069  16948428 2023-04-22 02:41:33                  2.00      4.25
# 2      0.000069  16948433 2023-04-22 02:41:36                  3.00      7.25
# 3      0.000052  16948437 2023-04-22 02:41:38                  2.00      9.25
# 4      0.000052  16948442 2023-04-22 02:41:40                  2.00     11.25
#
#    Coste total
# 0     0.000069
# 1     0.000139
# 2     0.000208
# 3     0.000261
# 4     0.000313
#                                          Transacción  Estado  Gas utilizado  \
# 0  0xc2c0546e65e61d7c950970d9609401a0fb1365aacc1d...    True          69472
# 1  0x96c04baab5c727fc254fb23e4d2fd2ce4775ea5af1cb...    True          69484
# 2  0xcaf72e2df3156dc196274e8464b17f4af2873d0aceab...    True          69484
# 3  0x1dc8b4e7a522112340de32fb9d287ef30ea4fb75bcee...    True          52384
# 4  0x8e3b9f51b8bc4130238034fdb694bb40a4eeda66aefb...    True          52384
#
#    Coste en wei    Bloque              Tiempo  Diferencia de tiempo  \
# 0      0.002432  20978944 2023-04-22 02:43:47              5.916667
# 1      0.002432  20978945 2023-04-22 02:43:54              7.000000
# 2      0.002432  20978947 2023-04-22 02:43:59              5.000000
# 3      0.001833  20978948 2023-04-22 02:44:04              5.000000
# 4      0.001833  20978950 2023-04-22 02:44:10              6.000000
#
#     Duración  Coste total
# 0   5.916667     0.002432
# 1  12.916667     0.004863
# 2  17.916667     0.007295
# 3  22.916667     0.009129
# 4  28.916667     0.010962
#                                          Transacción  Estado  Gas utilizado  \
# 0  0
# 14      0.000732  8852444 2023-04-22 03:21:36                  24.0     246.0
# 15      0.000732  8852445 2023-04-22 03:22:12                  36.0     282.0
# 16      0.000732  8852446 2023-04-22 03:22:24                  12.0     294.0
# 17      0.000732  8852447 2023-04-22 03:22:48                  24.0     318.0
# 18      0.000732  8852448 2023-04-22 03:23:00                  12.0     330.0
# 19      0.000732  8852449 2023-04-22 03:23:12                  12.0     342.0
# 20      0.000732  8852450 2023-04-22 03:23:48                  36.0     378.0
# 21      0.000732  8852451 2023-04-22 03:24:24                  36.0     414.0
# 22      0.000732  8852452 2023-04-22 03:24:36                  12.0     426.0
# 23      0.000732  8852453 2023-04-22 03:24:48                  12.0     438.0
# 24      0.000772  8852454 2023-04-22 03:25:00                  12.0     450.0
#
#     Coste total
# 0      0.001737
# 1      0.003474
# 2      0.005211
# 3      0.006521
# 4      0.007830
# 5      0.009140
# 6      0.010449
# 7      0.011759
# 8      0.013069
# 9      0.014378
# 10     0.015688
# 11     0.016997
# 12     0.017729
# 13     0.018460
# 14     0.019192
# 15     0.019924
# 16     0.020655
# 17     0.021387
# 18     0.022118
# 19     0.022850
# 20     0.023582
# 21     0.024313
# 22     0.025045
# 23     0.025777
# 24     0.026548

# %% [markdown]
# ### Creación de una columna para dolares

# %%
import pandas as pd

# Definir las constantes de conversión de cada conjunto de datos
conversion_constants = {
    "ether": 1904,
    "celo": 0.95,
    "avax": 22
}

# Definir la función para convertir a dólares
def wei_to_usd(datos, constant):
    # Agregar la nueva columna "Coste en dólares"
    datos["Coste en dólares"] = datos["Coste en wei"] * constant
    datos["Coste en dólares total"] = datos["Coste total"] * constant
    
    # Devolver el DataFrame modificado
    return datos

# Iterar sobre la lista de nombres de datasets
for dataset in datasets:
    # Obtener la constante correspondiente al conjunto de datos actual
    if "celo" in dataset:
        constant = conversion_constants['celo']
    elif "avalanche" in dataset:
        constant = conversion_constants['avax']
    else:
        constant = conversion_constants['ether']
    
    # Aplicar la función de conversión a dólares a la columna "Coste en wei"
    globals()[dataset] = wei_to_usd(globals()[dataset], constant)
    
    # Imprimir el DataFrame resultante
    print(globals()[dataset].head())
# Out:
#                                          Transacción  Estado  Gas utilizado  \
# 0  0x558f599a705443df2c2344ac1c918a3f7e3aee376f18...    True          69472
# 1  0xfaa0f2e7e2cb175cac8fdd1f5374763604de79264aab...    True          69484
# 2  0x3d56897ff6be097b0d0f5883c93294f0afa1b6bc3d0a...    True          69484
# 3  0x235d5dc3158ba7685d1805579c64dec5bcbfd9202915...    True          52384
# 4  0x906a89c0105ea0a3b3092976859e3ff64df7a5eea9a3...    True          52384
#
#    Coste en wei   Bloque              Tiempo  Diferencia de tiempo  Duración  \
# 0      0.001737  8852430 2023-04-22 03:17:48                  18.0      18.0
# 1      0.001737  8852431 2023-04-22 03:18:00                  12.0      30.0
# 2      0.001737  8852432 2023-04-22 03:18:36                  36.0      66.0
# 3      0.001310  8852433 2023-04-22 03:18:48                  12.0      78.0
# 4      0.001310  8852434 2023-04-22 03:19:00                  12.0      90.0
#
#    Coste total  Coste en dólares  Coste en dólares total
# 0     0.001737          3.306867                3.306867
# 1     0.003474          3.307438                6.614306
# 2     0.005211          3.307438                9.921744
# 3     0.006521          2.493478               12.415222
# 4     0.007830          2.493478               14.908701
#                                          Transacción  Estado  Gas utilizado  \
# 0  0x8b38451f53fc4fc2e530797fcd336826012b19cbb516...    True          69472
# 1  0x59532e68c65f2fbbd8ebe06979c94ea95352b9a5111c...    True          69484
# 2  0x024f325c51a35f15b9f3fd3e1651d6885664c535f09c...    True          69484
# 3  0xb5d19fa0a77b436533a21a03f634ccea6ba82026b75b...    True          52384
# 4  0x84f1d84f941c4ae674a1f3c2afed7616e6bce4095f97...    True          52384
#
#    Coste en wei    Bloque              Tiempo  Diferencia de tiempo  Duración  \
# 0      0
#  13  42.708333     0.044205          1.152427               84.166990
#  14  46.708333     0.044739          1.015606               85.182596
#  15  49.708333     0.045209          0.895854               86.078450
#  16  52.708333     0.045625          0.791043               86.869493
#  17  55.708333     0.045992          0.699307               87.568800
#  18  58.708333     0.046317          0.619015               88.187815
#  19  61.708333     0.046605          0.548741               88.736556
#  20  65.708333     0.046861          0.487234               89.223790
#  21  69.708333     0.047089          0.433400               89.657189
#  22  73.708333     0.047292          0.386282               90.043471
#  23  76.708333     0.047473          0.345042               90.388514
#  24  92.708333     0.047644          0.325885               90.714399  }

# %%
for key, dataset_values in datasets_resumen.items():
    print(f"Longitud de la columna 'Coste en wei' en el DataFrame {key}: {len(dataset_values['Coste en wei'])}")
# Out:
# Longitud de la columna 'Coste en wei' en el DataFrame goerli: 25
# Longitud de la columna 'Coste en wei' en el DataFrame arbitrum: 25
# Longitud de la columna 'Coste en wei' en el DataFrame avalanche: 25
# Longitud de la columna 'Coste en wei' en el DataFrame optimism: 25
# Longitud de la columna 'Coste en wei' en el DataFrame optimism_bear: 25
# Longitud de la columna 'Coste en wei' en el DataFrame celo: 25
# Longitud de la columna 'Coste en wei' en el DataFrame sepolia_bear: 25
# Longitud de la columna 'Coste en wei' en el DataFrame arbitrum_bear: 25
# Longitud de la columna 'Coste en wei' en el DataFrame sepolia: 25
# Longitud de la columna 'Coste en wei' en el DataFrame polygon_bear: 25

# %%
import matplotlib.pyplot as plt
import numpy as np

# Configuración del gráfico
max_len = max([len(dataset_values['Coste en dólares']) for dataset_values in datasets_resumen.values()])
for dataset_values in datasets_resumen.values():
    dataset_values['Coste en wei'] = np.pad(dataset_values['Coste en dólares'], (0, max_len - len(dataset_values['Coste en dólares'])), mode='constant')
labels = [f"{i}" for i in range(1, max_len+1)]
x = np.arange(len(labels))
width = 0.45

# Crear el gráfico con figsize
fig, ax = plt.subplots(figsize=(12, 6))

# Iterar sobre el diccionario de datasets y agregar los datos al gráfico
for i, (dataset_name, dataset_values) in enumerate(datasets_resumen.items()):
    ax.bar(x + ((-1)**i) * width/2, dataset_values['Coste en dólares'], width, label=f'{dataset_name}')

# Configurar las etiquetas y leyendas del gráfico
ax.set_ylabel('Coste en dólares')
ax.set_xlabel('Numero de transaccion')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
fig.suptitle("Comparativa coste en wei de cada operación")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# #### Forma individual

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_comparativa_compra(dataset_name, dataset):
    # Configuración del gráfico
    labels = [f"{i}" for i in range(1, len(dataset['Coste en dólares'])+1)]
    x = np.arange(len(labels))
    width = 0.45

    # Crear el gráfico con figsize
    fig, ax = plt.subplots(figsize=(12, 6))

    # Agregar los datos al gráfico
    ax.bar(x, dataset['Coste en dólares'], width)

    # Configurar las etiquetas y leyendas del gráfico
    ax.set_ylabel('Coste en dólares')
    ax.set_xlabel('Numero de transaccion')
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    fig.suptitle(f"Coste en dólares de cada operación - {dataset_name}")

    # Mostrar el gráfico
    plt.show()

# Generar la gráfica para cada dataset
for dataset_name, dataset_values in datasets_resumen.items():
    plot_comparativa_compra(dataset_name, dataset_values)

# %% [markdown]
# ### Comparativa de tiempo que tarda en confirmarse cada transacción

# %% [markdown]
# ## hacer

# %% [raw]
# import matplotlib.pyplot as plt
# import numpy as np
#
#
# # Configuración del gráfico
# labels = [f"{i}" for i in range(1, len(entradas_ganache_3_datos['Diferencia de tiempo'])+1)]
# x = np.arange(len(labels))
# width = 0.35
#
# # Crear el gráfico
# fig, ax = plt.subplots()
# rects1 = ax.bar(x - width/2, datos_ganache['Diferencia de tiempo'], width, label='ganache')
# rects2 = ax.bar(x + width/2, datos_ganache3['Diferencia de tiempo'], width, label='ganache3')
#
# # Configurar las etiquetas y leyendas del gráfico
# ax.set_ylabel('Tiempo')
# ax.set_xlabel('Numero de transaccion')
# ax.set_xticks(x)
# ax.set_xticklabels(labels)
# ax.legend()
#
# # Mostrar el gráfico
# plt.show()

# %% [markdown]
# ### Comparativa de tiempo que tarda en cada transacción con diagrama de dispersión

# %%
import matplotlib.pyplot as plt
import numpy as np

# Configuración del gráfico
fig, ax = plt.subplots(figsize=(12, 6))

for dataset_name, dataset_values in datasets_resumen.items():
    ax.scatter(dataset_values.index, dataset_values['Diferencia de tiempo'], label=dataset_name)

# Configurar las etiquetas y leyendas del gráfico
ax.set_ylabel('Diferencia de tiempo (segundos)')
ax.set_xlabel('Número de transacción')
ax.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Comparativa de coste en wei y tiempo que tarda en cada transacción

# %%
import matplotlib.pyplot as plt
import numpy as np

# Configuración del gráfico
size = 50
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']
max_len = max([len(dataset_values['Coste en dólares']) for dataset_values in datasets_resumen.values()])
for dataset_values in datasets_resumen.values():
    dataset_values['Coste en dólares'] = np.pad(dataset_values['Coste en dólares'], (0, max_len - len(dataset_values['Coste en wei'])), mode='constant')
labels = [f"{i}" for i in range(1, max_len+1)]
x = np.arange(len(labels))
width = 0.45

# Crear el gráfico con figsize
fig, ax = plt.subplots(figsize=(12, 6))

# Iterar sobre el diccionario de datasets y agregar los datos al gráfico de dispersión
for i, (dataset_name, dataset_values) in enumerate(datasets_resumen.items()):
    ax.scatter(dataset_values['Coste en wei'], dataset_values['Diferencia de tiempo'], s=size, c=colors[i%len(colors)], alpha=0.5, label=f'{dataset_name}')
    
    # Agregar el número de puntos en cada posición
    points_dict = {}
    for j in range(len(dataset_values['Coste en dólares'])):
        point = (dataset_values['Coste en dólares'][j], dataset_values['Diferencia de tiempo'][j])
        if point in points_dict:
            points_dict[point] += 1
        else:
            points_dict[point] = 1
    for point, count in points_dict.items():
        if count > 1:
            ax.annotate(f"{count}", xy=point, xytext=(10, 10), textcoords='offset points', fontsize=8, color='white')

# Configurar las etiquetas y leyendas del gráfico
ax.set_xlabel('Coste en dólares')
ax.set_ylabel('Diferencia de tiempo (s)')
ax.legend()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Vemos de forma numérica la cantidad de transaccione que han coincidido en coste y tiempo para poder hacernos una idea del tiempo que tardaría y el coste que supondría cada transacción de media

# %%
import warnings
warnings.filterwarnings('ignore')

# Crear una lista vacía para almacenar los DataFrames
dataframes = []

# Recorrer el diccionario y agregar cada DataFrame a la lista
# Agregar columna 'Fuente' a cada DataFrame
for dataset_name, dataset_values in datasets_resumen.items():
    dataset_values['Fuente'] = dataset_name.replace("_secuencial_datos", "")
    dataframes.append(dataset_values)

# Concatenar los DataFrames en la lista
datos = pd.concat(dataframes, axis=0, ignore_index=True)

# Contar el número de puntos con las mismas coordenadas y fuente
conteo = datos.groupby(['Diferencia de tiempo', 'Coste en dólares', 'Fuente']).size().reset_index(name='coincidencia')

# Ordenar los resultados por la columna 'coincidencia' de mayor a menor
conteo = conteo.sort_values(by=['coincidencia'], ascending=False)

# Crear una columna que indique la fuente de cada punto
for dataset_name in datasets_resumen:
    conteo['Fuente'] = conteo['Fuente'].apply(lambda x: dataset_name if x == dataset_name else x)

# Mostrar los resultados en formato de tabla
display(conteo.style.set_properties(**{'text-align': 'center'}).hide_index())
# Out:
# <style type="text/css">
# #T_f6988_row0_col0, #T_f6988_row0_col1, #T_f6988_row0_col2, #T_f6988_row0_col3, #T_f6988_row1_col0, #T_f6988_row1_col1, #T_f6988_row1_col2, #T_f6988_row1_col3, #T_f6988_row2_col0, #T_f6988_row2_col1, #T_f6988_row2_col2, #T_f6988_row2_col3, #T_f6988_row3_col0, #T_f6988_row3_col1, #T_f6988_row3_col2, #T_f6988_row3_col3, #T_f6988_row4_col0, #T_f6988_row4_col1, #T_f6988_row4_col2, #T_f6988_row4_col3, #T_f6988_row5_col0, #T_f6988_row5_col1, #T_f6988_row5_col2, #T_f6988_row5_col3, #T_f6988_row6_col0, #T_f6988_row6_col1, #T_f6988_row6_col2, #T_f6988_row6_col3, #T_f6988_row7_col0, #T_f6988_row7_col1, #T_f6988_row7_col2, #T_f6988_row7_col3, #T_f6988_row8_col0, #T_f6988_row8_col1, #T_f6988_row8_col2, #T_f6988_row8_col3, #T_f6988_row9_col0, #T_f6988_row9_col1, #T_f6988_row9_col2, #T_f6988_row9_col3, #T_f6988_row10_col0, #T_f6988_row10_col1, #T_f6988_row10_col2, #T_f6988_row10_col3, #T_f6988_row11_col0, #T_f6988_row11_col1, #T_f6988_row11_col2, #T_f6988_row11_col3, #T_f6988_row12_col0, #T_f6988_row12_col1, #T_f6988_row12_col2, #T_f6988_row12_col3, #T_f6988_row13_col0, #T_f6988_row13_col1, #T_f6988_row13_col2, #T_f6988_row13_col3, #T_f6988_row14_col0, #T_f6988_row14_col1, #T_f6988_row14_col2, #T_f6988_row14_col3, #T_f6988_row15_col0, #T_f6988_row15_col1, #T_f6988_row15_col2, #T_f6988_row15_col3, #T_f6988_row16_col0, #T_f6988_row16_col1, #T_f6988_row16_col2, #T_f6988_row16_col3, #T_f6988_row17_col0, #T_f6988_row17_col1, #T_f6988_row17_col2, #T_f6988_row17_col3, #T_f6988_row18_col0, #T_f6988_row18_col1, #T_f6988_row18_col2, #T_f6988_row18_col3, #T_f6988_row19_col0, #T_f6988_row19_col1, #T_f6988_row19_col2, #T_f6988_row19_col3, #T_f6988_row20_col0, #T_f6988_row20_col1, #T_f6988_row20_col2, #T_f6988_row20_col3, #T_f6988_row21_col0, #T_f6988_row21_col1, #T_f6988_row21_col2, #T_f6988_row21_col3, #T_f6988_row22_col0, #T_f6988_row22_col1, #T_f6988_row22_col2, #T_f6988_row22_col3, #T_f6988_row23_col0, #T_f6988_row23_col1, #T_f6988_row23_col2, #T_f6988_row23_col3, #T_f6988_row24_col0, #T_f6988_row24_col1, #T_f6988_row24_col2, #T_f6988_row24_col3, #T_f6988_row25_col0, #T_f6988_row25_col1, #T_f6988_row25_col2, #T_f6988_row25_col3, #T_f6988_row26_col0, #T_f6988_row26_col1, #T_f6988_row26_col2, #T_f6988_row26_col3, #T_f6988_row27_col0, #T_f6988_row27_col1, #T_f6988_row27_col2, #T_f6988_row27_col3, #T_f6988_row28_col0, #T_f6988_row28_col1, #T_f6988_row28_col2, #T_f6988_row28_col3, #T_f6988_row29_col0, #T_f6988_row29_col1, #T_f6988_row29_col2, #T_f6988_row29_col3, #T_f6988_row30_col0, #T_f6988_row30_col1, #T_f6988_row30_col2, #T_f6988_row30_col3, #T_f6988_row31_col0, #T_f6988_row31_col1, #T_f6988_row31_col2, #T_f6988_row31_col3, #T_f6988_row32_col0, #T_f6988_row32_col1, #T_f6988_row32_col2, #T_f6988_row32_col3, #T_f6988_row33_col0, #T_f6988_row33_col1, #T_f6988_row33_col2, #T_f6988_row33_col3, #T_f6988_row34_col0, #T_f6988_row34_col1, #T_f6988_row34_col2, #T_f6988_row34_col3, #T_f6988_row35_col0, #T_f6988_row35_col1, #T_f6988_row35_col2, #T_f6988_row35_col3, #T_f6988_row36_col0, #T_f6988_row36_col1, #T_f6988_row36_col2, #T_f6988_row36_col3, #T_f6988_row37_col0, #T_f6988_row37_col1, #T_f6988_row37_col2, #T_f6988_row37_col3, #T_f6988_row38_col0, #T_f6988_row38_col1, #T_f6988_row38_col2, #T_f6988_row38_col3, #T_f6988_row39_col0, #T_f6988_row39_col1, #T_f6988_row39_col2, #T_f6988_row39_col3, #T_f6988_row40_col0, #T_f6988_row40_col1, #T_f6988_row40_col2, #T_f6988_row40_col3, #T_f6988_row41_col0, #T_f6988_row41_col1, #T_f6988_row41_col2, #T_f6988_row41_col3, #T_f6988_row42_col0, #T_f6988_row42_col1, #T_f6988_row42_col2, #T_f6988_row42_col3, #T_f6988_row43_col0, #T_f6988_row43_col1, #T_f6988_row43_col2, #T_f6988_row43_col3, #T_f6988_row44_col0, #T_f6988_row44_col1, #T_f6988_row44_col2, #T_f6988_row44_col3, #T_f6988_row45_col0, #T_f6988_row45_col1, #T_f6988_row45_col2, #T_f6988_row45_col3, #T_f6988_row46_col0, #T_f6988_row46_col1, #T_f6988_row46_col2, #T_f6988_row46_col3, #T_f6988_row47_col0, #T_f6988_row47_col1, #T_f6988_row47_col2, #T_f6988_row47_col3, #T_f6988 ...

# %% [markdown]
# ### Representación del gas y su equivalencia en Coste en wei

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Ajustar el tamaño de la figura
fig, axs = plt.subplots(len(datasets_resumen), 2, figsize=(12, 6*len(datasets_resumen)), sharex=True)
fig.subplots_adjust(hspace=0.5)

# Crear el gráfico de barras para cada conjunto de datos en datasets_resumen
for i, (dataset_name, dataset_values) in enumerate(datasets_resumen.items()):
    axs[i, 0].bar(dataset_values.index, dataset_values["Gas utilizado"], label="Gas utilizado")
    axs[i, 0].legend()
    axs[i, 0].set_title("Gas utilizado")

    axs[i, 1].bar(dataset_values.index, dataset_values["Coste en dólares"], label="Coste en dólares")
    axs[i, 1].legend()
    axs[i, 1].set_title("Coste en dólares")
    axs[i, 1].set_xticks(dataset_values.index)
    axs[i, 1].set_xticklabels(dataset_values.index)

    # Añadir título a cada conjunto de gráficas
    axs[i, 0].set_title(f"Datos de {dataset_name}")

# Mostrar el gráfico
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_comparativa_compra(dataset_name, dataset):
    # Configuración del gráfico
    labels = [f"{i}" for i in range(1, len(dataset['Coste en wei'])+1)]
    x = np.arange(len(labels))
    width = 0.45

    # Crear el gráfico con figsize
    fig, axs = plt.subplots(2, 1, sharex=True, figsize=(12, 6))
    fig.subplots_adjust(hspace=0.5)

    # Gráfico para Coste en wei
    axs[0].bar(x, dataset['Coste en wei'], width)
    axs[0].set_ylabel('Coste en wei')
    axs[0].set_xticks(x)
    axs[0].set_xticklabels(labels)
    axs[0].set_title(f"Coste en wei - {dataset_name}")

    # Gráfico para Gas utilizado
    axs[1].bar(x, dataset['Gas utilizado'], width)
    axs[1].set_ylabel('Gas utilizado')
    axs[1].set_xticks(x)
    axs[1].set_xticklabels(labels)
    axs[1].set_title(f"Gas utilizado - {dataset_name}")

    # Mostrar el gráfico
    plt.show()

# Generar la gráfica para cada dataset
for dataset_name, dataset_values in datasets_resumen.items():
    plot_comparativa_compra(dataset_name, dataset_values)

# %% [markdown]
# ### Representación de dispersión para comparar el Gas utilizado y el Coste en wei por Bloque

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_scatter(dataset_name, dataset):
    # Configuración del gráfico
    x = dataset['Coste en wei']
    y = dataset['Gas utilizado']
    size = 50
    colors = 'b'

    # Crear el gráfico de dispersión
    fig, ax = plt.subplots()
    ax.scatter(x, y, s=size, c=colors, alpha=0.5, label=dataset_name)

    # Configurar las etiquetas y leyendas del gráfico
    ax.set_xlabel('Coste en wei')
    ax.set_ylabel('Gas utilizado')
    ax.legend()

    # Añadir título al gráfico
    plt.title(f"Diagrama de dispersión: Gas utilizado vs Coste en wei - {dataset_name}")

    # Mostrar el gráfico
    plt.show()

# Generar la gráfica de dispersión para cada dataset
for dataset_name, dataset_values in datasets_resumen.items():
    plot_scatter(dataset_name, dataset_values)

# %% [markdown]
# ### En conjunto

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


# Configuración del gráfico
fig, ax = plt.subplots()
for i, (dataset_name, dataset_values) in enumerate(datasets_resumen.items()):
    x = dataset_values['Coste en wei']
    y = dataset_values['Gas utilizado']
    size = 50

    # Crear el gráfico de dispersión
    ax.scatter(x, y, s=size,  alpha=0.5, label=dataset_name)

# Configurar las etiquetas y leyendas del gráfico
ax.set_xlabel('Coste en wei')
ax.set_ylabel('Gas utilizado')
ax.legend(title='Datasets', bbox_to_anchor=(1.05, 1), loc='upper left')

# Añadir título al gráfico
plt.title("Diagrama de dispersión: Gas utilizado vs Coste en wei")

# Mostrar el gráfico
plt.show()

# %%
# Crear una lista vacía para almacenar los DataFrames
dataframes = []

# Recorrer el diccionario y agregar cada DataFrame a la lista
for dataset_name, dataset_values in datasets_resumen.items():
    dataset_values['Fuente'] = dataset_name
    dataframes.append(dataset_values)

# Concatenar los DataFrames en la lista
datos = pd.concat(dataframes, axis=0, ignore_index=True)

# Contar el número de puntos con las mismas coordenadas y fuente
conteo = datos.groupby(['Diferencia de tiempo', 'Coste en wei', 'Fuente']).size().reset_index(name='coincidencia')

# Ordenar los resultados por la columna 'coincidencia' de mayor a menor
conteo = conteo.sort_values(by=['coincidencia'], ascending=False)

# Crear una columna que indique la fuente de cada punto
for dataset_name in datasets_resumen:
    conteo['Fuente'] = conteo['Fuente'].apply(lambda x: dataset_name if x == dataset_name else x)


# Mostrar los resultados en formato de tabla
display(conteo.style.set_properties(**{'text-align': 'center'}).hide_index())
# Out:
# <style type="text/css">
# #T_d8735_row0_col0, #T_d8735_row0_col1, #T_d8735_row0_col2, #T_d8735_row0_col3, #T_d8735_row1_col0, #T_d8735_row1_col1, #T_d8735_row1_col2, #T_d8735_row1_col3, #T_d8735_row2_col0, #T_d8735_row2_col1, #T_d8735_row2_col2, #T_d8735_row2_col3, #T_d8735_row3_col0, #T_d8735_row3_col1, #T_d8735_row3_col2, #T_d8735_row3_col3, #T_d8735_row4_col0, #T_d8735_row4_col1, #T_d8735_row4_col2, #T_d8735_row4_col3, #T_d8735_row5_col0, #T_d8735_row5_col1, #T_d8735_row5_col2, #T_d8735_row5_col3, #T_d8735_row6_col0, #T_d8735_row6_col1, #T_d8735_row6_col2, #T_d8735_row6_col3, #T_d8735_row7_col0, #T_d8735_row7_col1, #T_d8735_row7_col2, #T_d8735_row7_col3, #T_d8735_row8_col0, #T_d8735_row8_col1, #T_d8735_row8_col2, #T_d8735_row8_col3, #T_d8735_row9_col0, #T_d8735_row9_col1, #T_d8735_row9_col2, #T_d8735_row9_col3, #T_d8735_row10_col0, #T_d8735_row10_col1, #T_d8735_row10_col2, #T_d8735_row10_col3, #T_d8735_row11_col0, #T_d8735_row11_col1, #T_d8735_row11_col2, #T_d8735_row11_col3, #T_d8735_row12_col0, #T_d8735_row12_col1, #T_d8735_row12_col2, #T_d8735_row12_col3, #T_d8735_row13_col0, #T_d8735_row13_col1, #T_d8735_row13_col2, #T_d8735_row13_col3, #T_d8735_row14_col0, #T_d8735_row14_col1, #T_d8735_row14_col2, #T_d8735_row14_col3, #T_d8735_row15_col0, #T_d8735_row15_col1, #T_d8735_row15_col2, #T_d8735_row15_col3, #T_d8735_row16_col0, #T_d8735_row16_col1, #T_d8735_row16_col2, #T_d8735_row16_col3, #T_d8735_row17_col0, #T_d8735_row17_col1, #T_d8735_row17_col2, #T_d8735_row17_col3, #T_d8735_row18_col0, #T_d8735_row18_col1, #T_d8735_row18_col2, #T_d8735_row18_col3, #T_d8735_row19_col0, #T_d8735_row19_col1, #T_d8735_row19_col2, #T_d8735_row19_col3, #T_d8735_row20_col0, #T_d8735_row20_col1, #T_d8735_row20_col2, #T_d8735_row20_col3, #T_d8735_row21_col0, #T_d8735_row21_col1, #T_d8735_row21_col2, #T_d8735_row21_col3, #T_d8735_row22_col0, #T_d8735_row22_col1, #T_d8735_row22_col2, #T_d8735_row22_col3, #T_d8735_row23_col0, #T_d8735_row23_col1, #T_d8735_row23_col2, #T_d8735_row23_col3, #T_d8735_row24_col0, #T_d8735_row24_col1, #T_d8735_row24_col2, #T_d8735_row24_col3, #T_d8735_row25_col0, #T_d8735_row25_col1, #T_d8735_row25_col2, #T_d8735_row25_col3, #T_d8735_row26_col0, #T_d8735_row26_col1, #T_d8735_row26_col2, #T_d8735_row26_col3, #T_d8735_row27_col0, #T_d8735_row27_col1, #T_d8735_row27_col2, #T_d8735_row27_col3, #T_d8735_row28_col0, #T_d8735_row28_col1, #T_d8735_row28_col2, #T_d8735_row28_col3, #T_d8735_row29_col0, #T_d8735_row29_col1, #T_d8735_row29_col2, #T_d8735_row29_col3, #T_d8735_row30_col0, #T_d8735_row30_col1, #T_d8735_row30_col2, #T_d8735_row30_col3, #T_d8735_row31_col0, #T_d8735_row31_col1, #T_d8735_row31_col2, #T_d8735_row31_col3, #T_d8735_row32_col0, #T_d8735_row32_col1, #T_d8735_row32_col2, #T_d8735_row32_col3, #T_d8735_row33_col0, #T_d8735_row33_col1, #T_d8735_row33_col2, #T_d8735_row33_col3, #T_d8735_row34_col0, #T_d8735_row34_col1, #T_d8735_row34_col2, #T_d8735_row34_col3, #T_d8735_row35_col0, #T_d8735_row35_col1, #T_d8735_row35_col2, #T_d8735_row35_col3, #T_d8735_row36_col0, #T_d8735_row36_col1, #T_d8735_row36_col2, #T_d8735_row36_col3, #T_d8735_row37_col0, #T_d8735_row37_col1, #T_d8735_row37_col2, #T_d8735_row37_col3, #T_d8735_row38_col0, #T_d8735_row38_col1, #T_d8735_row38_col2, #T_d8735_row38_col3, #T_d8735_row39_col0, #T_d8735_row39_col1, #T_d8735_row39_col2, #T_d8735_row39_col3, #T_d8735_row40_col0, #T_d8735_row40_col1, #T_d8735_row40_col2, #T_d8735_row40_col3, #T_d8735_row41_col0, #T_d8735_row41_col1, #T_d8735_row41_col2, #T_d8735_row41_col3, #T_d8735_row42_col0, #T_d8735_row42_col1, #T_d8735_row42_col2, #T_d8735_row42_col3, #T_d8735_row43_col0, #T_d8735_row43_col1, #T_d8735_row43_col2, #T_d8735_row43_col3, #T_d8735_row44_col0, #T_d8735_row44_col1, #T_d8735_row44_col2, #T_d8735_row44_col3, #T_d8735_row45_col0, #T_d8735_row45_col1, #T_d8735_row45_col2, #T_d8735_row45_col3, #T_d8735_row46_col0, #T_d8735_row46_col1, #T_d8735_row46_col2, #T_d8735_row46_col3, #T_d8735_row47_col0, #T_d8735_row47_col1, #T_d8735_row47_col2, #T_d8735_row47_col3, #T_d8735 ...

# %% [markdown]
# ### BoxPlot

# %% [markdown]
# EL Boxplot nos permite visualizar la distribución de un conjunto de datos. El boxplot muestra la mediana (línea dentro de la caja), el rango intercuartil (la caja que va desde el primer cuartil al tercer cuartil), los valores mínimo y máximo (los bigotes), y los posibles valores atípicos o extremos (los puntos fuera de los bigotes)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Configuración del gráfico
data = []
labels = []
colors = []

for dataset_name, dataset_values in datasets_resumen.items():
    data.append(dataset_values['Gas utilizado'])
    labels.append(dataset_name)
    colors.append(np.random.rand(3,))

# Crear el gráfico
fig, ax = plt.subplots(figsize=(13, 6))

# Cambiar el color de cada boxplot y guardar las cajas en una lista
boxes = ax.boxplot(data, labels=labels, patch_artist=True, whiskerprops=dict(linestyle='-', linewidth=1.5))
for box, color in zip(boxes['boxes'], colors):
    box.set_facecolor(color)

# Obtener la mediana de cada set de datos y mostrarla en el gráfico
for i, median in enumerate(boxes['medians']):
    median_val = np.median(data[i])
    ax.text(i + 1, median_val, f"{median_val:.4f}", horizontalalignment='center', fontsize=10)

# Configurar las etiquetas y leyendas del gráfico
ax.set_ylabel('Gas utilizado')
ax.set_title('Boxplot de Gas utilizado por cada dataset')
plt.xticks(range(1, len(labels) + 1), labels)
ax.tick_params(axis='x', which='major', pad=15)

# Ajustar los límites del eje y
ymin, ymax = ax.get_ylim()
margin = (ymax - ymin) * 0.1
ax.set_ylim(ymin - margin, ymax + margin)

# Mostrar el gráfico
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

data = []
labels = []
colors = []

for dataset_name, dataset_values in datasets_resumen.items():
    data.append(dataset_values['Coste en wei'])
    labels.append(dataset_name)
    colors.append(np.random.rand(3,))

# Crear el gráfico
fig, ax = plt.subplots(figsize=(13, 8))

# Cambiar el color de cada boxplot y guardar las cajas en una lista
boxes = ax.boxplot(data, labels=labels, patch_artist=True, whiskerprops=dict(linestyle='-', linewidth=1.5))
for box, color in zip(boxes['boxes'], colors):
    box.set(facecolor=color)

# Obtener la mediana de cada set de datos y mostrarla debajo de la grafica
medians = [np.median(d) for d in data]
median_labels = [f"{dataset_name}: {median:.9f}" for dataset_name, median in zip(labels, medians)]

# Agregar leyenda con rectángulos de colores
rects = [plt.Rectangle((0, 0), 1, 1, color=color) for color in colors]
ax.legend(rects, labels, loc='upper right')

# Configurar las etiquetas y leyendas del gráfico
ax.set_ylabel('Coste en dólares')
ax.set_title('Boxplot de Coste en wei por cada dataset')
ax.tick_params(axis='x', which='major', pad=15)

# Ajustar los límites del eje y
ymin, ymax = ax.get_ylim()
margin = (ymax - ymin) * 0.1
ax.set_ylim(ymin - margin, ymax + margin)

# Mostrar el gráfico
plt.show()

# Mostrar texto con la mediana debajo de la gráfica
fig, ax = plt.subplots(figsize=(12, 1))
ax.axis('off')
ax.text(0, 0, '\n'.join(median_labels), ha='left', va='center', fontsize=12)
plt.show()

# %% [markdown]
# ### Variación del coste total en función de la duración de las transacciones Grafico de linea

# %%
import matplotlib.pyplot as plt

# Configuración del gráfico
fig, ax = plt.subplots(figsize=(8, 6))

# Crear el gráfico de línea para cada conjunto de datos en datasets_resumen
for dataset_name, dataset_values in datasets_resumen.items():
    x = dataset_values['Duración']
    y = dataset_values['Coste en wei']
    ax.plot(x, y, label=dataset_name)
    
# Configurar las etiquetas y leyendas del gráfico
ax.set_xlabel('Tiempo')
ax.set_ylabel('Coste en wei')
ax.legend()
fig.suptitle('Variación del coste total en función de la duración de las transacciones')
ax.xaxis.set_major_locator(plt.MaxNLocator(integer=True)) # Establece el eje x como continuo
plt.ylim(bottom=0) # Asegura que el eje y empiece desde cero
plt.ylim(bottom=0)  # Asegura que el eje y empiece desde cero
plt.show()

# %%
import matplotlib.pyplot as plt

# Configuración del gráfico
fig, ax = plt.subplots(figsize=(8, 6))

# Crear el gráfico de línea para cada conjunto de datos en datasets_resumen
for dataset_name, dataset_values in datasets_resumen.items():
    x = dataset_values['Duración']
    y = dataset_values['Coste en dólares']
    ax.plot(x, y, label=dataset_name)
    
# Configurar las etiquetas y leyendas del gráfico
ax.set_xlabel('Tiempo')
ax.set_ylabel('Coste en dólares')
ax.legend()
fig.suptitle('Variación del coste total en función de la duración de las transacciones')
ax.xaxis.set_major_locator(plt.MaxNLocator(integer=True)) # Establece el eje x como continuo
plt.ylim(bottom=0) # Asegura que el eje y empiece desde cero
plt.ylim(bottom=0)  # Asegura que el eje y empiece desde cero
plt.show()

# %% [markdown]
# # Dataset Total

# %%
from prettytable import PrettyTable

for dataset_name, dataset_values in datasets_resumen.items():
    # Obtener la media de la duración y el coste en ether
    media_duracion = dataset_values['Duración'].mean()
    media_coste_ether = dataset_values['Coste total'].mean()
    media_coste_dolares = dataset_values['Coste en dólares total'].mean()

    # Imprimir las estadísticas para el conjunto de datos actual
    print('\n')
    print("Estadísticas para el conjunto de datos", dataset_name)
    table = PrettyTable()
    table.field_names = ["Estadísticas", "Valor"]
    table.add_row(["Media de Duración", f"{media_duracion:.2f}"])
    table.add_row(["Media de Coste en ether", media_coste_ether])
    table.add_row(["Media de Coste en dolares", media_coste_dolares])
    print(table)
# Out:
# Estadísticas para el conjunto de datos goerli
# +---------------------------+--------------------+
# |        Estadísticas       |       Valor        |
# +---------------------------+--------------------+
# |     Media de Duración     |       227.28       |
# |  Media de Coste en ether  |    0.016153319     |
# | Media de Coste en dolares | 30.755919375999998 |
# +---------------------------+--------------------+
#
#
# Estadísticas para el conjunto de datos arbitrum
# +---------------------------+-----------------------+
# |        Estadísticas       |         Valor         |
# +---------------------------+-----------------------+
# |     Media de Duración     |         29.05         |
# |  Media de Coste en ether  | 0.0006461327600000001 |
# | Media de Coste en dolares |   1.2302367750400003  |
# +---------------------------+-----------------------+
#
#
# Estadísticas para el conjunto de datos avalanche
# +---------------------------+----------------------+
# |        Estadísticas       |        Valor         |
# +---------------------------+----------------------+
# |     Media de Duración     |        76.28         |
# |  Media de Coste en ether  | 0.022614646599999996 |
# | Media de Coste en dolares | 0.49752222520000006  |
# +---------------------------+----------------------+
#
#
# Estadísticas para el conjunto de datos optimism
# +---------------------------+---------------------+
# |        Estadísticas       |        Valor        |
# +---------------------------+---------------------+
# |     Media de Duración     |        78.72        |
# |  Media de Coste en ether  | 0.01617194484445575 |
# | Media de Coste en dolares |  30.791382983843747 |
# +---------------------------+---------------------+
#
#
# Estadísticas para el conjunto de datos optimism_bear
# +---------------------------+-----------------------+
# |        Estadísticas       |         Valor         |
# +---------------------------+-----------------------+
# |     Media de Duración     |         39.48         |
# |  Media de Coste en ether  | 0.0008282288712251761 |
# | Media de Coste en dolares |   1.576947770812735   |
# +---------------------------+-----------------------+
#
#
# Estadísticas para el conjunto de datos celo
# +---------------------------+----------------------+
# |        Estadísticas       |        Valor         |
# +---------------------------+----------------------+
# |     Media de Duración     |        68.22         |
# |  Media de Coste en ether  | 0.015097718999999996 |
# | Media de Coste en dolares | 0.014342833049999996 |
# +---------------------------+----------------------+
#
#
# Estadísticas para el conjunto de datos sepolia_bear
# +---------------------------+-----------------------+
# |        Estadísticas       |         Valor         |
# +---------------------------+-----------------------+
# |     Media de Duración     |         39.80         |
# |  Media de Coste en ether  | 0.0006461327645219802 |
# | Media de Coste en dolares |   1.2302367836498505  |
# +---------------------------+-----------------------+
#
#
# Estadísticas para el conjunto de datos arbitrum_bear
# +---------------------------+-----------------------+
# |        Estadísticas       |         Valor         |
# +---------------------------+-----------------------+
# |     Media de Duración     |         39.00         |
# |  Media de Coste en ether  | 0.0006643330495595682 |
# | Media de Coste en dolares |   1.2648901263614178  |
# +---------------------------+-----------------------+
#
#
# Estadísticas para el conjunto de datos sepolia
# +---------------------------+----------------------+
# |        Estadísticas       |        Valor         |
# +---------------------------+----------------------+
# |     Media de Duración     |        175.24        |
# |  Media de Coste en ether  | 0.019383982799999994 |
# | Media de Coste en dolares |  36.90710325119999   |
# +---------------------------+----------------------+
#
#
# Estadísticas para el conjunto de datos polygon_bear
# +---------------------------+----------------------+
# |        Estadísticas       |        Valor         |
# +---------------------------+----------------------+
# |     Media de Duración     |        41.19         |
# |  Media de Coste en ether  | 0.038297236564549836 |
# | Media de Coste en dolares |  72.91793841890288   |
# +---------------------------+----------------------+

# %%
import random
import matplotlib.pyplot as plt

# Crear una lista de colores aleatorios para cada conjunto de datos
colores = [tuple(random.random() for _ in range(3)) for _ in datasets_resumen]

# Configurar el gráfico de líneas
fig, ax = plt.subplots()
for i, (dataset_name, dataset_values) in enumerate(datasets_resumen.items()):
    duracion_media = dataset_values['Duración']
    coste_media = dataset_values['Coste total']
    ax.plot(duracion_media, coste_media, color=colores[i], label=dataset_name)

ax.set_xlabel('Duración (s)')
ax.set_ylabel('Coste en ether')
ax.set_title('Duración y Coste en ether por conjunto de datos')

# Ubicar la leyenda al lado derecho del gráfico
ax.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# Ajustar el tamaño de la figura
fig.set_size_inches(10, 6)

# Mostrar el gráfico
plt.show()

# %%
import random
import matplotlib.pyplot as plt

# Crear una lista de colores aleatorios para cada conjunto de datos
colores = [tuple(random.random() for _ in range(3)) for _ in datasets_resumen]

# Configurar el gráfico de líneas
fig, ax = plt.subplots()
for i, (dataset_name, dataset_values) in enumerate(datasets_resumen.items()):
    duracion_media = dataset_values['Duración']
    coste_media = dataset_values['Coste en dólares total']
    ax.plot(duracion_media, coste_media, color=colores[i], label=dataset_name)

ax.set_xlabel('Duración (s)')
ax.set_ylabel('Coste en dolares')
ax.set_title('Duración y Coste en dolares por conjunto de datos')

# Ubicar la leyenda al lado derecho del gráfico
ax.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# Ajustar el tamaño de la figura
fig.set_size_inches(10, 6)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Licence
# The notebook is freely licensed under under the [Creative Commons Attribution Share-Alike license](https://creativecommons.org/licenses/by/2.0/).
#
# ©  Carlos A. Iglesias, Universidad Politécnica de Madrid.
